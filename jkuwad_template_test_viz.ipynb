# %% [markdown]
# # Deep Reinforcement Learning — Doom Agent (SS2025)
#
# Welcome to the last assignment for the **Deep Reinforcement Learning** course (SS2025). In this notebook, you"ll implement and train a reinforcement learning agent to play **Doom**.
#
# You will:
# - Set up a custom VizDoom environment with shaped rewards
# - Train an agent using an approach of your choice
# - Track reward components across episodes
# - Evaluate the best model
# - Visualize performance with replays and GIFs
# - Export the trained agent to ONNX to submit to the evaluation server

# %%
# Clone repo
#!git clone https://$token@github.com/gerkone/jku.wad.git
#%cd jku.wad

# %%
# Install the dependencies
#!pip install torch numpy matplotlib vizdoom portpicker gym onnx

# %%
from IPython import get_ipython
get_ipython().run_line_magic('load_ext', 'autoreload')
get_ipython().run_line_magic('autoreload', '2')

# %%
from typing import Dict, Sequence
from datetime import datetime
import torch
from collections import deque, OrderedDict
from copy import deepcopy
import random
import numpy as np
import torch.nn.functional as F
import torch.optim as optim
import pandas as pd
from matplotlib import pyplot as plt
from PIL import Image
import vizdoom as vzd
from vizdoom import ScreenFormat

import pandas as pd

from gym import Env
from torch import nn
from einops import rearrange

from doom_arena import VizdoomMPEnv, ObsBuffer
from doom_arena.render import render_episode
from IPython.display import HTML
from typing import Dict, Tuple

# %%
from agents.utils import *
from agents.utils_viz import *
from agents.helpers import *
from agents.dqn import EfficientDQN, epsilon_greedy, soft_update_target_network

# %% [markdown]
# ## Environment configuration
#
# ViZDoom supports multiple visual buffers that can be used as input for training agents. Each buffer provides different information about the game environment, as seen from left to right:
#
#
# Screen
# - The default first-person RGB view seen by the agent.
#
# Labels
# - A semantic map where each pixel is tagged with an object ID (e.g., enemy, item, wall).
#
# Depth
# - A grayscale map showing the distance from the agent to surfaces in the scene.
#
# Automap
# - A top-down schematic view of the map, useful for global navigation tasks.
#
# ![buffers gif](https://vizdoom.farama.org/_images/vizdoom-demo.gif)

# %%
USE_GRAYSCALE = False  # ← flip to False for RGB

PLAYER_CONFIG = {
    # NOTE: "algo_type" defaults to POLICY in evaluation script!
    "algo_type": "QVALUE",  # OPTIONAL, change to POLICY if using policy-based (eg PPO)
    "n_stack_frames": 1, #4, # 1 # Temporal information
    "extra_state": ["labels"],#, "automap"], #["depth", "labels", "automap"],
    "hud": "none",
    "crosshair": True,
    "screen_format": 8 if USE_GRAYSCALE else 0,
}

EXTRA_STATE_DIMS = {key: value for key, value in {"screen": 3, "labels": 1, "depth": 1, "automap": 3}.items() if key in PLAYER_CONFIG["extra_state"] or key == "screen"}

# %%
# TODO: environment training paramters
N_STACK_FRAMES = 1 # 4 does not work yet!
NUM_PLAYERS = 3
NUM_BOTS = 1 #1, #6
EPISODE_TIMEOUT = 2000
# TODO: model hyperparams
GAMMA = 0.99
EPISODES = 500
BATCH_SIZE = 64
REPLAY_BUFFER_SIZE = 20_000
LEARNING_RATE = 5e-5
EPSILON_START = 1.0
EPSILON_END = 0.1
EPSILON_DECAY = 0.995 # 0.987
N_EPOCHS = 50
TARGET_UPDATE_FREQ = 1000
FRAME_SKIPPING = 0
FRAME_SKIPPING_STOP = 100
DEBUG = True
PRINT_EVERY = 20

# %%
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print("Device:", device)

DTYPE = torch.float32

reward_fn = YourReward(num_players=NUM_PLAYERS)

env = VizdoomMPEnv(
    num_players=NUM_PLAYERS, # 4 is max
    num_bots=NUM_BOTS,
    bot_skill=1, # Increased difficulty
    doom_map="ROOM",  # NOTE simple, small map; other options: TRNM, TRNMBIG
    extra_state=PLAYER_CONFIG["extra_state"],  # see info about states at the beginning of "Environment configuration" above
    episode_timeout=EPISODE_TIMEOUT,
    n_stack_frames=PLAYER_CONFIG["n_stack_frames"],
    crosshair=PLAYER_CONFIG["crosshair"],
    hud=PLAYER_CONFIG["hud"],
    screen_format=PLAYER_CONFIG["screen_format"],
    reward_fn=reward_fn,
    seed = np.random.randint(1, 2000, NUM_PLAYERS),
    ticrate = 35*3,
)
# Out:
# Device: mps
# Environment Seed: [1534 1459   77]
# Host 59779
# Player 59779

# %% [markdown]
# ## Agent
#
# Implement **your own agent** in the code cell that follows.
#
# * In `agents/dqn.py` and `agents/ppo.py` you’ll find very small **skeletons**—they compile but are meant only as reference or quick tests.
#   Feel free to open them, borrow ideas, extend them, or ignore them entirely.
# * The notebook does **not** import those files automatically; whatever class you define in the next cell is the one that will be trained.
# * You may keep the DQN interface, switch to PPO, or try something else.
# * Tweak any hyper-parameters (`PLAYER_CONFIG`, ε-schedule, optimiser, etc.) and document what you tried.

# %%
# ================================================================
# Initialise your networks and training utilities
# ================================================================

# main Q-network
input_channels = {k: v *  N_STACK_FRAMES for k, v in EXTRA_STATE_DIMS.items()}
print(input_channels)

model = EfficientDQN(
    input_channels_dict=input_channels,
    action_space=env.action_space.n if env.num_players == 1 else env.action_space[0].n,
    feature_dim_cnns = 128,
    hidden_dim_heads = 2048,
).to(device, dtype=DTYPE)

# Load a model from file
# model = model.load_model("runs/20250620_151451/best_model_20250620_153705.pt")
# Out:
# {'screen': 3, 'labels': 1}
# Initialized model with 2963309 parameters!

# %%
target_model  = deepcopy(model).to(device, dtype=DTYPE)
optimizer  = torch.optim.AdamW(target_model.parameters(), lr=LEARNING_RATE, weight_decay=5e-4)
scheduler  = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=20, eta_min=1e-5)
loss_fn = nn.MSELoss()
replay_buffer = deque(maxlen=REPLAY_BUFFER_SIZE)

# %% [markdown]
# ## Example of environment

# %%
# Reset environment
with suppress_output():
    obs_test: torch.Tensor = env.reset()
    obs_test = torch.stack(obs_test)
    
for player in range(len(obs_test)):
    plot_images(obs_test[player], EXTRA_STATE_DIMS)

# %%
# Iterate 60 steps
STEPS = 30

if env.num_players > 1:
    actions = [random.randint(0, action_space.n - 1) for action_space in env.action_space] # Multiple players
else:
    actions = random.randint(0, env.action_space.n - 1) # Single players


for i in range(STEPS):
    obs_test_tensor = process_observation(obs_test, EXTRA_STATE_DIMS, device, DTYPE)
    actions = model(obs_test_tensor).argmax(dim=1).tolist()
    obs_test: torch.Tensor = env.step(actions)[0]
    obs_test = torch.stack(obs_test)

for player in range(env.num_players):
    plot_images(obs_test[player], EXTRA_STATE_DIMS)

# %%
obs_test: torch.Tensor = env.step((6,0,9))[0]
obs_test = torch.stack(obs_test)

for player in range(env.num_players):
    plot_images(obs_test[player], EXTRA_STATE_DIMS)

# %% [markdown]
# ### Example of Reward

# %%
player_idx = np.random.randint(0, env.num_players)
for key, value_now, value_old in zip(env.envs[player_idx].unwrapped._game_vars, env.envs[player_idx].unwrapped._game_vars.values(), env.envs[player_idx].unwrapped._game_vars_pre.values()):
    print(f"{key+':':<25}{value_now:.0f} | {value_old:.0f}")
# Out:
# HEALTH:                  0 | 0
# AMMO3:                   0 | 0
# FRAGCOUNT:               0 | 0
# ARMOR:                   0 | 0
# HITCOUNT:                0 | 0
# HITS_TAKEN:              0 | 0
# DEAD:                    1 | 1
# DEATHCOUNT:              0 | 0
# DAMAGECOUNT:             0 | 0
# DAMAGE_TAKEN:            0 | 0
# KILLCOUNT:               0 | 0
# SELECTED_WEAPON:         2 | 2
# SELECTED_WEAPON_AMMO:    110 | 110
# POSITION_X:              453 | 453
# POSITION_Y:              16 | 16

# %% [markdown]
# ## Training loop

# %%
# ---------------------  TRAINING LOOP  ----------------------

# Create folder for training
training_id = datetime.now().strftime("%Y%m%d_%H%M%S")
training_folder = os.path.join("runs", training_id)
os.makedirs(training_folder, exist_ok=True)

# Define logger
logger = FileLogger(training_folder, also_print=DEBUG)

# %%
from agents.utils import get_buttons

# %%
# Training settings
q_loss_list, epsilon_history = [], []
reward_history = {player: [] for player in range(env.num_players)}
best_reward = float("-inf")
best_model = None

epsilon = EPSILON_START 
steps_done = 0

for episode in range(EPISODES):
    
    episode_action_counter = ActionCounter()
    
    with suppress_output():
        obs: torch.Tensor = env.reset()
    
    # Episode variables for each player
    episode_metrics = {player: {"frags": 0, "hits": 0, "damage_taken": 0, "movement": 0, "ammo_efficiency": 0, "survival": 0, "health_pickup": 0} for player in range(env.num_players)}
    episode_reward = {player: 0.0 for player in range(env.num_players)}
        
    done = False
    model.eval()
    
    episode_msg = f"{datetime.now().strftime("%H:%M:%S")} | Episode: {episode} | Steps done: {steps_done} | Gathering rollout (currently {len(replay_buffer)})"
    logger.log(episode_msg)
    
    # ───────── rollout ─────────────────────────────────────────────
    while not done:
        
        # Skip Frames (Testing - I am aware that in the original paper they stacked the images. I want to get many more steps at the beginning)
        act = epsilon_greedy(env, model, obs, epsilon, device, EXTRA_STATE_DIMS, DTYPE, episode_action_counter)
        
        max_skip_steps = max(FRAME_SKIPPING * (episode < FRAME_SKIPPING_STOP), 1)
        for skip_steps in range(max_skip_steps):    
            next_obs, reward, done, _ = env.step(act)
            steps_done += 1

        # ----- reward definition ----------------
        for player_idx in range(env.num_players):
            episode_reward[player_idx] += np.sum(reward[player_idx]) # Should be a list with one value
            reward_components = reward_fn(None, env.envs[player_idx].unwrapped._game_vars, env.envs[player_idx].unwrapped._game_vars_pre, None)

            if len(reward_components) >= 6:
                episode_metrics[player_idx]["frags"] += reward_components[0]
                episode_metrics[player_idx]["hits"] += reward_components[1]
                episode_metrics[player_idx]["damage_taken"] += reward_components[2]
                episode_metrics[player_idx]["movement"] += reward_components[3]
                episode_metrics[player_idx]["ammo_efficiency"] += reward_components[4]
                episode_metrics[player_idx]["survival"] += reward_components[5]
                episode_metrics[player_idx]["health_pickup"] += reward_components[6]
        
            # ----- buffer and environment handling ----------------
            if env.num_players == 1:
                act = [act]
                
            replay_buffer.append((obs[player_idx], act[player_idx], reward[player_idx], next_obs[player_idx], done))
        
    obs = next_obs
    [reward_history[player_idx].append(reward) for player_idx, reward in episode_reward.items()] # Append rewards for every player
    epsilon_history.append(epsilon)

    # ───────── learning step (experience replay) ──────────────────
    if len(replay_buffer) >= BATCH_SIZE:
        #print(f"{datetime.now().strftime("%H:%M:%S")} | Episode: {episode} | Enriching replay buffer...") if DEBUG else None

        model.train()
        train_msg = f"{datetime.now().strftime("%H:%M:%S")} | Episode: {episode} | Training for {N_EPOCHS} epochs"
        logger.log(train_msg)
        
        for epoch in range(N_EPOCHS):

            batch = random.sample(replay_buffer, BATCH_SIZE)
            states, actions, rewards, next_states, dones = zip(*batch)

            # Convert to tensors for training
            states = process_observation(torch.stack(states), EXTRA_STATE_DIMS, device, DTYPE)
            next_states = process_observation(torch.stack(next_states), EXTRA_STATE_DIMS, device, DTYPE)
            actions = torch.tensor(actions, device=device)
            rewards = torch.tensor(rewards, device=device, dtype=torch.float32) #.squeeze(1) # Added squeeze here
            dones = torch.tensor(dones, device=device, dtype=torch.float32)

            current_q = model(states).gather(1, actions.unsqueeze(1)).squeeze(1)
            
            # Target q values
            with torch.no_grad():
                next_q = target_model(next_states).max(1)[0] #.values
                target_q = rewards + GAMMA * next_q * (1 - dones)
            
            loss = loss_fn(current_q, target_q) # TODO: Check whether correct, did that in Deep Q Assignment

            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            
            q_loss_list.append(loss.item())
        
        # Update target network        
        target_update_msg = f"{datetime.now().strftime("%H:%M:%S")} | Episode: {episode} | Updating target network..."
        logger.log(target_update_msg)
        soft_update_target_network(model, target_model, tau=1e-3)
        #hard_update_target_network(target_model, model)
        
        # Update scheduler and epsilon
        scheduler.step()
        epsilon = max(EPSILON_END, epsilon * EPSILON_DECAY)

    else:
        train_fail_msg = f"{datetime.now().strftime("%H:%M:%S")} | Episode: {episode} | Replay buffer smaller than batchsize {len(replay_buffer)} {BATCH_SIZE}"
        logger.log(train_fail_msg, print_once=True)

    # -------- logging ----------
    avg_reward = get_avg_reward(reward_history, episodes=PRINT_EVERY, round=0)
    avg_loss = np.mean(q_loss_list[-10:]) if q_loss_list else 0
    stacked_episode_reward = np.array([np.round(reward, 0) for reward in episode_reward.values()])
    
    action_counts = episode_action_counter.get_counts()

    # Rewards and losses
    reward_msg = f"{datetime.now().strftime("%H:%M:%S")} | Episode: {episode} | Rewards:\n"
    reward_msg += f"\tReward: {stacked_episode_reward} | Avg Reward: {avg_reward} | Loss: {avg_loss:.4f} | ε: {epsilon:.3f} | LR: {scheduler.get_last_lr()[0]:.2e}"
    reward_msg += f"\n\tMetrics - {[f'{metric}: {value}' for metric, value in get_average_result(episode_metrics).items()]}"
    reward_msg += f"\n\tActions - {', '.join([f"{k}: {v}" for k, v in sorted(action_counts.items())])}"
    
    logger.log(reward_msg, print_once = episode % PRINT_EVERY == 0)
        
    # Show the video 
    if episode % PRINT_EVERY * 2 == 0:
        with suppress_output():
            replay_episode(env, target_model, device, EXTRA_STATE_DIMS, DTYPE, path=training_folder, store=True)
    
    # ───────── quick evaluation for best-model tracking ───────────
    quick_eval_msg = f"{datetime.now().strftime("%H:%M:%S")} | Episode: {episode} | Running quick evaluation..."
    logger.log(quick_eval_msg)

    with suppress_output():
        eval_obs = env.reset() # List of obs
        
    eval_episode_rewards = [0.0] * env.num_players
    eval_done = False
    model.eval()
 
    while not eval_done:
        eval_action_list = epsilon_greedy(env, model, eval_obs, 0, device, EXTRA_STATE_DIMS, DTYPE)
        eval_next_obs_list, eval_reward_list, eval_done, _ = env.step(eval_action_list)
        for i in range(env.num_players):
            eval_episode_rewards[i] += eval_reward_list[i]
        eval_obs = eval_next_obs_list
    
    mean_eval_reward = np.mean(eval_episode_rewards)
    
    if mean_eval_reward > best_reward:
        best_reward = mean_eval_reward
        model_name = "best_model_" + datetime.now().strftime("%Y%m%d_%H%M%S") + ".pt"
        model.save_model(path=training_folder, filename=model_name)
        best_model = deepcopy(model)
# Out:
# 21:32:49 | Episode: 0 | Steps done: 0 | Gathering rollout (currently 0)
# 21:33:07 | Episode: 0 | Training for 50 epochs
# 21:33:12 | Episode: 0 | Updating target network...
# 21:33:12 | Episode: 0 | Rewards:
# 	Reward: [ 412. -450.  246.] | Avg Reward: 69.0 | Loss: 0.7865 | ε: 0.995 | LR: 4.98e-05
# 	Metrics - ['frags: 0', 'hits: 65', 'damage_taken: -4', 'movement: 59', 'ammo_efficiency: 46', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1197, 1: 1196, 2: 695, 3: 760, 4: 886, 5: 926, 6: 167, 7: 173
# 21:33:47 | Episode: 0 | Running quick evaluation...
# Successfully stored the model: runs/20250620_213247/best_model_20250620_213415.pt
# 21:34:16 | Episode: 1 | Steps done: 2000 | Gathering rollout (currently 6000)
# 21:34:35 | Episode: 1 | Training for 50 epochs
# 21:34:37 | Episode: 1 | Updating target network...
# 21:34:37 | Episode: 1 | Rewards:
# 	Reward: [ 317.  233. -499.] | Avg Reward: 43.0 | Loss: 0.8964 | ε: 0.990 | LR: 4.90e-05
# 	Metrics - ['frags: 0', 'hits: 35', 'damage_taken: -2', 'movement: 54', 'ammo_efficiency: 26', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1239, 1: 1197, 2: 686, 3: 735, 4: 918, 5: 886, 6: 179, 7: 160
# 21:34:37 | Episode: 1 | Running quick evaluation...
# Successfully stored the model: runs/20250620_213247/best_model_20250620_213504.pt
# 21:35:05 | Episode: 2 | Steps done: 4000 | Gathering rollout (currently 12000)
# 21:35:24 | Episode: 2 | Training for 50 epochs
# 21:35:26 | Episode: 2 | Updating target network...
# 21:35:26 | Episode: 2 | Rewards:
# 	Reward: [ 418. -597.  247.] | Avg Reward: 36.0 | Loss: 2.0137 | ε: 0.985 | LR: 4.78e-05
# 	Metrics - ['frags: 0', 'hits: 35', 'damage_taken: -2', 'movement: 59', 'ammo_efficiency: 26', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1181, 1: 1212, 2: 731, 3: 720, 4: 917, 5: 908, 6: 180, 7: 151
# 21:35:26 | Episode: 2 | Running quick evaluation...
# Successfully stored the model: runs/20250620_213247/best_model_20250620_213553.pt
# 21:35:55 | Episode: 3 | Steps done: 6000 | Gathering rollout (currently 18000)
# 21:36:14 | Episode: 3 | Training for 50 epochs
# 21:36:16 | Episode: 3 | Updating target network...
# 21:36:16 | Episode: 3 | Rewards:
# 	Reward: [ 384. -579.  657.] | Avg Reward: 66.0 | Loss: 5.7132 | ε: 0.980 | LR: 4.62e-05
# 	Metrics - ['frags: 0', 'hits: 115', 'damage_taken: -7', 'movement: 63', 'ammo_efficiency: 79', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1229, 1: 1158, 2: 694, 3: 815, 4: 866, 5: 898, 6: 168, 7: 172
# 21:36:16 | Episode: 3 | Running quick evaluation...
# 21:36:44 | Episode: 4 | Steps done: 8000 | Gathering rollout (currently 20000)
# 21:37:03 | Episode: 4 | Training for 50 epochs
# 21:37:05 | Episode: 4 | Updating target network...
# 21:37:05 | Episode: 4 | Rewards:
# 	Reward: [ 457. -428.  594.] | Avg Reward: 94.0 | Loss: 4.7196 | ε: 0.975 | LR: 4.41e-05
# 	Metrics - ['frags: 0', 'hits: 150', 'damage_taken: -10', 'movement: 61', 'ammo_efficiency: 102', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1191, 1: 1173, 2: 691, 3: 816, 4: 860, 5: 887, 6: 187, 7: 195
# 21:37:05 | Episode: 4 | Running quick evaluation...
# 21:37:34 | Episode: 5 | Steps done: 10000 | Gathering rollout (currently 20000)
# 21:37:53 | Episode: 5 | Training for 50 epochs
# 21:37:55 | Episode: 5 | Updating target network...
# 21:37:55 | Episode: 5 | Rewards:
# 	Reward: [ 359. -279.  330.] | Avg Reward: 101.0 | Loss: 3.6743 | ε: 0.970 | LR: 4.18e-05
# 	Metrics - ['frags: 0', 'hits: 105', 'damage_taken: -7', 'movement: 62', 'ammo_efficiency: 72', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1097, 1: 1188, 2: 701, 3: 883, 4: 874, 5: 919, 6: 157, 7: 181
# 21:37:55 | Episode: 5 | Running quick evaluation...
# Successfully stored the model: runs/20250620_213247/best_model_20250620_213823.pt
# 21:38:24 | Episode: 6 | Steps done: 12000 | Gathering rollout (currently 20000)
# 21:38:43 | Episode: 6 | Training for 50 epochs
# 21:38:45 | Episode: 6 | Updating target network...
# 21:38:45 | Episode: 6 | Rewards:
# 	Reward: [ 424. -347.  602.] | Avg Reward: 119.0 | Loss: 1.7915 | ε: 0.966 | LR: 3.91e-05
# 	Metrics - ['frags: 0', 'hits: 160', 'damage_taken: -10', 'movement: 63', 'ammo_efficiency: 109', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1139, 1: 1159, 2: 709, 3: 912, 4: 844, 5: 862, 6: 200, 7: 175
# 21:38:45 | Episode: 6 | Running quick evaluation...
# 21:39:14 | Episode: 7 | Steps done: 14000 | Gathering rollout (currently 20000)
# 21:39:33 | Episode: 7 | Training for 50 epochs
# 21:39:34 | Episode: 7 | Updating target network...
# 21:39:34 | Episode: 7 | Rewards:
# 	Reward: [ 383. -522.  398.] | Avg Reward: 115.0 | Loss: 1.9745 | ε: 0.961 | LR: 3.62e-05
# 	Metrics - ['frags: 0', 'hits: 75', 'damage_taken: -5', 'movement: 59', 'ammo_efficiency: 52', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1137, 1: 1199, 2: 703, 3: 864, 4: 845, 5: 899, 6: 181, 7: 172
# 21:39:34 | Episode: 7 | Running quick evaluation...
# 21:40:03 | Episode: 8 | Steps done: 16000 | Gathering rollout (currently 20000)
# 21:40:23 | Episode: 8 | Training for 50 epochs
# 21:40:24 | Episode: 8 | Updating target network...
# 21:40:24 | Episode: 8 | Rewards:
# 	Reward: [ 585.  236. -556.] | Avg Reward: 112.0 | Loss: 3.3455 | ε: 0.956 | LR: 3.31e-05
# 	Metrics - ['frags: 0', 'hits: 80', 'damage_taken: -5', 'movement: 53', 'ammo_efficiency: 56', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1164, 1: 1144, 2: 696, 3: 907, 4: 858, 5: 872, 6: 178, 7: 181
# 21:40:24 | Episode: 8 | Running quick evaluation...
# 21:40:53 | Episode: 9 | Steps done: 18000 | Gathering rollout (currently 20000)
# 21:41:12 | Episode: 9 | Training for 50 epochs
# 21:41:14 | Episode: 9 | Updating target network...
# 21:41:14 | Episode: 9 | Rewards:
# 	Reward: [ 325. -574.  688.] | Avg Reward: 115.0 | Loss: 3.5714 | ε: 0.951 | LR: 3.00e-05
# 	Metrics - ['frags: 0', 'hits: 110', 'damage_taken: -7', 'movement: 63', 'ammo_efficiency: 76', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1179, 1: 1130, 2: 636, 3: 985, 4: 852, 5: 863, 6: 166, 7: 189
# 21:41:14 | Episode: 9 | Running quick evaluation...
# 21:41:43 | Episode: 10 | Steps done: 20000 | Gathering rollout (currently 20000)
# 21:42:02 | Episode: 10 | Training for 50 epochs
# 21:42:04 | Episode: 10 | Updating target network...
# 21:42:04 | Episode: 10 | Rewards:
# 	Reward: [ 315.  273. -624.] | Avg Reward: 104.0 | Loss: 3.8026 | ε: 0.946 | LR: 2.69e-05
# 	Metrics - ['frags: 0', 'hits: 15', 'damage_taken: -1', 'movement: 57', 'ammo_efficiency: 12', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1143, 1: 1145, 2: 684, 3: 992, 4: 890, 5: 815, 6: 169, 7: 162
# 21:42:04 | Episode: 10 | Running quick evaluation...
# 21:42:33 | Episode: 11 | Steps done: 22000 | Gathering rollout (currently 20000)
# 21:42:52 | Episode: 11 | Training for 50 epochs
# 21:42:54 | Episode: 11 | Updating target network...
# 21:42:54 | Episode: 11 | Rewards:
# 	Reward: [ 441.  315. -578.] | Avg Reward: 100.0 | Loss: 1.7914 | ε: 0.942 | LR: 2.38e-05
# 	Metrics - ['frags: 0', 'hits: 55', 'damage_taken: -3', 'movement: 64', 'ammo_efficiency: 39', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1134, 1: 1118, 2: 693, 3: 1040, 4: 851, 5: 836, 6: 144, 7: 184
# 21:42:54 | Episode: 11 | Running quick evaluation...
# 21:43:22 | Episode: 12 | Steps done: 24000 | Gathering rollout (currently 20000)
# 21:43:41 | Episode: 12 | Training for 50 epochs
# 21:43:43 | Episode: 12 | Updating target network...
# 21:43:43 | Episode: 12 | Rewards:
# 	Reward: [ 613. -525.  426.] | Avg Reward: 106.0 | Loss: 3.5400 | ε: 0.937 | LR: 2.09e-05
# 	Metrics - ['frags: 0', 'hits: 125', 'damage_taken: -8', 'movement: 64', 'ammo_efficiency: 86', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1129, 1: 1148, 2: 706, 3: 995, 4: 807, 5: 872, 6: 169, 7: 174
# 21:43:43 | Episode: 12 | Running quick evaluation...
# 21:44:13 | Episode: 13 | Steps done: 26000 | Gathering rollout (currently 20000)
# 21:44:32 | Episode: 13 | Training for 50 epochs
# 21:44:33 | Episode: 13 | Updating target network...
# 21:44:33 | Episode: 13 | Rewards:
# 	Reward: [ 569. -613.  404.] | Avg Reward: 107.0 | Loss: 4.8482 | ε: 0.932 | LR: 1.82e-05
# 	Metrics - ['frags: 0', 'hits: 95', 'damage_taken: -6', 'movement: 61', 'ammo_efficiency: 66', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1126, 1: 1127, 2: 705, 3: 1035, 4: 854, 5: 834, 6: 167, 7: 152
# 21:44:33 | Episode: 13 | Running quick evaluation...
# 21:45:03 | Episode: 14 | Steps done: 28000 | Gathering rollout (currently 20000)
# 21:45:22 | Episode: 14 | Training for 50 epochs
# 21:45:24 | Episode: 14 | Updating target network...
# 21:45:24 | Episode: 14 | Rewards:
# 	Reward: [ 285. -571.  318.] | Avg Reward: 100.0 | Loss: 2.5522 | ε: 0.928 | LR: 1.59e-05
# 	Metrics - ['frags: 0', 'hits: 30', 'damage_taken: -2', 'movement: 56', 'ammo_efficiency: 22', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1176, 1: 1127, 2: 643, 3: 1060, 4: 845, 5: 819, 6: 177, 7: 153
# 21:45:24 | Episode: 14 | Running quick evaluation...
# 21:45:52 | Episode: 15 | Steps done: 30000 | Gathering rollout (currently 20000)
# 21:46:12 | Episode: 15 | Training for 50 epochs
# 21:46:14 | Episode: 15 | Updating target network...
# 21:46:14 | Episode: 15 | Rewards:
# 	Reward: [ 405.  255. -528.] | Avg Reward: 97.0 | Loss: 1.6616 | ε: 0.923 | LR: 1.38e-05
# 	Metrics - ['frags: 0', 'hits: 50', 'damage_taken: -3', 'movement: 57', 'ammo_efficiency: 36', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1147, 1: 1106, 2: 685, 3: 1103, 4: 852, 5: 787, 6: 159, 7: 161
# 21:46:14 | Episode: 15 | Running quick evaluation...
# 21:46:43 | Episode: 16 | Steps done: 32000 | Gathering rollout (currently 20000)
# 21:47:02 | Episode: 16 | Training for 50 epochs
# 21:47:04 | Episode: 16 | Updating target network...
# 21:47:04 | Episode: 16 | Rewards:
# 	Reward: [ 262.  277. -622.] | Avg Reward: 89.0 | Loss: 1.7388 | ε: 0.918 | LR: 1.22e-05
# 	Metrics - ['frags: 0', 'hits: 5', 'damage_taken: 0', 'movement: 57', 'ammo_efficiency: 6', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1104, 1: 1072, 2: 661, 3: 1152, 4: 842, 5: 821, 6: 190, 7: 158
# 21:47:04 | Episode: 16 | Running quick evaluation...
# 21:47:33 | Episode: 17 | Steps done: 34000 | Gathering rollout (currently 20000)
# 21:47:53 | Episode: 17 | Training for 50 epochs
# 21:47:54 | Episode: 17 | Updating target network...
# 21:47:54 | Episode: 17 | Rewards:
# 	Reward: [ 379.  428. -605.] | Avg Reward: 88.0 | Loss: 2.7751 | ε: 0.914 | LR: 1.10e-05
# 	Metrics - ['frags: 0', 'hits: 65', 'damage_taken: -4', 'movement: 56', 'ammo_efficiency: 46', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1113, 1: 1096, 2: 647, 3: 1178, 4: 819, 5: 785, 6: 175, 7: 187
# 21:47:54 | Episode: 17 | Running quick evaluation...
# 21:48:24 | Episode: 18 | Steps done: 36000 | Gathering rollout (currently 20000)
# 21:48:43 | Episode: 18 | Training for 50 epochs
# 21:48:45 | Episode: 18 | Updating target network...
# 21:48:45 | Episode: 18 | Rewards:
# 	Reward: [ 271.  312. -594.] | Avg Reward: 83.0 | Loss: 0.4571 | ε: 0.909 | LR: 1.02e-05
# 	Metrics - ['frags: 0', 'hits: 15', 'damage_taken: -1', 'movement: 65', 'ammo_efficiency: 12', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1054, 1: 1099, 2: 671, 3: 1197, 4: 818, 5: 804, 6: 164, 7: 193
# 21:48:45 | Episode: 18 | Running quick evaluation...
# 21:49:17 | Episode: 19 | Steps done: 38000 | Gathering rollout (currently 20000)
# 21:49:43 | Episode: 19 | Training for 50 epochs
# 21:49:45 | Episode: 19 | Updating target network...
# 21:49:45 | Episode: 19 | Rewards:
# 	Reward: [ 281. -579.  364.] | Avg Reward: 80.0 | Loss: 1.8759 | ε: 0.905 | LR: 5.00e-05
# 	Metrics - ['frags: 0', 'hits: 40', 'damage_taken: -2', 'movement: 51', 'ammo_efficiency: 29', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1064, 1: 1135, 2: 665, 3: 1201, 4: 806, 5: 781, 6: 184, 7: 164
# 21:49:45 | Episode: 19 | Running quick evaluation...
# 21:50:18 | Episode: 20 | Steps done: 40000 | Gathering rollout (currently 20000)
# 21:50:43 | Episode: 20 | Training for 50 epochs
# 21:50:44 | Episode: 20 | Updating target network...
# 21:50:44 | Episode: 20 | Rewards:
# 	Reward: [ 378.  335. -405.] | Avg Reward: 82.0 | Loss: 2.6846 | ε: 0.900 | LR: 4.98e-05
# 	Metrics - ['frags: 0', 'hits: 85', 'damage_taken: -5', 'movement: 60', 'ammo_efficiency: 59', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1084, 1: 1053, 2: 655, 3: 1307, 4: 783, 5: 793, 6: 175, 7: 150
# 21:51:24 | Episode: 20 | Running quick evaluation...
# 21:51:57 | Episode: 21 | Steps done: 42000 | Gathering rollout (currently 20000)
# 21:52:23 | Episode: 21 | Training for 50 epochs
# 21:52:24 | Episode: 21 | Updating target network...
# 21:52:24 | Episode: 21 | Rewards:
# 	Reward: [ 707.  251. -519.] | Avg Reward: 88.0 | Loss: 1.8316 | ε: 0.896 | LR: 4.90e-05
# 	Metrics - ['frags: 0', 'hits: 115', 'damage_taken: -7', 'movement: 55', 'ammo_efficiency: 79', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1117, 1: 1028, 2: 606, 3: 1275, 4: 843, 5: 803, 6: 173, 7: 155
# 21:52:24 | Episode: 21 | Running quick evaluation...
# 21:52:57 | Episode: 22 | Steps done: 44000 | Gathering rollout (currently 20000)
# 21:53:23 | Episode: 22 | Training for 50 epochs
# 21:53:25 | Episode: 22 | Updating target network...
# 21:53:25 | Episode: 22 | Rewards:
# 	Reward: [ 521. -407.  577.] | Avg Reward: 99.0 | Loss: 4.9788 | ε: 0.891 | LR: 4.78e-05
# 	Metrics - ['frags: 0', 'hits: 165', 'damage_taken: -11', 'movement: 59', 'ammo_efficiency: 112', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1037, 1: 1015, 2: 640, 3: 1304, 4: 854, 5: 830, 6: 151, 7: 169
# 21:53:25 | Episode: 22 | Running quick evaluation...
# 21:53:58 | Episode: 23 | Steps done: 46000 | Gathering rollout (currently 20000)
# 21:54:24 | Episode: 23 | Training for 50 epochs
# 21:54:26 | Episode: 23 | Updating target network...
# 21:54:26 | Episode: 23 | Rewards:
# 	Reward: [ 604. -563.  610.] | Avg Reward: 102.0 | Loss: 8.6588 | ε: 0.887 | LR: 4.62e-05
# 	Metrics - ['frags: 0', 'hits: 155', 'damage_taken: -10', 'movement: 62', 'ammo_efficiency: 106', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1086, 1: 1057, 2: 660, 3: 1244, 4: 791, 5: 825, 6: 165, 7: 172
# 21:54:26 | Episode: 23 | Running quick evaluation...
# 21:55:00 | Episode: 24 | Steps done: 48000 | Gathering rollout (currently 20000)
# 21:55:25 | Episode: 24 | Training for 50 epochs
# 21:55:27 | Episode: 24 | Updating target network...
# 21:55:27 | Episode: 24 | Rewards:
# 	Reward: [ 357.  353. -379.] | Avg Reward: 97.0 | Loss: 1.2855 | ε: 0.882 | LR: 4.41e-05
# 	Metrics - ['frags: 0', 'hits: 90', 'damage_taken: -6', 'movement: 60', 'ammo_efficiency: 62', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 
 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 940, 1: 1002, 2: 595, 3: 1646, 4: 781, 5: 745, 6: 148, 7: 143
# 22:12:21 | Episode: 40 | Running quick evaluation...
# 22:12:54 | Episode: 41 | Steps done: 82000 | Gathering rollout (currently 20000)
# 22:13:20 | Episode: 41 | Training for 50 epochs
# 22:13:22 | Episode: 41 | Updating target network...
# 22:13:22 | Episode: 41 | Rewards:
# 	Reward: [ 379. -483.  343.] | Avg Reward: 82.0 | Loss: 2.5410 | ε: 0.810 | LR: 4.90e-05
# 	Metrics - ['frags: 0', 'hits: 70', 'damage_taken: -4', 'movement: 61', 'ammo_efficiency: 49', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 1032, 1: 919, 2: 616, 3: 1648, 4: 750, 5: 733, 6: 140, 7: 162
# 22:13:22 | Episode: 41 | Running quick evaluation...
# 22:13:55 | Episode: 42 | Steps done: 84000 | Gathering rollout (currently 20000)
# 22:14:22 | Episode: 42 | Training for 50 epochs
# 22:14:24 | Episode: 42 | Updating target network...
# 22:14:24 | Episode: 42 | Rewards:
# 	Reward: [ 472.  636. -448.] | Avg Reward: 81.0 | Loss: 4.5655 | ε: 0.806 | LR: 4.78e-05
# 	Metrics - ['frags: 0', 'hits: 160', 'damage_taken: -10', 'movement: 57', 'ammo_efficiency: 109', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 953, 1: 981, 2: 573, 3: 1756, 4: 718, 5: 732, 6: 155, 7: 132
# 22:14:24 | Episode: 42 | Running quick evaluation...
# 22:14:57 | Episode: 43 | Steps done: 86000 | Gathering rollout (currently 20000)
# 22:15:24 | Episode: 43 | Training for 50 epochs
# 22:15:25 | Episode: 43 | Updating target network...
# 22:15:25 | Episode: 43 | Rewards:
# 	Reward: [ 258. -408.  461.] | Avg Reward: 76.0 | Loss: 2.6082 | ε: 0.802 | LR: 4.62e-05
# 	Metrics - ['frags: 0', 'hits: 85', 'damage_taken: -5', 'movement: 61', 'ammo_efficiency: 59', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 972, 1: 941, 2: 567, 3: 1725, 4: 739, 5: 759, 6: 166, 7: 131
# 22:15:25 | Episode: 43 | Running quick evaluation...
# 22:15:59 | Episode: 44 | Steps done: 88000 | Gathering rollout (currently 20000)
# 22:16:26 | Episode: 44 | Training for 50 epochs
# 22:16:27 | Episode: 44 | Updating target network...
# 22:16:27 | Episode: 44 | Rewards:
# 	Reward: [ 622.  245. -555.] | Avg Reward: 75.0 | Loss: 2.7508 | ε: 0.798 | LR: 4.41e-05
# 	Metrics - ['frags: 0', 'hits: 90', 'damage_taken: -6', 'movement: 53', 'ammo_efficiency: 62', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 965, 1: 927, 2: 571, 3: 1805, 4: 729, 5: 696, 6: 152, 7: 155
# 22:16:27 | Episode: 44 | Running quick evaluation...
# 22:17:01 | Episode: 45 | Steps done: 90000 | Gathering rollout (currently 20000)
# 22:17:27 | Episode: 45 | Training for 50 epochs
# 22:17:29 | Episode: 45 | Updating target network...
# 22:17:29 | Episode: 45 | Rewards:
# 	Reward: [ 401.  423. -537.] | Avg Reward: 79.0 | Loss: 3.5684 | ε: 0.794 | LR: 4.18e-05
# 	Metrics - ['frags: 0', 'hits: 80', 'damage_taken: -5', 'movement: 61', 'ammo_efficiency: 56', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0:
 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 925, 1: 958, 2: 536, 3: 1947, 4: 667, 5: 665, 6: 142, 7: 160
# 22:22:38 | Episode: 50 | Running quick evaluation...
# 22:23:11 | Episode: 51 | Steps done: 102000 | Gathering rollout (currently 20000)
# 22:23:39 | Episode: 51 | Training for 50 epochs
# 22:23:41 | Episode: 51 | Updating target network...
# 22:23:41 | Episode: 51 | Rewards:
# 	Reward: [ 310. -611.  275.] | Avg Reward: 67.0 | Loss: 0.5662 | ε: 0.771 | LR: 2.38e-05
# 	Metrics - ['frags: 0', 'hits: 20', 'damage_taken: -1', 'movement: 53', 'ammo_efficiency: 16', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 936, 1: 922, 2: 568, 3: 1932, 4: 679, 5: 679, 6: 158, 7: 126
# 22:23:41 | Episode: 51 | Running quick evaluation...
# 22:24:14 | Episode: 52 | Steps done: 104000 | Gathering rollout (currently 20000)
# 22:24:41 | Episode: 52 | Training for 50 epochs
# 22:24:43 | Episode: 52 | Updating target network...
# 22:24:43 | Episode: 52 | Rewards:
# 	Reward: [ 277. -631.  357.] | Avg Reward: 58.0 | Loss: 1.7281 | ε: 0.767 | LR: 2.09e-05
# 	Metrics - ['frags: 0', 'hits: 25', 'damage_taken: -1', 'movement: 54', 'ammo_efficiency: 19', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 922, 1: 868, 2: 553, 3: 2030, 4: 667, 5: 682, 6: 133, 7: 145
# 22:24:43 | Episode: 52 | Running quick evaluation...
# 22:25:16 | Episode: 53 | Steps done: 106000 | Gathering rollout (currently 20000)
# 22:25:43 | Episode: 53 | Training for 50 epochs
# 22:25:45 | Episode: 53 | Updating target network...
# 22:25:45 | Episode: 53 | Rewards:
# 	Reward: [ 327.  284. -455.] | Avg Reward: 58.0 | Loss: 1.7278 | ε: 0.763 | LR: 1.82e-05
# 	Metrics - ['frags: 0', 'hits: 55', 'damage_taken: -3', 'movement: 57', 'ammo_efficiency: 39', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 912, 1: 940, 2: 491, 3: 2039, 4: 670, 5: 675, 6: 139, 7: 134
# 22:25:45 | Episode: 53 | Running quick evaluation...
# 22:26:18 | Episode: 54 | Steps done: 108000 | Gathering rollout (currently 20000)
# 22:26:45 | Episode: 54 | Training for 50 epochs
# 22:26:47 | Episode: 54 | Updating target network...
# 22:26:47 | Episode: 54 | Rewards:
# 	Reward: [ 323. -598.  480.] | Avg Reward: 58.0 | Loss: 1.6866 | ε: 0.759 | LR: 1.59e-05
# 	Metrics - ['frags: 0', 'hits: 65', 'damage_taken: -4', 'movement: 57', 'ammo_efficiency: 46', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 945, 1: 911, 2: 578, 3: 1972, 4: 674, 5: 665, 6: 129, 7: 126
# 22:26:47 | Episode: 54 | Running quick evaluation...
# 22:27:20 | Episode: 55 | Steps done: 110000 | Gathering rollout (currently 20000)
# 22:27:47 | Episode: 55 | Training for 50 epochs
# 22:27:49 | Episode: 55 | Updating target network...
# 22:27:49 | Episode: 55 | Rewards:
# 	Reward: [ 316. -337.  281.] | Avg Reward: 63.0 | Loss: 2.8381 | ε: 0.755 | LR: 1.38e-05
# 	Metrics - ['frags: 0', 'hits: 80', 'damage_taken: -5', 'movement: 51', 'ammo_efficiency: 56', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 924, 1: 928, 2: 584, 3: 1955, 4: 680, 5: 670, 6: 130, 7: 129
# 22:27:49 | Episode: 55 | Running quick evaluation...
# 22:28:22 | Episode: 56 | Steps done: 112000 | Gathering rollout (currently 20000)
# 22:28:50 | Episode: 56 | Training for 50 epochs
# 22:28:51 | Episode: 56 | Updating target network...
# 22:28:51 | Episode: 56 | Rewards:
# 	Reward: [ 374. -589.  428.] | Avg Reward: 63.0 | Loss: 2.8117 | ε: 0.751 | LR: 1.22e-05
# 	Metrics - ['frags: 0', 'hits: 75', 'damage_taken: -5', 'movement: 44', 'ammo_efficiency: 52', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 870, 1: 879, 2: 567, 3: 2091, 4: 678, 5: 655, 6: 124, 7: 136
# 22:28:51 | Episode: 56 | Running quick evaluation...
# 22:29:24 | Episode: 57 | Steps done: 114000 | Gathering rollout (currently 20000)
# 22:29:52 | Episode: 57 | Training for 50 epochs
# 22:29:53 | Episode: 57 | Updating target network...
# 22:29:53 | Episode: 57 | Rewards:
# 	Reward: [ 334. -461.  313.] | Avg Reward: 65.0 | Loss: 2.6167 | ε: 0.748 | LR: 1.10e-05
# 	Metrics - ['frags: 0', 'hits: 60', 'damage_taken: -4', 'movement: 59', 'ammo_efficiency: 42', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 918, 1: 840, 2: 548, 3: 2088, 4: 650, 5: 704, 6: 122, 7: 130
# 22:29:53 | Episode: 57 | Running quick evaluation...
# 22:30:26 | Episode: 58 | Steps done: 116000 | Gathering rollout (currently 20000)
# 22:30:54 | Episode: 58 | Training for 50 epochs
# 22:30:56 | Episode: 58 | Updating target network...
# 22:30:56 | Episode: 58 | Rewards:
# 	Reward: [ 278. -589.  257.] | Avg Reward: 62.0 | Loss: 2.5176 | ε: 0.744 | LR: 1.02e-05
# 	Metrics - ['frags: 0', 'hits: 15', 'damage_taken: -1', 'movement: 51', 'ammo_efficiency: 12', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 898, 1: 936, 2: 527, 3: 2097, 4: 607, 5: 657, 6: 142, 7: 136
# 22:30:56 | Episode: 58 | Running quick evaluation...
# 22:31:29 | Episode: 59 | Steps done: 118000 | Gathering rollout (currently 20000)
# 22:31:56 | Episode: 59 | Training for 50 epochs
# 22:31:58 | Episode: 59 | Updating target network...
# 22:31:58 | Episode: 59 | Rewards:
# 	Reward: [ 338. -469.  357.] | Avg Reward: 65.0 | Loss: 0.7274 | ε: 0.740 | LR: 5.00e-05
# 	Metrics - ['frags: 0', 'hits: 75', 'damage_taken: -5', 'movement: 49', 'ammo_efficiency: 52', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 909, 1: 902, 2: 503, 3: 2135, 4: 661, 5: 617, 6: 127, 7: 146
# 22:31:58 | Episode: 59 | Running quick evaluation...
# 22:32:32 | Episode: 60 | Steps done: 120000 | Gathering rollout (currently 20000)
# 22:32:59 | Episode: 60 | Training for 50 epochs
# 22:33:01 | Episode: 60 | Updating target network...
# 22:33:01 | Episode: 60 | Rewards:
# 	Reward: [ 374.  255. -631.] | Avg Reward: 62.0 | Loss: 1.5978 | ε: 0.737 | LR: 4.98e-05
# 	Metrics - ['frags: 0', 'hits: 30', 'damage_taken: -2', 'movement: 45', 'ammo_efficiency: 22', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 882, 1: 861, 2: 500, 3: 2165, 4: 630, 5: 686, 6: 138, 7: 138
# 22:33:41 | Episode: 60 | Running quick evaluation...
# 22:34:14 | Episode: 61 | Steps done: 122000 | Gathering rollout (currently 20000)
# 22:34:41 | Episode: 61 | Training for 50 epochs
# 22:34:43 | Episode: 61 | Updating target network...
# 22:34:43 | Episode: 61 | Rewards:
# 	Reward: [ 300.  309. -590.] | Avg Reward: 58.0 | Loss: 3.0016 | ε: 0.733 | LR: 4.90e-05
# 	Metrics - ['frags: 0', 'hits: 30', 'damage_taken: -2', 'movement: 51', 'ammo_efficiency: 22', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 869, 1: 899, 2: 540, 3: 2184, 4: 619, 5: 654, 6: 104, 7: 131
# 22:34:43 | Episode: 61 | Running quick evaluation...
# 22:35:16 | Episode: 62 | Steps done: 124000 | Gathering rollout (currently 20000)
# 22:35:44 | Episode: 62 | Training for 50 epochs
# 22:35:46 | Episode: 62 | Updating target network...
# 22:35:46 | Episode: 62 | Rewards:
# 	Reward: [ 325.  315. -559.] | Avg Reward: 48.0 | Loss: 2.5898 | ε: 0.729 | LR: 4.78e-05
# 	Metrics - ['frags: 0', 'hits: 40', 'damage_taken: -2', 'movement: 56', 'ammo_efficiency: 29', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 837, 1: 883, 2: 557, 3: 2121, 4: 641, 5: 669, 6: 134, 7: 158
# 22:35:46 | Episode: 62 | Running quick evaluation...
# 22:36:19 | Episode: 63 | Steps done: 126000 | Gathering rollout (currently 20000)
# 22:36:46 | Episode: 63 | Training for 50 epochs
# 22:36:48 | Episode: 63 | Updating target network...
# 22:36:48 | Episode: 63 | Rewards:
# 	Reward: [ 264.  285. -601.] | Avg Reward: 42.0 | Loss: 1.7221 | ε: 0.726 | LR: 4.62e-05
# 	Metrics - ['frags: 0', 'hits: 10', 'damage_taken: 0', 'movement: 60', 'ammo_efficiency: 9', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 921, 1: 871, 2: 524, 3: 2146, 4: 634, 5: 646, 6: 120, 7: 138
# 22:36:48 | Episode: 63 | Running quick evaluation...
# 22:37:21 | Episode: 64 | Steps done: 128000 | Gathering rollout (currently 20000)
# 22:37:49 | Episode: 64 | Training for 50 epochs
# 22:37:51 | Episode: 64 | Updating target network...
# 22:37:51 | Episode: 64 | Rewards:
# 	Reward: [ 294. -485.  344.] | Avg Reward: 40.0 | Loss: 1.8748 | ε: 0.722 | LR: 4.41e-05
# 	Metrics - ['frags: 0', 'hits: 55', 'damage_taken: -3', 'movement: 56', 'ammo_efficiency: 39', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 875, 1: 846, 2: 513, 3: 2128, 4: 670, 5: 696, 6: 134, 7: 138
# 22:37:51 | Episode: 64 | Running quick evaluation...
# 22:38:24 | Episode: 65 | Steps done: 130000 | Gathering rollout (currently 20000)
# 22:38:52 | Episode: 65 | Training for 50 epochs
# 22:38:53 | Episode: 65 | Updating target network...
# 22:38:53 | Episode: 65 | Rewards:
# 	Reward: [ 270.  387. -614.] | Avg Reward: 36.0 | Loss: 1.4420 | ε: 0.718 | LR: 4.18e-05
# 	Metrics - ['frags: 0', 'hits: 35', 'damage_taken: -2', 'movement: 51', 'ammo_efficiency: 26', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 846, 1: 886, 2: 515, 3: 2195, 4: 652, 5: 649, 6: 137, 7: 120
# 22:38:53 | Episode: 65 | Running quick evaluation...
# Successfully stored the model: runs/20250620_213247/best_model_20250620_223925.pt
# 22:39:27 | Episode: 66 | Steps done: 132000 | Gathering rollout (currently 20000)
# 22:39:54 | Episode: 66 | Training for 50 epochs
# 22:39:56 | Episode: 66 | Updating target network...
# 22:39:56 | Episode: 66 | Rewards:
# 	Reward: [ 257.  337. -608.] | Avg Reward: 30.0 | Loss: 2.7620 | ε: 0.715 | LR: 3.91e-05
# 	Metrics - ['frags: 0', 'hits: 20', 'damage_taken: -1', 'movement: 56', 'ammo_efficiency: 16', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0:
 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 865, 1: 862, 2: 486, 3: 2236, 4: 666, 5: 625, 6: 123, 7: 137
# 22:45:09 | Episode: 71 | Running quick evaluation...
# 22:45:42 | Episode: 72 | Steps done: 144000 | Gathering rollout (currently 20000)
# 22:46:10 | Episode: 72 | Training for 50 epochs
# 22:46:12 | Episode: 72 | Updating target network...
# 22:46:12 | Episode: 72 | Rewards:
# 	Reward: [ 246.  333. -611.] | Avg Reward: 26.0 | Loss: 0.8960 | ε: 0.694 | LR: 2.09e-05
# 	Metrics - ['frags: 0', 'hits: 20', 'damage_taken: -1', 'movement: 50', 'ammo_efficiency: 16', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 791, 1: 837, 2: 497, 3: 2391, 4: 607, 5: 614, 6: 130, 7: 133
# 22:46:12 | Episode: 72 | Running quick evaluation...
# 22:46:45 | Episode: 73 | Steps done: 146000 | Gathering rollout (currently 20000)
# 22:47:13 | Episode: 73 | Training for 50 epochs
# 22:47:14 | Episode: 73 | Updating target network...
# 22:47:14 | Episode: 73 | Rewards:
# 	Reward: [ 289. -609.  402.] | Avg Reward: 25.0 | Loss: 2.6802 | ε: 0.690 | LR: 1.82e-05
# 	Metrics - ['frags: 0', 'hits: 45', 'damage_taken: -3', 'movement: 48', 'ammo_efficiency: 32', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 809, 1: 829, 2: 481, 3: 2387, 4: 621, 5: 620, 6: 138, 7: 115
# 22:47:14 | Episode: 73 | Running quick evaluation...
# 22:47:47 | Episode: 74 | Steps done: 148000 | Gathering rollout (currently 20000)
# 22:48:15 | Episode: 74 | Training for 50 epochs
# 22:48:17 | Episode: 74 | Updating target network...
# 22:48:17 | Episode: 74 | Rewards:
# 	Reward: [ 357. -463.  255.] | Avg Reward: 24.0 | Loss: 1.5694 | ε: 0.687 | LR: 1.59e-05
# 	Metrics - ['frags: 0', 'hits: 55', 'damage_taken: -3', 'movement: 55', 'ammo_efficiency: 39', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 783, 1: 826, 2: 475, 3: 2438, 4: 616, 5: 640, 6: 102, 7: 120
# 22:48:17 | Episode: 74 | Running quick evaluation...
# 22:48:51 | Episode: 75 | Steps done: 150000 | Gathering rollout (currently 20000)
# 22:49:15 | Episode: 75 | Training for 50 epochs
# 22:49:16 | Episode: 75 | Updating target network...
# 22:49:16 | Episode: 75 | Rewards:
# 	Reward: [ 263. -388.  310.] | Avg Reward: 23.0 | Loss: 0.9105 | ε: 0.683 | LR: 1.38e-05
# 	Metrics - ['frags: 0', 'hits: 65', 'damage_taken: -4', 'movement: 51', 'ammo_efficiency: 46', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 804, 1: 879, 2: 485, 3: 2313, 4: 585, 5: 667, 6: 140, 7: 127
# 22:49:16 | Episode: 75 | Running quick evaluation...
# 22:49:46 | Episode: 76 | Steps done: 152000 | Gathering rollout (currently 20000)
# 22:50:08 | Episode: 76 | Training for 50 epochs
# 22:50:10 | Episode: 76 | Updating target network...
# 22:50:10 | Episode: 76 | Rewards:
# 	Reward: [ 267. -632.  353.] | Avg Reward: 19.0 | Loss: 0.8020 | ε: 0.680 | LR: 1.22e-05
# 	Metrics - ['frags: 0', 'hits: 25', 'damage_taken: -1', 'movement: 49', 'ammo_efficiency: 19', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0:
 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 791, 1: 773, 2: 455, 3: 2572, 4: 587, 5: 563, 6: 127, 7: 132
# 23:00:34 | Episode: 87 | Running quick evaluation...
# 23:01:04 | Episode: 88 | Steps done: 176000 | Gathering rollout (currently 20000)
# 23:01:27 | Episode: 88 | Training for 50 epochs
# 23:01:28 | Episode: 88 | Updating target network...
# 23:01:28 | Episode: 88 | Rewards:
# 	Reward: [ 386.  283. -499.] | Avg Reward: 31.0 | Loss: 2.6751 | ε: 0.640 | LR: 3.31e-05
# 	Metrics - ['frags: 0', 'hits: 65', 'damage_taken: -4', 'movement: 46', 'ammo_efficiency: 46', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 760, 1: 789, 2: 438, 3: 2653, 4: 595, 5: 541, 6: 104, 7: 120
# 23:01:28 | Episode: 88 | Running quick evaluation...
# 23:01:57 | Episode: 89 | Steps done: 178000 | Gathering rollout (currently 20000)
# 23:02:20 | Episode: 89 | Training for 50 epochs
# 23:02:21 | Episode: 89 | Updating target network...
# 23:02:21 | Episode: 89 | Rewards:
# 	Reward: [ 297. -592.  308.] | Avg Reward: 32.0 | Loss: 1.5545 | ε: 0.637 | LR: 3.00e-05
# 	Metrics - ['frags: 0', 'hits: 30', 'damage_taken: -2', 'movement: 49', 'ammo_efficiency: 22', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 705, 1: 759, 2: 432, 3: 2737, 4: 587, 5: 538, 6: 113, 7: 129
# 23:02:21 | Episode: 89 | Running quick evaluation...
# 23:02:51 | Episode: 90 | Steps done: 180000 | Gathering rollout (currently 20000)
# 23:03:14 | Episode: 90 | Training for 50 epochs
# 23:03:16 | Episode: 90 | Updating target network...
# 23:03:16 | Episode: 90 | Rewards:
# 	Reward: [ 268. -550.  279.] | Avg Reward: 30.0 | Loss: 2.6044 | ε: 0.634 | LR: 2.69e-05
# 	Metrics - ['frags: 0', 'hits: 25', 'damage_taken: -1', 'movement: 52', 'ammo_efficiency: 19', 'survival: -98', 'health_pickup: 1']
# 	Actions - 0: 746, 1: 779, 2: 491, 3: 2644, 4: 560, 5: 553, 6: 115, 7: 112
# 23:03:16 | Episode: 90 | Running quick evaluation...

# %% [markdown]
# ## Dump to ONNX

# %%
import onnx
import json

def onnx_dump(env, model, config, filename: str):
    # dummy state
    init_state = env.reset()[0].unsqueeze(0)

    # Export to ONNX
    torch.onnx.export(
        model.cpu(),
        args=init_state,
        f=filename,
        export_params=True,
        opset_version=11,
        do_constant_folding=True,
        input_names=["input"],
        output_names=["output"],
        dynamic_axes={"input": {0: "batch_size"}, "output": {0: "batch_size"}},
    )
    onnx_model = onnx.load(filename)

    meta = onnx_model.metadata_props.add()
    meta.key = "config"
    meta.value = json.dumps(config)

    onnx.save(onnx_model, filename)

def onnx_export_multi_buffer(env, model, config, filename: str):
    """Export multi-buffer model to ONNX format"""
    model.eval()
    
    # Create dummy inputs for all buffers
    dummy_screen = torch.randn(1, input_channels["screen"], 128, 128)
    dummy_inputs = {"screen": dummy_screen}
    
    if "depth" in input_channels:
        dummy_inputs["depth"] = torch.randn(1, input_channels["depth"], 128, 128)
    if "labels" in input_channels:
        dummy_inputs["labels"] = torch.randn(1, input_channels["labels"], 128, 128)
    if "automap" in input_channels:
        dummy_inputs["automap"] = torch.randn(1, input_channels["automap"], 128, 128)
    
    # For ONNX export, we need to handle the dictionary input differently
    # This is a simplified version - you might need to modify based on your exact requirements
    print("Note: Multi-buffer ONNX export may require custom handling.")
    print("Exporting with screen buffer only for compatibility.")
    
    # Simple export with screen buffer
    torch.onnx.export(
        model.screen_encoder.cpu(),  # Export just the screen encoder for compatibility
        dummy_screen,
        filename,
        export_params=True,
        opset_version=11,
        do_constant_folding=True,
        input_names=["screen"],
        output_names=["features"],
        dynamic_axes={"screen": {0: "batch_size"}, "features": {0: "batch_size"}},
    )
    
    # Add metadata
    onnx_model = onnx.load(filename)
    meta = onnx_model.metadata_props.add()
    meta.key = "config"
    meta.value = json.dumps(config)
    onnx.save(onnx_model, filename)
    
# ---------------------  SAVE / EXPORT ---------------------------------------
final_model = best_model if best_model is not None else model  # choose best

onnx_filename = os.path.join(training_folder, "enhanced_doom_agent.onnx")
onnx_export_multi_buffer(env, final_model, PLAYER_CONFIG, onnx_filename)
print(f"Best network exported to {onnx_filename}")
# Out:
# Note: Multi-buffer ONNX export may require custom handling.
# Exporting with screen buffer only for compatibility.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 72
#      69 final_model = best_model if best_model is not None else model  # choose best
#      71 onnx_filename = os.path.join(training_folder, "enhanced_doom_agent.onnx")
# ---> 72 onnx_export_multi_buffer(env, final_model, PLAYER_CONFIG, onnx_filename)
#      73 print(f"Best network exported to {onnx_filename}")
#
# Cell In[36], line 49, in onnx_export_multi_buffer(env, model, config, filename)
#      46 print("Exporting with screen buffer only for compatibility.")
#      48 # Simple export with screen buffer
# ---> 49 torch.onnx.export(
#      50     model.cpu(),#screen_encoder.cpu(),  # Export just the screen encoder for compatibility
#      51     dummy_screen,
#      52     filename,
#      53     export_params=True,
#      54     opset_version=11,
#      55     do_constant_folding=True,
#      56     input_names=["screen"],
#      57     output_names=["features"],
#      58     dynamic_axes={"screen": {0: "batch_size"}, "features": {0: "batch_size"}},
#      59 )
#      61 # Add metadata
#      62 onnx_model = onnx.load(filename)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/onnx/__init__.py:375, in export(model, args, f, kwargs, export_params, verbose, input_names, output_names, opset_version, dynamic_axes, keep_initializers_as_inputs, dynamo, external_data, dynamic_shapes, report, verify, profile, dump_exported_program, artifacts_dir, fallback, training, operator_export_type, do_constant_folding, custom_opsets, export_modules_as_functions, autograd_inlining, **_)
#     369 if dynamic_shapes:
#     370     raise ValueError(
#     371         "The exporter only supports dynamic shapes "
#     372         "through parameter dynamic_axes when dynamo=False."
#     373     )
# --> 375 export(
#     376     model,
#     377     args,
#     378     f,  # type: ignore[arg-type]
#     379     kwargs=kwargs,
#     380     export_params=export_params,
#     381     verbose=verbose is True,
#     382     input_names=input_names,
#     383     output_names=output_names,
#     384     opset_version=opset_version,
#     385     dynamic_axes=dynamic_axes,
#     386     keep_initializers_as_inputs=keep_initializers_as_inputs,
#     387     training=training,
#     388     operator_export_type=operator_export_type,
#     389     do_constant_folding=do_constant_folding,
#     390     custom_opsets=custom_opsets,
#     391     export_modules_as_functions=export_modules_as_functions,
#     392     autograd_inlining=autograd_inlining,
#     393 )
#     394 return None
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/onnx/utils.py:502, in export(model, args, f, kwargs, export_params, verbose, training, input_names, output_names, operator_export_type, opset_version, do_constant_folding, dynamic_axes, keep_initializers_as_inputs, custom_opsets, export_modules_as_functions, autograd_inlining)
#     499 if kwargs is not None:
#     500     args = args + (kwargs,)
# --> 502 _export(
#     503     model,
#     504     args,
#     505     f,
#     506     export_params,
#     507     verbose,
#     508     training,
#     509     input_names,
#     510     output_names,
#     511     operator_export_type=operator_export_type,
#     512     opset_version=opset_version,
#     513     do_constant_folding=do_constant_folding,
#     514     dynamic_axes=dynamic_axes,
#     515     keep_initializers_as_inputs=keep_initializers_as_inputs,
#     516     custom_opsets=custom_opsets,
#     517     export_modules_as_functions=export_modules_as_functions,
#     518     autograd_inlining=autograd_inlining,
#     519 )
#     521 return None
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/onnx/utils.py:1564, in _export(model, args, f, export_params, verbose, training, input_names, output_names, operator_export_type, export_type, opset_version, do_constant_folding, dynamic_axes, keep_initializers_as_inputs, fixed_batch_size, custom_opsets, add_node_names, onnx_shape_inference, export_modules_as_functions, autograd_inlining)
#    1561     dynamic_axes = {}
#    1562 _validate_dynamic_axes(dynamic_axes, model, input_names, output_names)
# -> 1564 graph, params_dict, torch_out = _model_to_graph(
#    1565     model,
#    1566     args,
#    1567     verbose,
#    1568     input_names,
#    1569     output_names,
#    1570     operator_export_type,
#    1571     val_do_constant_folding,
#    1572     fixed_batch_size=fixed_batch_size,
#    1573     training=training,
#    1574     dynamic_axes=dynamic_axes,
#    1575 )
#    1577 # TODO: Don't allocate a in-memory string for the protobuf
#    1578 defer_weight_export = (
#    1579     export_type is not _exporter_states.ExportTypes.PROTOBUF_FILE
#    1580 )
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/onnx/utils.py:1113, in _model_to_graph(model, args, verbose, input_names, output_names, operator_export_type, do_constant_folding, _disable_torch_constant_prop, fixed_batch_size, training, dynamic_axes)
#    1110     args = (args,)
#    1112 model = _pre_trace_quant_model(model, args)
# -> 1113 graph, params, torch_out, module = _create_jit_graph(model, args)
#    1114 params_dict = _get_named_param_dict(graph, params)
#    1116 try:
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/onnx/utils.py:997, in _create_jit_graph(model, args)
#     992     graph = _C._propagate_and_assign_input_shapes(
#     993         graph, flattened_args, param_count_list, False, False
#     994     )
#     995     return graph, params, torch_out, None
# --> 997 graph, torch_out = _trace_and_get_graph_from_model(model, args)
#     998 _C._jit_pass_onnx_lint(graph)
#     999 state_dict = torch.jit._unique_state_dict(model)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/onnx/utils.py:904, in _trace_and_get_graph_from_model(model, args)
#     902 prev_autocast_cache_enabled = torch.is_autocast_cache_enabled()
#     903 torch.set_autocast_cache_enabled(False)
# --> 904 trace_graph, torch_out, inputs_states = torch.jit._get_trace_graph(
#     905     model,
#     906     args,
#     907     strict=False,
#     908     _force_outplace=False,
#     909     _return_inputs_states=True,
#     910 )
#     911 torch.set_autocast_cache_enabled(prev_autocast_cache_enabled)
#     913 warn_on_static_input_change(inputs_states)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/jit/_trace.py:1500, in _get_trace_graph(f, args, kwargs, strict, _force_outplace, return_inputs, _return_inputs_states)
#    1498 if not isinstance(args, tuple):
#    1499     args = (args,)
# -> 1500 outs = ONNXTracedModule(
#    1501     f, strict, _force_outplace, return_inputs, _return_inputs_states
#    1502 )(*args, **kwargs)
#    1503 return outs
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/jit/_trace.py:139, in ONNXTracedModule.forward(self, *args)
#     136     else:
#     137         return tuple(out_vars)
# --> 139 graph, out = torch._C._create_graph_by_tracing(
#     140     wrapper,
#     141     in_vars + module_state,
#     142     _create_interpreter_name_lookup_fn(),
#     143     self.strict,
#     144     self._force_outplace,
#     145 )
#     147 if self._return_inputs:
#     148     return graph, outs[0], ret_inputs[0]
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/jit/_trace.py:130, in ONNXTracedModule.forward.<locals>.wrapper(*args)
#     128 if self._return_inputs_states:
#     129     inputs_states.append(_unflatten(in_args, in_desc))
# --> 130 outs.append(self.inner(*trace_inputs))
#     131 if self._return_inputs_states:
#     132     inputs_states[0] = (inputs_states[0], trace_inputs)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1726, in Module._slow_forward(self, *input, **kwargs)
#    1724         recording_scopes = False
#    1725 try:
# -> 1726     result = self.forward(*input, **kwargs)
#    1727 finally:
#    1728     if recording_scopes:
#
# File ~/Documents/Studium/JKU/Deep Reinforcement Learning/365.277 UE DRL/Final/jku.wad/agents/dqn.py:202, in forward(self, observations)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1726, in Module._slow_forward(self, *input, **kwargs)
#    1724         recording_scopes = False
#    1725 try:
# -> 1726     result = self.forward(*input, **kwargs)
#    1727 finally:
#    1728     if recording_scopes:
#
# File ~/Documents/Studium/JKU/Deep Reinforcement Learning/365.277 UE DRL/Final/jku.wad/agents/modules.py:15, in Parallel.forward(self, inputs)
#      14 def forward(self, inputs: dict[str, torch.Tensor]):
# ---> 15     return [module(inputs[name]) for name, module in self.model.items()]
#
# IndexError: too many indices for tensor of dimension 4

# %% [markdown]
# ### Evaluation and Visualization
#
# In this final section, you can evaluate your trained agent, inspect its performance visually, and analyze reward components over time.

# %%
plot_training_metrics(get_avg_reward(reward_history, episodes=0), q_loss_list, epsilon_history)

# %%
replay_episode(env, final_model.cpu(), device, EXTRA_STATE_DIMS, DTYPE, store=True)
