# %% [markdown]
# # Deep Reinforcement Learning — Doom Agent (SS2025)
#
# Welcome to the last assignment for the **Deep Reinforcement Learning** course (SS2025). In this notebook, you"ll implement and train a reinforcement learning agent to play **Doom**.
#
# You will:
# - Set up a custom VizDoom environment with shaped rewards
# - Train an agent using an approach of your choice
# - Track reward components across episodes
# - Evaluate the best model
# - Visualize performance with replays and GIFs
# - Export the trained agent to ONNX to submit to the evaluation server

# %%
# Clone repo
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#%cd /content/drive/MyDrive/Colab\ Notebooks

# %%
# Clone repo
#!git clone https://github.com/albortino/doom-drl-challenge.git
#%cd doom-drl-challenge

# Install the dependencies
#!pip install torch numpy matplotlib vizdoom portpicker gym onnx

# %%
from IPython import get_ipython
get_ipython().run_line_magic('load_ext', 'autoreload')
get_ipython().run_line_magic('autoreload', '2')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from datetime import datetime
from collections import deque
from copy import deepcopy
import random
from torch import nn
from doom_arena import VizdoomMPEnv

# %%
from agents.utils import *
from agents.visualizations import *
from agents.helpers import *
from agents.dqn import EfficientDQN, epsilon_greedy, soft_update_target_network

# %%
rng = np.random.default_rng(100)

# %% [markdown]
# ## Configuration
#
# ViZDoom supports multiple visual buffers that can be used as input for training agents. Each buffer provides different information about the game environment, as seen from left to right:
#
#
# Screen
# - The default first-person RGB view seen by the agent.
#
# Labels
# - A semantic map where each pixel is tagged with an object ID (e.g., enemy, item, wall).
#
# Depth
# - A grayscale map showing the distance from the agent to surfaces in the scene.
#
# Automap
# - A top-down schematic view of the map, useful for global navigation tasks.
#
# ![buffers gif](https://vizdoom.farama.org/_images/vizdoom-demo.gif)

# %% [markdown]
# ### Variables

# %%
USE_GRAYSCALE = False  # ← flip to False for RGB

PLAYER_CONFIG = {
    # NOTE: "algo_type" defaults to POLICY in evaluation script!
    "algo_type": "QVALUE",  # OPTIONAL, change to POLICY if using policy-based (eg PPO)
    "n_stack_frames": 1, #4, # 1 # Temporal information
    "extra_state": ["depth"], #["labels"],#, "automap"], #["depth", "labels", "automap"],
    "hud": "none",
    "crosshair": True,
    "screen_format": 8 if USE_GRAYSCALE else 0,
}

# %%
# TODO: environment training paramters
N_STACK_FRAMES = 1 # 4 does not work yet!
NUM_PLAYERS = 4 #3
NUM_EVAL_PLAYERS = 2
NUM_BOTS = 6 #1, #6
EPISODE_TIMEOUT = 1500 # 2000
# TODO: model hyperparams
GAMMA = 0.98
EPISODES = 250 #2 # 500
BATCH_SIZE = 128
REPLAY_BUFFER_SIZE = 25_000
LEARNING_RATE = 1e-5
EPSILON_START = 1.0
EPSILON_END = 0.1
EPSILON_DECAY = 0.998 # 0.987
N_EPOCHS = 20
FRAME_SKIPPING = 0
FRAME_SKIPPING_STOP = 100
DEBUG = True
PRINT_EVERY = 50
VIDEO_DURING_TRAINING = True
EVALUATION_EVERY = 25
CHECKPOINT_EVERY = 10
RESET_ENV_EVERY = 50
DTYPE = torch.float32
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print("Device:", device)
# Out:
# Device: mps

# %%
# Create folder for training
training_id = datetime.now().strftime('%Y%m%d_%H%M%S')
training_folder = os.path.join("runs", training_id)
os.makedirs(training_folder, exist_ok=True)
print("Using folder:", training_folder)

# Define loggers and helpers
logger = Logger(training_folder, also_print=True)
activation_logger = ActivationLogger(training_folder, filename="activations.txt", also_print=False)

obs_states = ExtraStates(PLAYER_CONFIG["extra_state"] + ["screen"], num_frames = N_STACK_FRAMES)
# Out:
# Using folder: runs/20250622_191922

# %% [markdown]
# ### Environment

# %%
reward_fn = YourReward(num_players=NUM_PLAYERS)
def build_env(num_players: int = NUM_PLAYERS, seed: np.ndarray = rng.integers(1, 2000, NUM_PLAYERS)):
    env = VizdoomMPEnv(
        num_players=num_players, # 4 is max
        num_bots=NUM_BOTS,
        bot_skill=1, # Increased difficulty
        doom_map="TRNM",  # ROOM = NOTE simple, small map; other options: TRNM, TRNMBIG
        extra_state=PLAYER_CONFIG["extra_state"],  # see info about states at the beginning of "Environment configuration" above
        episode_timeout=EPISODE_TIMEOUT,
        n_stack_frames=PLAYER_CONFIG["n_stack_frames"],
        crosshair=PLAYER_CONFIG["crosshair"],
        hud=PLAYER_CONFIG["hud"],
        screen_format=PLAYER_CONFIG["screen_format"],
        reward_fn=reward_fn,
        seed = seed,
        ticrate = 35#*3,
    )
    return env

env = build_env()
with suppress_output(): # Reset to get player and game information
    _ = env.reset()
# Out:
# Environment Seed: [1534 1670  249 1193]
# Host 65023
# Player 65023

# %% [markdown]
# ## Agent
#
# Implement **your own agent** in the code cell that follows.
#
# * In `agents/dqn.py` and `agents/ppo.py` you’ll find very small **skeletons**—they compile but are meant only as reference or quick tests.
#   Feel free to open them, borrow ideas, extend them, or ignore them entirely.
# * The notebook does **not** import those files automatically; whatever class you define in the next cell is the one that will be trained.
# * You may keep the DQN interface, switch to PPO, or try something else.
# * Tweak any hyper-parameters (`PLAYER_CONFIG`, ε-schedule, optimiser, etc.) and document what you tried.

# %%
# Get information about actions from the environment
env_actions = EnvActions(env, rng=rng)

# main Q-network
model = EfficientDQN(
    input_dim = 0,
    action_space=env_actions.action_space,
    obs_state_infos=obs_states,
).to(device, dtype=DTYPE)

# Load a model from file
#model = model.load_model("/Users/matsschneider/Documents/Studium/JKU/DRL/UE_DRL/Final/jku.wad/runs/20250622_120122/best_model_20250622_121858_best223_max473.pt").to(device, dtype=DTYPE)
# Out:
# Weights initialized with Kaiming He
# Weights initialized with Kaiming He
# Weights initialized with Kaiming He
# Weights initialized with Kaiming He
# Weights initialized with Kaiming He
# Initialized model with 1349049 parameters!

# %%
# Define training helpers
target_model  = deepcopy(model).to(device, dtype=DTYPE)
optimizer  = torch.optim.AdamW(target_model.parameters(), lr=LEARNING_RATE, weight_decay=5e-4)
scheduler  = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=50, eta_min=1e-8)
loss_fn = nn.MSELoss()
replay_buffer = deque(maxlen=REPLAY_BUFFER_SIZE)

# %% [markdown]
# ## Example of environment
#
# This let's you play and analyze the environment

# %%
# Reset environment
with suppress_output():
    obs_test: list = env.reset()
    
for player in range(len(obs_test)):
    plot_images(obs_test[player], obs_states.get_dims())

# %%
# Iterate for a given number of steps
STEPS = 30

with torch.no_grad():
    for i in range(STEPS):
        actions = env_actions.get_random_action(NUM_PLAYERS) # Random
        #actions = env_actions.get_action_value(1, NUM_PLAYERS) # Get a specific action 
        #actions = epsilon_greedy(env, model, obs_test, 0.5, env_actions, device, DTYPE, debug=True) # 50% random actions by model
        actions = epsilon_greedy(env, model, torch.rand_like(torch.stack(obs_test)), 0, env_actions, device, DTYPE, debug=False) # model fully random
        
        obs_test, reward = env.step(actions)[0:2] # Select next observations and reward

    # Plot the visuals for every player
    for player in range(env.num_players):
        action_print = [actions] if isinstance(actions, int) else actions
        plot_images(obs_test[player], obs_states.get_dims(), **{"title": f"Reward: {reward[player]:.1f} | Action: {env_actions.get_action_name(action_print[player])}"})

# %% [markdown]
# ### Example of Reward

# %%
player_idx = rng.integers(env.num_players)

player_game_vars = env.envs[player_idx].unwrapped._game_vars
player_game_vars_pre = env.envs[player_idx].unwrapped._game_vars_pre
reward = reward_fn(0, player_game_vars, player_game_vars_pre, 0)
print(f"Reward: {np.sum(reward)} | {reward}")
for key, value_now, value_old in zip(player_game_vars, player_game_vars.values(), player_game_vars_pre.values()):   
    print(f"{key+':':<25}{value_now:.0f} | {value_old:.0f}")
# Out:
# Reward: -0.013520792420351882 | (0.0, 0.0, -0.0, 0, 0.0, np.float64(-0.013520792420351882), 0.0)
# HEALTH:                  100 | 100
# AMMO3:                   0 | 0
# FRAGCOUNT:               0 | 0
# ARMOR:                   0 | 0
# HITCOUNT:                0 | 0
# HITS_TAKEN:              0 | 0
# DEAD:                    0 | 0
# DEATHCOUNT:              0 | 0
# DAMAGECOUNT:             0 | 0
# DAMAGE_TAKEN:            0 | 0
# KILLCOUNT:               0 | 0
# SELECTED_WEAPON:         2 | 2
# SELECTED_WEAPON_AMMO:    110 | 110
# POSITION_X:              1088 | 1088
# POSITION_Y:              1230 | 1230

# %% [markdown]
# ## Training loop

# %%
# ---------------------  TRAINING LOOP  ----------------------
training_info_str = (
    f"N_STACK_FRAMES: {N_STACK_FRAMES}, "
    f"NUM_PLAYERS: {NUM_PLAYERS}, "
    f"NUM_BOTS: {NUM_BOTS}, "
    f"EPISODE_TIMEOUT: {EPISODE_TIMEOUT}, "
    f"GAMMA: {GAMMA}, "
    f"EPISODES: {EPISODES}, "
    f"BATCH_SIZE: {BATCH_SIZE}, "
    f"REPLAY_BUFFER_SIZE: {REPLAY_BUFFER_SIZE}, "
    f"LEARNING_RATE: {LEARNING_RATE}, "
    f"EPSILON_START: {EPSILON_START}, "
    f"EPSILON_END: {EPSILON_END}, "
    f"EPSILON_DECAY: {EPSILON_DECAY}, "
    f"N_EPOCHS: {N_EPOCHS}, "
    f"FRAME_SKIPPING: {FRAME_SKIPPING}, "
    f"FRAME_SKIPPING_STOP: {FRAME_SKIPPING_STOP}, "
    f"DEBUG: {DEBUG}, "
    f"PRINT_EVERY: {PRINT_EVERY}, "
    f"VIDEO_DURING_TRAINING: {VIDEO_DURING_TRAINING}, "
    f"EVALUATION_EVERY: {EVALUATION_EVERY}"
)

training_info_str += ', '.join([f"{k}: {v}" for k, v in PLAYER_CONFIG.items()])

logger.log(training_info_str, improve_file_output=True)

# Training settings
q_loss_list, epsilon_history = [], []
reward_history = {player: [] for player in range(env.num_players)}
best_reward = float("-inf")
best_model = None

epsilon = EPSILON_START 
steps_done = 0

with TqdmProgress(total=EPISODES) as progress_bar:
    for episode in progress_bar:
        
        episode_action_counter = ActionCounter()
        progress_bar.set_description(episode)
        
        if episode >= RESET_ENV_EVERY and episode % RESET_ENV_EVERY == 0:
            episode_msg = f"{datetime.now().strftime('%H:%M:%S')} | Episode: {episode} | Creating new environment... "
            logger.log(episode_msg)
            env = build_env()
    
        with suppress_output():
            obs: torch.Tensor = env.reset()
        
        # Episode variables for each player
        episode_metrics = {player: {"frags": 0, "hits": 0, "damage_taken": 0, "movement": 0, "ammo_efficiency": 0, "survival": 0, "health_pickup": 0} for player in range(env.num_players)}
        episode_reward = {player: 0.0 for player in range(env.num_players)}

        dones = [False]
        model.eval()
        
        episode_msg = f"{datetime.now().strftime('%H:%M:%S')} | Episode: {episode} | Steps done: {steps_done} | Gathering rollout (currently {len(replay_buffer)})"
        logger.log(episode_msg)
        
        # ───────── rollout ─────────────────────────────────────────────
        while not all(dones):
            
            # Skip Frames (Testing - I am aware that in the original paper they stacked the images. I want to get many more steps at the beginning)
            act = epsilon_greedy(env, model, obs, epsilon, env_actions, device, DTYPE, episode_action_counter)
            
            max_skip_steps = max(FRAME_SKIPPING * (episode < FRAME_SKIPPING_STOP), 1)
            for skip_steps in range(max_skip_steps):
                if all(dones):
                    break
                next_obs, reward, dones, _ = env.step(act)
                steps_done += 1

            # ----- reward definition ----------------
            for player_idx in range(env.num_players):
                episode_reward[player_idx] += np.sum(reward[player_idx]) # Should be a list with one value
                
                if dones[player_idx]:
                    break
                
                reward_components = reward_fn(None, env.envs[player_idx].unwrapped._game_vars, env.envs[player_idx].unwrapped._game_vars_pre, None)

                if len(reward_components) >= 6:
                    episode_metrics[player_idx]["frags"] += reward_components[0]
                    episode_metrics[player_idx]["hits"] += reward_components[1]
                    episode_metrics[player_idx]["damage_taken"] += reward_components[2]
                    episode_metrics[player_idx]["movement"] += reward_components[3]
                    episode_metrics[player_idx]["ammo_efficiency"] += reward_components[4]
                    episode_metrics[player_idx]["survival"] += reward_components[5]
                    episode_metrics[player_idx]["health_pickup"] += reward_components[6]
            
                # ----- buffer and environment handling ----------------
                if env.num_players == 1:
                    act = [act]
                    
                replay_buffer.append((obs[player_idx], act[player_idx], reward[player_idx], next_obs[player_idx], dones[player_idx]))

            obs = next_obs
            
        [reward_history[player_idx].append(reward) for player_idx, reward in episode_reward.items()] # Append rewards for every player
        epsilon_history.append(epsilon)

        # ───────── learning step (experience replay) ──────────────────
        if len(replay_buffer) >= BATCH_SIZE:

            model.train()
            train_msg = f"{datetime.now().strftime('%H:%M:%S')} | Episode: {episode} | Training for {N_EPOCHS} epochs"
            logger.log(train_msg)
            
            for epoch in range(N_EPOCHS):

                batch = random.sample(replay_buffer, BATCH_SIZE)
                states, actions, rewards, next_states, dones = zip(*batch)

                # Convert to tensors for training
                states = torch.stack(states).to(device, DTYPE)
                next_states = torch.stack(next_states).to(device, DTYPE)
                actions = torch.tensor(actions, device=device)
                rewards = torch.tensor(rewards, device=device, dtype=torch.float32)
                dones = torch.tensor(dones, device=device, dtype=torch.float32)

                current_q = model(states).gather(1, actions.unsqueeze(1)).squeeze(1)
                
                # Target q values
                with torch.no_grad():
                    next_q = target_model(next_states).max(1)[0] #.values
                    target_q = torch.clamp(rewards + GAMMA * next_q * (1 - dones), min=-10, max=10) # clamping to staibilize training
                
                loss = loss_fn(current_q, target_q)

                optimizer.zero_grad()
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                optimizer.step()
                
                q_loss_list.append(loss.item())
            
            # Update scheduler and epsilon
            scheduler.step()
            epsilon = max(EPSILON_END, epsilon * EPSILON_DECAY)
            
            progress_bar.update_step_count()

            # Update target network        
            target_update_msg = f"{datetime.now().strftime('%H:%M:%S')} | Episode: {episode} | Updating target network..."
            logger.log(target_update_msg)
            
            soft_update_target_network(model, target_model, tau=1e-3)
            #hard_update_target_network(target_model, model)
            
        else:
            train_fail_msg = f"{datetime.now().strftime('%H:%M:%S')} | Episode: {episode} | Replay buffer smaller than batchsize {len(replay_buffer)} {BATCH_SIZE}"
            logger.log(train_fail_msg, print_once=True)

        # -------- logging ----------
        avg_reward = get_avg_reward(reward_history, episodes=PRINT_EVERY, round=0)
        avg_loss = np.mean(q_loss_list[-10:]) if q_loss_list else 0
        stacked_episode_reward = np.array([np.round(reward, 0) for reward in episode_reward.values()])
        
        action_counts = episode_action_counter.get_counts()

        # Rewards and losses
        reward_msg = f"{datetime.now().strftime('%H:%M:%S')} | Episode: {episode} | Rewards:\n"
        reward_msg += f"\tReward: {stacked_episode_reward} | Avg Reward: {avg_reward} | Loss: {avg_loss:.4f} | ε: {epsilon:.3f} | LR: {scheduler.get_last_lr()[0]:.2e}"
        reward_msg += f"\n\tMetrics - {[f'{metric}: {value}' for metric, value in get_average_result(episode_metrics).items()]}"
        reward_msg += f"\n\tActions - {', '.join([f'{k}: {v}' for k, v in episode_action_counter.get_name_counts(env_actions).items()])}"

        logger.log(reward_msg, print_once = episode % PRINT_EVERY == 0)
        
        progress_bar.set_postfix({
            "Avg Reward": f"{avg_reward}",
            "Loss": f"{avg_loss:.4f}",
            "Epsilon": f"{epsilon:.2f}"
        })
        
        # ───────── quick evaluation for best-model tracking ───────────
        quick_eval_msg = f"{datetime.now().strftime('%H:%M:%S')} | Episode: {episode} | Running quick evaluation..."
        logger.log(quick_eval_msg)
        
        # Create test env with random seed
        eval_env = build_env(num_players=NUM_EVAL_PLAYERS, seed = rng.integers(2000, size=NUM_EVAL_PLAYERS))
        
        # Reset environment
        with suppress_output():
            eval_obs = eval_env.reset()
        
        # Show the video 
        if VIDEO_DURING_TRAINING and episode % EVALUATION_EVERY == 0:
            replay_msg = f"{datetime.now().strftime('%H:%M:%S')} | Episode: {episode} | Replaying animation..."
            logger.log(replay_msg)
            with suppress_output():
                replay_episode(eval_obs, model, device, DTYPE, path=training_folder, store=True, random_player=False)

        # Make a random number of steps in the environment
        for action in [env_actions.get_random_action(2) for _ in range(rng.integers(30))]:
            eval_obs = eval_env.step(action)[0]

        # Analyze the model tensors at the position
        analyze_model_tensors(activation_logger, episode, eval_obs, model, split_dims=obs_states.get_dims(return_dict=False), print_once=True)

        # Evaluate every EVALUTATION EVERY periods to improve the speed
        if episode > 0 and episode % EVALUATION_EVERY == 0:
            with suppress_output():
                eval_obs = eval_env.reset() # List of obs
                
            eval_episode_rewards = [0.0] * eval_env.num_players
            eval_dones = [False]
            model.eval()
        
            while not all(eval_dones):
                eval_action_list = epsilon_greedy(eval_env, model, eval_obs, 0, env_actions, device, dtype=DTYPE)
                eval_next_obs_list, eval_reward_list, eval_dones, _ = eval_env.step(eval_action_list)
                for i in range(eval_env.num_players):
                    eval_episode_rewards[i] += eval_reward_list[i]
                eval_obs = eval_next_obs_list
            
            mean_eval_reward = np.mean(eval_episode_rewards)
            
            if mean_eval_reward > best_reward:
                best_reward = mean_eval_reward
                model_name = f"best_model_{datetime.now().strftime('%Y%m%d_%H%M%S')}_best{best_reward:.0f}_max{np.max(eval_episode_rewards):.0f}.pt"
                model.save_model(path=training_folder, filename=model_name)
                best_model = deepcopy(model)
        
        if episode > 0 and episode % CHECKPOINT_EVERY == 0 or episode == EPISODES - 1:
            quick_eval_msg = f"{datetime.now().strftime('%H:%M:%S')} | Episode: {episode} | Saving checkpoint..."
            logger.log(quick_eval_msg)
            model_name = f"backup_model_{datetime.now().strftime('%Y%m%d_%H%M%S')}.pt"
            model.save_model(path=os.path.join(training_folder, 'backups'), filename=model_name)
# Out:
# N_STACK_FRAMES: 1, NUM_PLAYERS: 4, NUM_BOTS: 6, EPISODE_TIMEOUT: 1500, GAMMA: 0.98, EPISODES: 250, BATCH_SIZE: 128, REPLAY_BUFFER_SIZE: 25000, LEARNING_RATE: 1e-05, EPSILON_START: 0.8, EPSILON_END: 0.1, EPSILON_DECAY: 0.998, N_EPOCHS: 20, FRAME_SKIPPING: 0, FRAME_SKIPPING_STOP: 100, DEBUG: True, PRINT_EVERY: 50, VIDEO_DURING_TRAINING: True, EVALUATION_EVERY: 25algo_type: QVALUE, n_stack_frames: 1, extra_state: ['depth'], hud: none, crosshair: True, screen_format: 0
# Training:   0%|          | 0/250 [00:00<?, ? episode/s]
# 19:22:06 | Episode: 0 | Steps done: 0 | Gathering rollout (currently 5996)
# 19:22:21 | Episode: 0 | Training for 20 epochs
# 19:22:23 | Episode: 0 | Updating target network...
# 19:22:23 | Episode: 0 | Rewards:
# 	Reward: [ 167. -133.   36.   36.] | Avg Reward: 26.0 | Loss: 7.1213 | ε: 0.798 | LR: 9.96e-06
# 	Metrics - ['frags: 0', 'hits: 91', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 11', 'survival: -76', 'health_pickup: 2']
# 	Actions - Noop: 333, Move Forward: 979, Attack: 745, Move Left: 710, Move Right: 728, Turn Left: 993, Turn Right: 968, Jump: 544
# 19:22:23 | Episode: 0 | Replaying animation...
# 19:23:08 | Episode: 0 | Running quick evaluation...
# Environment Seed: [160 577]
# Host 65164
# Player 65164
# Episode 0 | encoders       | Shape: [2, 768],	Mean: 2.52,	Std: 4.44,	Norm: 200.08
# Episode 0 | head_first     | Shape: [2, 1024],	Mean: 2.92,	Std: 5.34,	Norm: 275.19
# Episode 0 | value_head     | Shape: [2, 1],	Mean: 1.01,	Std: 1.61,	Norm: 2.15
# Episode 0 | advantage_head | Shape: [2, 8],	Mean: -1.08,	Std: 10.50,	Norm: 40.88
#
# 19:23:11 | Episode: 1 | Steps done: 1500 | Gathering rollout (currently 11992)
# 19:23:27 | Episode: 1 | Training for 20 epochs
# 19:23:29 | Episode: 1 | Updating target network...
# 19:23:29 | Episode: 1 | Rewards:
# 	Reward: [ 35.  57. -18. -18.] | Avg Reward: 20.0 | Loss: 6.2972 | ε: 0.797 | LR: 9.91e-06
# 	Metrics - ['frags: 0', 'hits: 30', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 5', 'survival: -21', 'health_pickup: 1']
# 	Actions - Noop: 326, Move Forward: 968, Attack: 758, Move Left: 798, Move Right: 747, Turn Left: 936, Turn Right: 910, Jump: 557
# 19:23:29 | Episode: 1 | Running quick evaluation...
# Environment Seed: [  85 1175]
# Host 65173
# Player 65173
# Episode 1 | encoders       | Shape: [2, 768],	Mean: 2.74,	Std: 4.72,	Norm: 213.99
# Episode 1 | head_first     | Shape: [2, 1024],	Mean: 3.02,	Std: 5.66,	Norm: 290.12
# Episode 1 | value_head     | Shape: [2, 1],	Mean: 5.18,	Std: 2.66,	Norm: 7.79
# Episode 1 | advantage_head | Shape: [2, 8],	Mean: -1.91,	Std: 10.05,	Norm: 39.66
#
# 19:23:32 | Episode: 2 | Steps done: 3000 | Gathering rollout (currently 17988)
# 19:23:47 | Episode: 2 | Training for 20 epochs
# 19:23:48 | Episode: 2 | Updating target network...
# 19:23:48 | Episode: 2 | Rewards:
# 	Reward: [-20. -31.  90.  90.] | Avg Reward: 24.0 | Loss: 6.8475 | ε: 0.795 | LR: 9.84e-06
# 	Metrics - ['frags: 0', 'hits: 58', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 8', 'survival: -36', 'health_pickup: 2']
# 	Actions - Noop: 334, Move Forward: 1000, Attack: 768, Move Left: 726, Move Right: 681, Turn Left: 904, Turn Right: 1050, Jump: 537
# 19:23:48 | Episode: 2 | Running quick evaluation...
# Environment Seed: [1894 1192]
# Host 65181
# Player 65181
# Episode 2 | encoders       | Shape: [2, 768],	Mean: 2.60,	Std: 4.64,	Norm: 208.29
# Episode 2 | head_first     | Shape: [2, 1024],	Mean: 2.81,	Std: 5.33,	Norm: 272.59
# Episode 2 | value_head     | Shape: [2, 1],	Mean: 3.78,	Std: 4.50,	Norm: 6.99
# Episode 2 | advantage_head | Shape: [2, 8],	Mean: -0.87,	Std: 10.52,	Norm: 40.90
#
# 19:23:52 | Episode: 3 | Steps done: 4500 | Gathering rollout (currently 23984)
# 19:24:08 | Episode: 3 | Training for 20 epochs
# 19:24:09 | Episode: 3 | Updating target network...
# 19:24:09 | Episode: 3 | Rewards:
# 	Reward: [ 38. -18.  40.  50.] | Avg Reward: 25.0 | Loss: 5.8697 | ε: 0.794 | LR: 9.76e-06
# 	Metrics - ['frags: 0', 'hits: 40', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 7', 'survival: -20', 'health_pickup: 1']
# 	Actions - Noop: 365, Move Forward: 1014, Attack: 774, Move Left: 780, Move Right: 667, Turn Left: 942, Turn Right: 929, Jump: 529
# 19:24:09 | Episode: 3 | Running quick evaluation...
# Environment Seed: [1580 1849]
# Host 65191
# Player 65191
# Episode 3 | encoders       | Shape: [2, 768],	Mean: 2.51,	Std: 4.66,	Norm: 207.18
# Episode 3 | head_first     | Shape: [2, 1024],	Mean: 2.87,	Std: 5.48,	Norm: 279.76
# Episode 3 | value_head     | Shape: [2, 1],	Mean: -0.40,	Std: 8.82,	Norm: 8.84
# Episode 3 | advantage_head | Shape: [2, 8],	Mean: -2.62,	Std: 9.54,	Norm: 38.39
#
# 19:24:12 | Episode: 4 | Steps done: 6000 | Gathering rollout (currently 25000)
# 19:24:28 | Episode: 4 | Training for 20 epochs
# 19:24:29 | Episode: 4 | Updating target network...
# 19:24:29 | Episode: 4 | Rewards:
# 	Reward: [ 86.  59. -22. -18.] | Avg Reward: 25.0 | Loss: 6.3701 | ε: 0.792 | LR: 9.65e-06
# 	Metrics - ['frags: 0', 'hits: 60', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 11', 'survival: -45', 'health_pickup: 2']
# 	Actions - Noop: 330, Move Forward: 1050, Attack: 730, Move Left: 755, Move Right: 693, Turn Left: 950, Turn Right: 977, Jump: 515
# 19:24:29 | Episode: 4 | Running quick evaluation...
# Environment Seed: [   6 1376]
# Host 65200
# Player 65200
# Episode 4 | encoders       | Shape: [2, 768],	Mean: 2.37,	Std: 4.48,	Norm: 198.43
# Episode 4 | head_first     | Shape: [2, 1024],	Mean: 2.60,	Std: 5.19,	Norm: 262.66
# Episode 4 | value_head     | Shape: [2, 1],	Mean: -1.75,	Std: 4.51,	Norm: 5.15
# Episode 4 | advantage_head | Shape: [2, 8],	Mean: -3.60,	Std: 9.22,	Norm: 38.48
#
# 19:24:33 | Episode: 5 | Steps done: 7500 | Gathering rollout (currently 25000)
# 19:24:48 | Episode: 5 | Training for 20 epochs
# 19:24:50 | Episode: 5 | Updating target network...
# 19:24:50 | Episode: 5 | Rewards:
# 	Reward: [25. 11. 65. -1.] | Avg Reward: 25.0 | Loss: 6.5062 | ε: 0.790 | LR: 9.52e-06
# 	Metrics - ['frags: 0', 'hits: 46', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 8', 'survival: -28', 'health_pickup: 0']
# 	Actions - Noop: 323, Move Forward: 954, Attack: 769, Move Left: 720, Move Right: 696, Turn Left: 931, Turn Right: 1000, Jump: 607
# 19:24:50 | Episode: 5 | Running quick evaluation...
# Environment Seed: [ 379 1011]
# Host 65207
# Player 65207
# Episode 5 | encoders       | Shape: [2, 768],	Mean: 2.73,	Std: 4.79,	Norm: 215.90
# Episode 5 | head_first     | Shape: [2, 1024],	Mean: 2.79,	Std: 5.22,	Norm: 267.81
# Episode 5 | value_head     | Shape: [2, 1],	Mean: -0.32,	Std: 2.04,	Norm: 2.09
# Episode 5 | advantage_head | Shape: [2, 8],	Mean: -0.34,	Std: 9.15,	Norm: 35.47
#
# 19:24:53 | Episode: 6 | Steps done: 9000 | Gathering rollout (currently 25000)
# 19:25:09 | Episode: 6 | Training for 20 epochs
# 19:25:10 | Episode: 6 | Updating target network...
# 19:25:10 | Episode: 6 | Rewards:
# 	Reward: [-15.  11. 111. -30.] | Avg Reward: 24.0 | Loss: 6.3545 | ε: 0.789 | LR: 9.38e-06
# 	Metrics - ['frags: 0', 'hits: 46', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 7', 'survival: -35', 'health_pickup: 2']
# 	Actions - Noop: 334, Move Forward: 1005, Attack: 730, Move Left: 794, Move Right: 665, Turn Left: 883, Turn Right: 985, Jump: 604
# 19:25:10 | Episode: 6 | Running quick evaluation...
# Environment Seed: [1374  569]
# Host 65217
# Player 65217
# Episode 6 | encoders       | Shape: [2, 768],	Mean: 2.68,	Std: 5.00,	Norm: 222.26
# Episode 6 | head_first     | Shape: [2, 1024],	Mean: 3.19,	Std: 5.86,	Norm: 301.88
# Episode 6 | value_head     | Shape: [2, 1],	Mean: -9.48,	Std: 4.59,	Norm: 14.16
# Episode 6 | advantage_head | Shape: [2, 8],	Mean: -2.87,	Std: 12.84,	Norm: 51.04
#
# 19:25:13 | Episode: 7 | Steps done: 10500 | Gathering rollout (currently 25000)
# 19:25:29 | Episode: 7 | Training for 20 epochs
# 19:25:30 | Episode: 7 | Updating target network...
# 19:25:30 | Episode: 7 | Rewards:
# 	Reward: [ -4. -13. 102.  11.] | Avg Reward: 24.0 | Loss: 5.7766 | ε: 0.787 | LR: 9.22e-06
# 	Metrics - ['frags: 0', 'hits: 42', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 8', 'survival: -26', 'health_pickup: 1']
# 	Actions - Noop: 332, Move Forward: 915, Attack: 720, Move Left: 778, Move Right: 691, Turn Left: 945, Turn Right: 1049, Jump: 570
# 19:25:30 | Episode: 7 | Running quick evaluation...
# Environment Seed: [1258  289]
# Host 65225
# Player 65225
# Episode 7 | encoders       | Shape: [2, 768],	Mean: 2.62,	Std: 4.86,	Norm: 216.30
# Episode 7 | head_first     | Shape: [2, 1024],	Mean: 2.86,	Std: 5.54,	Norm: 281.96
# Episode 7 | value_head     | Shape: [2, 1],	Mean: -2.59,	Std: 9.48,	Norm: 10.16
# Episode 7 | advantage_head | Shape: [2, 8],	Mean: -1.84,	Std: 9.64,	Norm: 38.04
#
# 19:25:33 | Episode: 8 | Steps done: 12000 | Gathering rollout (currently 25000)
# 19:25:49 | Episode: 8 | Training for 20 epochs
# 19:25:50 | Episode: 8 | Updating target network...
# 19:25:50 | Episode: 8 | Rewards:
# 	Reward: [-85.  14.  61. 119.] | Avg Reward: 25.0 | Loss: 5.9240 | ε: 0.786 | LR: 9.05e-06
# 	Metrics - ['frags: 0', 'hits: 62', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 8', 'survival: -42', 'health_pickup: 0']
# 	Actions - Noop: 355, Move Forward: 1027, Attack: 722, Move Left: 682, Move Right: 665, Turn Left: 948, Turn Right: 962, Jump: 639
# 19:25:50 | Episode: 8 | Running quick evaluation...
# Environment Seed: [1144 1199]
# Host 65233
# Player 65233
# Episode 8 | encoders       | Shape: [2, 768],	Mean: 2.67,	Std: 4.76,	Norm: 213.71
# Episode 8 | head_first     | Shape: [2, 1024],	Mean: 2.90,	Std: 5.54,	Norm: 282.90
# Episode 8 | value_head     | Shape: [2, 1],	Mean: -0.71,	Std: 2.46,	Norm: 2.66
# Episode 8 | advantage_head | Shape: [2, 8],	Mean: -5.35,	Std: 8.53,	Norm: 39.36
#
# 19:25:54 | Episode: 9 | Steps done: 13500 | Gathering rollout (currently 25000)
# 19:26:09 | Episode: 9 | Training for 20 epochs
# 19:26:11 | Episode: 9 | Updating target network...
# 19:26:11 | Episode: 9 | Rewards:
# 	Reward: [ 14.  11. -50. -18.] | Avg Reward: 21.0 | Loss: 6.3514 | ε: 0.784 | LR: 8.85e-06
# 	Metrics - ['frags: 0', 'hits: 12', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 4', 'survival: -27', 'health_pickup: 1']
# 	Actions - Noop: 348, Move Forward: 977, Attack: 817, Move Left: 763, Move Right: 687, Turn Left: 915, Turn Right: 910, Jump: 583
# 19:26:11 | Episode: 9 | Running quick evaluation...
# Environment Seed: [1070 1448]
# Host 65240
# Player 65240
# Episode 9 | encoders       | Shape: [2, 768],	Mean: 2.45,	Std: 4.50,	Norm: 200.83
# Episode 9 | head_first     | Shape: [2, 1024],	Mean: 2.79,	Std: 5.17,	Norm: 265.87
# Episode 9 | value_head     | Shape: [2, 1],	Mean: -1.93,	Std: 3.56,	Norm: 4.49
# Episode 9 | advantage_head | Shape: [2, 8],	Mean: -2.09,	Std: 7.18,	Norm: 29.05
#
# 19:26:14 | Episode: 10 | Steps done: 15000 | Gathering rollout (currently 25000)
# 19:26:30 | Episode: 10 | Training for 20 epochs
# 19:26:31 | Episode: 10 | Updating target network...
# 19:26:31 | Episode: 10 | Rewards:
# 	Reward: [ 144. -125.  103.   11.] | Avg Reward: 22.0 | Loss: 6.6146 | ε: 0.783 | LR: 8.65e-06
# 	Metrics - ['frags: 0', 'hits: 70', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 11', 'survival: -47', 'health_pickup: 1']
# 	Actions - Noop: 323, Move Forward: 990, Attack: 744, Move Left: 736, Move Right: 714, Turn Left: 932, Turn Right: 961, Jump: 600
# 19:26:31 | Episode: 10 | Running quick evaluation...
# Environment Seed: [ 257 1003]
# Host 65251
# Player 65251
# Episode 10 | encoders       | Shape: [2, 768],	Mean: 2.38,	Std: 4.25,	Norm: 190.96
# Episode 10 | head_first     | Shape: [2, 1024],	Mean: 2.60,	Std: 4.89,	Norm: 250.63
# Episode 10 | value_head     | Shape: [2, 1],	Mean: -3.25,	Std: 3.56,	Norm: 5.82
# Episode 10 | advantage_head | Shape: [2, 8],	Mean: -3.68,	Std: 8.28,	Norm: 35.27
#
# 19:26:33 | Episode: 10 | Saving checkpoint...
# Successfully stored the model: runs/20250622_191922/backups/backup_model_20250622_192633.pt
# 19:26:34 | Episode: 11 | Steps done: 16500 | Gathering rollout (currently 25000)
# 19:26:50 | Episode: 11 | Training for 20 epochs
# 19:26:52 | Episode: 11 | Updating target network...
# 19:26:52 | Episode: 11 | Rewards:
# 	Reward: [-18.  94.  40.  11.] | Avg Reward: 23.0 | Loss: 6.3859 | ε: 0.781 | LR: 8.42e-06
# 	Metrics - ['frags: 0', 'hits: 62', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 9', 'survival: -39', 'health_pickup: 0']
# 	Actions - Noop: 305, Move Forward: 988, Attack: 793, Move Left: 744, Move Right: 692, Turn Left: 943, Turn Right: 973, Jump: 562
# 19:26:52 | Episode: 11 | Running quick evaluation...
# Environment Seed: [1542  283]
# Host 65259
# Player 65259
# Episode 11 | encoders       | Shape: [2, 768],	Mean: 2.57,	Std: 4.51,	Norm: 203.38
# Episode 11 | head_first     | Shape: [2, 1024],	Mean: 2.69,	Std: 5.11,	Norm: 261.48
# Episode 11 | value_head     | Shape: [2, 1],	Mean: -0.14,	Std: 0.97,	Norm: 0.99
# Episode 11 | advantage_head | Shape: [2, 8],	Mean: -1.26,	Std: 9.87,	Norm: 38.55
#
# 19:26:55 | Episode: 12 | Steps done: 18000 | Gathering rollout (currently 25000)
# 19:27:12 | Episode: 12 | Training for 20 epochs
# 19:27:13 | Episode: 12 | Updating target network...
# 19:27:13 | Episode: 12 | Rewards:
# 	Reward: [ 93. 155. -57. -43.] | Avg Reward: 24.0 | Loss: 6.8555 | ε: 0.779 | LR: 8.19e-06
# 	Metrics - ['frags: 0', 'hits: 117', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 15', 'survival: -96', 'health_pickup: 2']
# 	Actions - Noop: 309, Move Forward: 918, Attack: 737, Move Left: 793, Move Right: 750, Turn Left: 929, Turn Right: 1005, Jump: 559
# 19:27:13 | Episode: 12 | Running quick evaluation...
# Environment Seed: [ 455 1995]
# Host 65271
# Player 65271
# Episode 12 | encoders       | Shape: [2, 768],	Mean: 2.62,	Std: 4.61,	Norm: 207.95
# Episode 12 | head_first     | Shape: [2, 1024],	Mean: 2.91,	Std: 5.47,	Norm: 280.39
# Episode 12 | value_head     | Shape: [2, 1],	Mean: -0.13,	Std: 6.96,	Norm: 6.97
# Episode 12 | advantage_head | Shape: [2, 8],	Mean: -2.82,	Std: 8.75,	Norm: 35.73
#
# 19:27:17 | Episode: 13 | Steps done: 19500 | Gathering rollout (currently 25000)
# 19:27:36 | Episode: 13 | Training for 20 epochs
# 19:27:37 | Episode: 13 | Updating target network...
# 19:27:37 | Episode: 13 | Rewards:
# 	Reward: [25. 61. 15. 36.] | Avg Reward: 25.0 | Loss: 5.9478 | ε: 0.778 | LR: 7.94e-06
# 	Metrics - ['frags: 0', 'hits: 77', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 8', 'survival: -54', 'health_pickup: 3']
# 	Actions - Noop: 377, Move Forward: 941, Attack: 709, Move Left: 744, Move Right: 702, Turn Left: 917, Turn Right: 1002, Jump: 608
# 19:27:37 | Episode: 13 | Running quick evaluation...
# Environment Seed: [1957 1765]
# Host 65280
# Player 65280
# Episode 13 | encoders       | Shape: [2, 768],	Mean: 2.82,	Std: 5.10,	Norm: 228.18
# Episode 13 | head_first     | Shape: [2, 1024],	Mean: 3.28,	Std: 6.00,	Norm: 309.49
# Episode 13 | value_head     | Shape: [2, 1],	Mean: -2.52,	Std: 0.70,	Norm: 3.63
# Episode 13 | advantage_head | Shape: [2, 8],	Mean: -1.98,	Std: 13.27,	Norm: 52.00
#
# 19:27:41 | Episode: 14 | Steps done: 21000 | Gathering rollout (currently 25000)
# 19:28:00 | Episode: 14 | Training for 20 epochs
# 19:28:01 | Episode: 14 | Updating target network...
# 19:28:01 | Episode: 14 | Rewards:
# 	Reward: [-21. 168. -18.   6.] | Avg Reward: 25.0 | Loss: 6.8078 | ε: 0.776 | LR: 7.68e-06
# 	Metrics - ['frags: 0', 'hits: 51', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 8', 'survival: -27', 'health_pickup: 3']
# 	Actions - Noop: 348, Move Forward: 924, Attack: 762, Move Left: 794, Move Right: 664, Turn Left: 944, Turn Right: 1005, Jump: 559
# 19:28:01 | Episode: 14 | Running quick evaluation...
# Environment Seed: [897 643]
# Host 65290
# Player 65290
# Episode 14 | encoders       | Shape: [2, 768],	Mean: 2.60,	Std: 4.78,	Norm: 212.98
# Episode 14 | head_first     | Shape: [2, 1024],	Mean: 3.00,	Std: 5.49,	Norm: 283.14
# Episode 14 | value_head     | Shape: [2, 1],	Mean: -5.04,	Std: 7.28,	Norm: 10.18
# Episode 14 | advantage_head | Shape: [2, 8],	Mean: -2.49,	Std: 9.43,	Norm: 37.86
#
# 19:28:04 | Episode: 15 | Steps done: 22500 | Gathering rollout (currently 25000)
# 19:28:23 | Episode: 15 | Training for 20 epochs
# 19:28:24 | Episode: 15 | Updating target network...
# 19:28:24 | Episode: 15 | Rewards:
# 	Reward: [-117.   11.   98.  -18.] | Avg Reward: 23.0 | Loss: 7.1829 | ε: 0.775 | LR: 7.41e-06
# 	Metrics - ['frags: 0', 'hits: 77', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 9', 'survival: -93', 'health_pickup: 1']
# 	Actions - Noop: 326, Move Forward: 1017, Attack: 736, Move Left: 731, Move Right: 716, Turn Left: 949, Turn Right: 959, Jump: 566
# 19:28:24 | Episode: 15 | Running quick evaluation...
# Environment Seed: [1724  976]
# Host 65299
# Player 65299
# Episode 15 | encoders       | Shape: [2, 768],	Mean: 2.47,	Std: 4.45,	Norm: 199.64
# Episode 15 | head_first     | Shape: [2, 1024],	Mean: 2.76,	Std: 5.08,	Norm: 261.62
# Episode 15 | value_head     | Shape: [2, 1],	Mean: -1.68,	Std: 0.35,	Norm: 2.40
# Episode 15 | advantage_head | Shape: [2, 8],	Mean: -4.26,	Std: 8.54,	Norm: 37.21
#
# 19:28:28 | Episode: 16 | Steps done: 24000 | Gathering rollout (currently 25000)
# 19:28:47 | Episode: 16 | Training for 20 epochs
# 19:28:48 | Episode: 16 | Updating target network...
# 19:28:48 | Episode: 16 | Rewards:
# 	Reward: [ 94. -18.  61. -18.] | Avg Reward: 24.0 | Loss: 6.2844 | ε: 0.773 | LR: 7.13e-06
# 	Metrics - ['frags: 0', 'hits: 43', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 5', 'survival: -20', 'health_pickup: 1']
# 	Actions - Noop: 353, Move Forward: 977, Attack: 718, Move Left: 736, Move Right: 657, Turn Left: 994, Turn Right: 979, Jump: 586
# 19:28:48 | Episode: 16 | Running quick evaluation...
# Environment Seed: [1927 1382]
# Host 65308
# Player 65308
# Episode 16 | encoders       | Shape: [2, 768],	Mean: 2.14,	Std: 4.10,	Norm: 181.29
# Episode 16 | head_first     | Shape: [2, 1024],	Mean: 2.43,	Std: 4.82,	Norm: 244.27
# Episode 16 | value_head     | Shape: [2, 1],	Mean: -1.39,	Std: 7.94,	Norm: 8.18
# Episode 16 | advantage_head | Shape: [2, 8],	Mean: -3.41,	Std: 8.73,	Norm: 36.45
#
# 19:28:52 | Episode: 17 | Steps done: 25500 | Gathering rollout (currently 25000)
# 19:29:10 | Episode: 17 | Training for 20 epochs
# 19:29:11 | Episode: 17 | Updating target network...
# 19:29:11 | Episode: 17 | Rewards:
# 	Reward: [157. -18. -18.  38.] | Avg Reward: 24.0 | Loss: 6.5276 | ε: 0.772 | LR: 6.84e-06
# 	Metrics - ['frags: 0', 'hits: 72', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 9', 'survival: -41', 'health_pickup: 1']
# 	Actions - Noop: 341, Move Forward: 952, Attack: 781, Move Left: 740, Move Right: 643, Turn Left: 968, Turn Right: 966, Jump: 609
# 19:29:11 | Episode: 17 | Running quick evaluation...
# Environment Seed: [ 817 1930]
# Host 65316
# Player 65316
# Episode 17 | encoders       | Shape: [2, 768],	Mean: 2.64,	Std: 4.62,	Norm: 208.45
# Episode 17 | head_first     | Shape: [2, 1024],	Mean: 2.78,	Std: 5.21,	Norm: 267.30
# Episode 17 | value_head     | Shape: [2, 1],	Mean: 2.50,	Std: 5.42,	Norm: 6.47
# Episode 17 | advantage_head | Shape: [2, 8],	Mean: -2.22,	Std: 7.88,	Norm: 31.80
#
# 19:29:15 | Episode: 18 | Steps done: 27000 | Gathering rollout (currently 25000)
# 19:29:33 | Episode: 18 | Training for 20 epochs
# 19:29:34 | Episode: 18 | Updating target network...
# 19:29:34 | Episode: 18 | Rewards:
# 	Reward: [ -27.   68. -247.    9.] | Avg Reward: 21.0 | Loss: 6.5502 | ε: 0.770 | LR: 6.55e-06
# 	Metrics - ['frags: 0', 'hits: 112', 'damage_taken: -2', 'movement: 0', 'ammo_efficiency: 15', 'survival: -179', 'health_pickup: 5']
# 	Actions - Noop: 347, Move Forward: 1024, Attack: 760, Move Left: 701, Move Right: 651, Turn Left: 951, Turn Right: 951, Jump: 615
# 19:29:34 | Episode: 18 | Running quick evaluation...
# Environment Seed: [1287  263]
# Host 65326
# Player 65326
# Episode 18 | encoders       | Shape: [2, 768],	Mean: 2.32,	Std: 4.30,	Norm: 191.59
# Episode 18 | head_first     | Shape: [2, 1024],	Mean: 2.52,	Std: 4.65,	Norm: 239.30
# Episode 18 | value_head     | Shape: [2, 1],	Mean: -4.02,	Std: 2.54,	Norm: 6.23
# Episode 18 | advantage_head | Shape: [2, 8],	Mean: -0.71,	Std: 7.16,	Norm: 27.89
#
# 19:29:37 | Episode: 19 | Steps done: 28500 | Gathering rollout (currently 25000)
# 19:29:53 | Episode: 19 | Training for 20 epochs
# 19:29:54 | Episode: 19 | Updating target network...
# 19:29:54 | Episode: 19 | Rewards:
# 	Reward: [-28.  98. 211. -14.] | Avg Reward: 23.0 | Loss: 6.1026 | ε: 0.769 | LR: 6.25e-06
# 	Metrics - ['frags: 0', 'hits: 105', 'damage_taken: -2', 'movement: 0', 'ammo_efficiency: 15', 'survival: -53', 'health_pickup: 2']
# 	Actions - Noop: 336, Move Forward: 966, Attack: 782, Move Left: 769, Move Right: 662, Turn Left: 891, Turn Right: 1045, Jump: 549
# 19:29:54 | Episode: 19 | Running quick evaluation...
# Environment Seed: [1250  359]
# Host 65360
# Player 65360
# Episode 19 | encoders       | Shape: [2, 768],	Mean: 2.38,	Std: 4.38,	Norm: 195.31
# Episode 19 | head_first     | Shape: [2, 1024],	Mean: 2.65,	Std: 5.01,	Norm: 256.51
# Episode 19 | value_head     | Shape: [2, 1],	Mean: 4.15,	Std: 3.64,	Norm: 6.91
# Episode 19 | advantage_head | Shape: [2, 8],	Mean: -1.96,	Std: 6.69,	Norm: 27.06
#
# 19:29:57 | Episode: 20 | Steps done: 30000 | Gathering rollout (currently 25000)
# 19:30:13 | Episode: 20 | Training for 20 epochs
# 19:30:14 | Episode: 20 | Updating target network...
# 19:30:14 | Episode: 20 | Rewards:
# 	Reward: [ 93. -18. 269. 237.] | Avg Reward: 29.0 | Loss: 6.2589 | ε: 0.767 | LR: 5.94e-06
# 	Metrics - ['frags: 0', 'hits: 161', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 13', 'survival: -31', 'health_pickup: 3']
# 	Actions - Noop: 323, Move Forward: 972, Attack: 793, Move Left: 745, Move Right: 721, Turn Left: 919, Turn Right: 973, Jump: 554
# 19:30:14 | Episode: 20 | Running quick evaluation...
# Environment Seed: [1658  549]
# Host 65369
# Player 65369
# Episode 20 | encoders       | Shape: [2, 768],	Mean: 2.56,	Std: 4.65,	Norm: 207.90
# Episode 20 | head_first     | Shape: [2, 1024],	Mean: 2.92,	Std: 5.55,	Norm: 283.72
# Episode 20 | value_head     | Shape: [2, 1],	Mean: 0.22,	Std: 4.52,	Norm: 4.53
# Episode 20 | advantage_head | Shape: [2, 8],	Mean: -1.07,	Std: 11.69,	Norm: 45.48
#
# 19:30:16 | Episode: 20 | Saving checkpoint...
# Successfully stored the model: runs/20250622_191922/backups/backup_model_20250622_193016.pt
# 19:30:17 | Episode: 21 | Steps done: 31500 | Gathering rollout (currently 25000)
# 19:30:33 | Episode: 21 | Training for 20 epochs
# 19:30:34 | Episode: 21 | Updating target network...
# 19:30:34 | Episode: 21 | Rewards:
# 	Reward: [ 25. -60.  58. 226.] | Avg Reward: 30.0 | Loss: 6.2067 | ε: 0.766 | LR: 5.63e-06
# 	Metrics - ['frags: 0', 'hits: 88', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 12', 'survival: -37', 'health_pickup: 1']
# 	Actions - Noop: 345, Move Forward: 967, Attack: 734, Move Left: 787, Move Right: 725, Turn Left: 890, Turn Right: 960, Jump: 592
# 19:30:34 | Episode: 21 | Running quick evaluation...
# Environment Seed: [1312  221]
# Host 65376
# Player 65376
# Episode 21 | encoders       | Shape: [2, 768],	Mean: 2.32,	Std: 4.46,	Norm: 197.13
# Episode 21 | head_first     | Shape: [2, 1024],	Mean: 2.77,	Std: 5.19,	Norm: 265.99
# Episode 21 | value_head     | Shape: [2, 1],	Mean: 4.17,	Std: 9.84,	Norm: 11.47
# Episode 21 | advantage_head | Shape: [2, 8],	Mean: -4.50,	Std: 8.43,	Norm: 37.30
#
# 19:30:37 | Episode: 22 | Steps done: 33000 | Gathering rollout (currently 25000)
# 19:30:53 | Episode: 22 | Training for 20 epochs
# 19:30:54 | Episode: 22 | Updating target network...
# 19:30:54 | Episode: 22 | Rewards:
# 	Reward: [-15.  65. -51. -10.] | Avg Reward: 29.0 | Loss: 6.5510 | ε: 0.764 | LR: 5.32e-06
# 	Metrics - ['frags: 0', 'hits: 21', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 5', 'survival: -29', 'health_pickup: 1']
# 	Actions - Noop: 356, Move Forward: 962, Attack: 734, Move Left: 776, Move Right: 632, Turn Left: 908, Turn Right: 1016, Jump: 616
# 19:30:54 | Episode: 22 | Running quick evaluation...
# Environment Seed: [ 252 1669]
# Host 65387
# Player 65387
# Episode 22 | encoders       | Shape: [2, 768],	Mean: 2.50,	Std: 4.67,	Norm: 207.63
# Episode 22 | head_first     | Shape: [2, 1024],	Mean: 2.79,	Std: 5.19,	Norm: 266.41
# Episode 22 | value_head     | Shape: [2, 1],	Mean: -4.82,	Std: 0.45,	Norm: 6.84
# Episode 22 | advantage_head | Shape: [2, 8],	Mean: 0.39,	Std: 8.45,	Norm: 32.77
#
# 19:30:57 | Episode: 23 | Steps done: 34500 | Gathering rollout (currently 25000)
# 19:31:13 | Episode: 23 | Training for 20 epochs
# 19:31:15 | Episode: 23 | Updating target network...
# 19:31:15 | Episode: 23 | Rewards:
# 	Reward: [141.  97.  90. 124.] | Avg Reward: 32.0 | Loss: 6.6784 | ε: 0.762 | LR: 5.01e-06
# 	Metrics - ['frags: 0', 'hits: 130', 'damage_taken: -2', 'movement: 0', 'ammo_efficiency: 18', 'survival: -35', 'health_pickup: 3']
# 	Actions - Noop: 371, Move Forward: 984, Attack: 747, Move Left: 712, Move Right: 730, Turn Left: 906, Turn Right: 940, Jump: 610
# 19:31:15 | Episode: 23 | Running quick evaluation...
# Environment Seed: [144 459]
# Host 65395
# Player 65395
# Episode 23 | encoders       | Shape: [2, 768],	Mean: 2.47,	Std: 4.66,	Norm: 206.63
# Episode 23 | head_first     | Shape: [2, 1024],	Mean: 2.83,	Std: 5.45,	Norm: 278.07
# Episode 23 | value_head     | Shape: [2, 1],	Mean: 1.46,	Std: 7.54,	Norm: 7.82
# Episode 23 | advantage_head | Shape: [2, 8],	Mean: -2.82,	Std: 11.07,	Norm: 44.32
#
# 19:31:18 | Episode: 24 | Steps done: 36000 | Gathering rollout (currently 25000)
# 19:31:34 | Episode: 24 | Training for 20 epochs
# 19:31:35 | Episode: 24 | Updating target network...
# 19:31:35 | Episode: 24 | Rewards:
# 	Reward: [ -3.  61. -39. 104.] | Avg Reward: 32.0 | Loss: 6.5650 | ε: 0.761 | LR: 4.69e-06
# 	Metrics - ['frags: 0', 'hits: 52', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 7', 'survival: -27', 'health_pickup: 0']
# 	Actions - Noop: 338, Move Forward: 986, Attack: 775, Move Left: 768, Move Right: 659, Turn Left: 935, Turn Right: 963, Jump: 576
# 19:31:35 | Episode: 24 | Running quick evaluation...
# Environment Seed: [1630 1093]
# Host 65403
# Player 65403
# Episode 24 | encoders       | Shape: [2, 768],	Mean: 2.35,	Std: 4.40,	Norm: 195.41
# Episode 24 | head_first     | Shape: [2, 1024],	Mean: 2.65,	Std: 5.17,	Norm: 262.77
# Episode 24 | value_head     | Shape: [2, 1],	Mean: -2.56,	Std: 7.50,	Norm: 8.32
# Episode 24 | advantage_head | Shape: [2, 8],	Mean: 0.11,	Std: 10.38,	Norm: 40.21
#
# 19:31:38 | Episode: 25 | Steps done: 37500 | Gathering rollout (currently 25000)
# 19:31:54 | Episode: 25 | Training for 20 epochs
# 19:31:55 | Episode: 25 | Updating target network...
# 19:31:55 | Episode: 25 | Rewards:
# 	Reward: [ 43.  11. 253.  83.] | Avg Reward: 35.0 | Loss: 6.6140 | ε: 0.759 | LR: 4.38e-06
# 	Metrics - ['frags: 0', 'hits: 115', 'damage_taken: -2', 'movement: 0', 'ammo_efficiency: 16', 'survival: -32', 'health_pickup: 1']
# 	Actions - Noop: 288, Move Forward: 1013, Attack: 726, Move Left: 773, Move Right: 716, Turn Left: 964, Turn Right: 955, Jump: 565
# 19:31:55 | Episode: 25 | Replaying animation...
# 19:32:41 | Episode: 25 | Running quick evaluation...
# Environment Seed: [ 454 1642]
# Host 65430
# Player 65430
# Episode 25 | encoders       | Shape: [2, 768],	Mean: 2.51,	Std: 4.41,	Norm: 198.99
# Episode 25 | head_first     | Shape: [2, 1024],	Mean: 2.64,	Std: 5.21,	Norm: 264.09
# Episode 25 | value_head     | Shape: [2, 1],	Mean: -3.57,	Std: 4.73,	Norm: 6.92
# Episode 25 | advantage_head | Shape: [2, 8],	Mean: -1.87,	Std: 10.65,	Norm: 41.93
#
# Successfully stored the model: runs/20250622_191922/best_model_20250622_193301_best75_max140.pt
# 19:33:03 | Episode: 26 | Steps done: 39000 | Gathering rollout (currently 25000)
# 19:33:19 | Episode: 26 | Training for 20 epochs
# 19:33:20 | Episode: 26 | Updating target network...
# 19:33:20 | Episode: 26 | Rewards:
# 	Reward: [ 53.  31. -18. 123.] | Avg Reward: 35.0 | Loss: 6.7719 | ε: 0.758 | LR: 4.07e-06
# 	Metrics - ['frags: 0', 'hits: 65', 'damage_taken: -2', 'movement: 0', 'ammo_efficiency: 13', 'survival: -31', 'health_pickup: 3']
# 	Actions - Noop: 332, Move Forward: 985, Attack: 746, Move Left: 761, Move Right: 675, Turn Left: 927, Turn Right: 972, Jump: 602
# 19:33:20 | Episode: 26 | Running quick evaluation...
# Environment Seed: [823 681]
# Host 65446
# Player 65446
# Episode 26 | encoders       | Shape: [2, 768],	Mean: 2.61,	Std: 4.63,	Norm: 208.26
# Episode 26 | head_first     | Shape: [2, 1024],	Mean: 2.91,	Std: 5.54,	Norm: 282.99
# Episode 26 | value_head     | Shape: [2, 1],	Mean: 2.98,	Std: 8.00,	Norm: 9.04
# Episode 26 | advantage_head | Shape: [2, 8],	Mean: -1.80,	Std: 9.41,	Norm: 37.13
#
# 19:33:23 | Episode: 27 | Steps done: 40500 | Gathering rollout (currently 25000)
# 19:33:39 | Episode: 27 | Training for 20 epochs
# 19:33:41 | Episode: 27 | Updating target network...
# 19:33:41 | Episode: 27 | Rewards:
# 	Reward: [ 64.  36.  61. -18.] | Avg Reward: 35.0 | Loss: 6.2442 | ε: 0.756 | LR: 3.76e-06
# 	Metrics - ['frags: 0', 'hits: 67', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 8', 'survival: -39', 'health_pickup: 0']
# 	Actions - Noop: 323, Move Forward: 983, Attack: 773, Move Left: 753, Move Right: 643, Turn Left: 929, Turn Right: 1016, Jump: 580
# 19:33:41 | Episode: 27 | Running quick evaluation...
# Environment Seed: [1009 1392]
# Host 65453
# Player 65453
# Episode 27 | encoders       | Shape: [2, 768],	Mean: 2.57,	Std: 4.70,	Norm: 209.90
# Episode 27 | head_first     | Shape: [2, 1024],	Mean: 3.03,	Std: 5.81,	Norm: 296.49
# Episode 27 | value_head     | Shape: [2, 1],	Mean: -1.66,	Std: 0.08,	Norm: 2.35
# Episode 27 | advantage_head | Shape: [2, 8],	Mean: -4.34,	Std: 10.18,	Norm: 43.08
#
# 19:33:44 | Episode: 28 | Steps done: 42000 | Gathering rollout (currently 25000)
# 19:33:59 | Episode: 28 | Training for 20 epochs
# 19:34:01 | Episode: 28 | Updating target network...
# 19:34:01 | Episode: 28 | Rewards:
# 	Reward: [-69. -18.  40. 140.] | Avg Reward: 35.0 | Loss: 6.2994 | ε: 0.755 | LR: 3.46e-06
# 	Metrics - ['frags: 0', 'hits: 75', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 9', 'survival: -63', 'health_pickup: 3']
# 	Actions - Noop: 338, Move Forward: 957, Attack: 783, Move Left: 777, Move Right: 680, Turn Left: 935, Turn Right: 940, Jump: 590
# 19:34:01 | Episode: 28 | Running quick evaluation...
# Environment Seed: [ 807 1313]
# Host 65461
# Player 65461
# Episode 28 | encoders       | Shape: [2, 768],	Mean: 2.42,	Std: 4.53,	Norm: 201.24
# Episode 28 | head_first     | Shape: [2, 1024],	Mean: 2.90,	Std: 5.33,	Norm: 274.42
# Episode 28 | value_head     | Shape: [2, 1],	Mean: -1.02,	Std: 2.88,	Norm: 3.22
# Episode 28 | advantage_head | Shape: [2, 8],	Mean: -1.61,	Std: 7.58,	Norm: 30.04
#
# 19:34:04 | Episode: 29 | Steps done: 43500 | Gathering rollout (currently 25000)
# 19:34:20 | Episode: 29 | Training for 20 epochs
# 19:34:21 | Episode: 29 | Updating target network...
# 19:34:21 | Episode: 29 | Rewards:
# 	Reward: [-18.  57. 149. -22.] | Avg Reward: 35.0 | Loss: 5.9099 | ε: 0.753 | LR: 3.17e-06
# 	Metrics - ['frags: 0', 'hits: 57', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 6', 'survival: -21', 'health_pickup: 0']
# 	Actions - Noop: 341, Move Forward: 981, Attack: 755, Move Left: 799, Move Right: 624, Turn Left: 902, Turn Right: 1063, Jump: 535
# 19:34:21 | Episode: 29 | Running quick evaluation...
# Environment Seed: [769 561]
# Host 65469
# Player 65469
# Episode 29 | encoders       | Shape: [2, 768],	Mean: 2.60,	Std: 4.69,	Norm: 210.03
# Episode 29 | head_first     | Shape: [2, 1024],	Mean: 2.94,	Std: 5.53,	Norm: 283.33
# Episode 29 | value_head     | Shape: [2, 1],	Mean: -1.61,	Std: 3.40,	Norm: 4.09
# Episode 29 | advantage_head | Shape: [2, 8],	Mean: -4.07,	Std: 6.28,	Norm: 29.27
#
# 19:34:24 | Episode: 30 | Steps done: 45000 | Gathering rollout (currently 25000)
# 19:34:40 | Episode: 30 | Training for 20 epochs
# 19:34:41 | Episode: 30 | Updating target network...
# 19:34:41 | Episode: 30 | Rewards:
# 	Reward: [109. 169. -18.  10.] | Avg Reward: 36.0 | Loss: 6.3096 | ε: 0.752 | LR: 2.88e-06
# 	Metrics - ['frags: 0', 'hits: 90', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 11', 'survival: -33', 'health_pickup: 1']
# 	Actions - Noop: 336, Move Forward: 953, Attack: 709, Move Left: 749, Move Right: 726, Turn Left: 948, Turn Right: 1012, Jump: 567
# 19:34:41 | Episode: 30 | Running quick evaluation...
# Environment Seed: [ 285 1911]
# Host 65476
# Player 65476
# Episode 30 | encoders       | Shape: [2, 768],	Mean: 2.48,	Std: 4.59,	Norm: 204.43
# Episode 30 | head_first     | Shape: [2, 1024],	Mean: 2.67,	Std: 5.11,	Norm: 260.84
# Episode 30 | value_head     | Shape: [2, 1],	Mean: 5.11,	Std: 4.10,	Norm: 8.30
# Episode 30 | advantage_head | Shape: [2, 8],	Mean: -0.46,	Std: 11.29,	Norm: 43.77
#
# 19:34:43 | Episode: 30 | Saving checkpoint...
# Successfully stored the model: runs/20250622_191922/backups/backup_model_20250622_193443.pt
# 19:34:45 | Episode: 31 | Steps done: 46500 | Gathering rollout (currently 25000)
# 19:35:01 | Episode: 31 | Training for 20 epochs
# 19:35:02 | Episode: 31 | Updating target network...
# 19:35:02 | Episode: 31 | Rewards:
# 	Reward: [ 61.  61.  11. -18.] | Avg Reward: 36.0 | Loss: 6.0871 | ε: 0.750 | LR: 2.60e-06
# 	Metrics - ['frags: 0', 'hits: 43', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 5', 'survival: -20', 'health_pickup: 0']
# 	Actions - Noop: 320, Move Forward: 980, Attack: 740, Move Left: 762, Move Right: 712, Turn Left: 928, Turn Right: 928, Jump: 630
# 19:35:02 | Episode: 31 | Running quick evaluation...
# Environment Seed: [1179   67]
# Host 65485
# Player 65485
# Episode 31 | encoders       | Shape: [2, 768],	Mean: 2.39,	Std: 4.28,	Norm: 192.06
# Episode 31 | head_first     | Shape: [2, 1024],	Mean: 2.52,	Std: 4.93,	Norm: 250.38
# Episode 31 | value_head     | Shape: [2, 1],	Mean: -1.39,	Std: 5.42,	Norm: 5.77
# Episode 31 | advantage_head | Shape: [2, 8],	Mean: -1.57,	Std: 7.95,	Norm: 31.42
#
# 19:35:05 | Episode: 32 | Steps done: 48000 | Gathering rollout (currently 25000)
# 19:35:21 | Episode: 32 | Training for 20 epochs
# 19:35:22 | Episode: 32 | Updating target network...
# 19:35:22 | Episode: 32 | Rewards:
# 	Reward: [-164.  -18.  -18.  202.] | Avg Reward: 35.0 | Loss: 6.2976 | ε: 0.749 | LR: 2.33e-06
# 	Metrics - ['frags: 0', 'hits: 58', 'damage_taken: -2', 'movement: 0', 'ammo_efficiency: 11', 'survival: -67', 'health_pickup: 0']
# 	Actions - Noop: 320, Move Forward: 946, Attack: 792, Move Left: 805, Move Right: 690, Turn Left: 913, Turn Right: 953, Jump: 581
# 19:35:22 | Episode: 32 | Running quick evaluation...
# Environment Seed: [ 680 1194]
# Host 65495
# Player 65495
# Episode 32 | encoders       | Shape: [2, 768],	Mean: 2.65,	Std: 4.61,	Norm: 208.38
# Episode 32 | head_first     | Shape: [2, 1024],	Mean: 2.92,	Std: 5.48,	Norm: 281.14
# Episode 32 | value_head     | Shape: [2, 1],	Mean: -1.47,	Std: 2.53,	Norm: 3.27
# Episode 32 | advantage_head | Shape: [2, 8],	Mean: -1.30,	Std: 7.63,	Norm: 30.02
#
# 19:35:25 | Episode: 33 | Steps done: 49500 | Gathering rollout (currently 25000)
# 19:35:41 | Episode: 33 | Training for 20 epochs
# 19:35:42 | Episode: 33 | Updating target network...
# 19:35:42 | Episode: 33 | Rewards:
# 	Reward: [ 79. -18. -18.  -4.] | Avg Reward: 34.0 | Loss: 5.8786 | ε: 0.747 | LR: 2.07e-06
# 	Metrics - ['frags: 0', 'hits: 27', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 5', 'survival: -22', 'health_pickup: 0']
# 	Actions - Noop: 342, Move Forward: 958, Attack: 711, Move Left: 752, Move Right: 710, Turn Left: 922, Turn Right: 950, Jump: 655
# 19:35:42 | Episode: 33 | Running quick evaluation...
# Environment Seed: [ 297 1446]
# Host 65502
# Player 65502
# Episode 33 | encoders       | Shape: [2, 768],	Mean: 2.59,	Std: 4.65,	Norm: 208.56
# Episode 33 | head_first     | Shape: [2, 1024],	Mean: 2.76,	Std: 5.19,	Norm: 265.84
# Episode 33 | value_head     | Shape: [2, 1],	Mean: -3.66,	Std: 1.79,	Norm: 5.47
# Episode 33 | advantage_head | Shape: [2, 8],	Mean: -0.19,	Std: 7.88,	Norm: 30.54
#
# 19:35:45 | Episode: 34 | Steps done: 51000 | Gathering rollout (currently 25000)
# 19:36:05 | Episode: 34 | Training for 20 epochs
# 19:36:06 | Episode: 34 | Updating target network...
# 19:36:06 | Episode: 34 | Rewards:
# 	Reward: [-18. -20. -23. 169.] | Avg Reward: 34.0 | Loss: 5.8711 | ε: 0.746 | LR: 1.82e-06
# 	Metrics - ['frags: 0', 'hits: 68', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 7', 'survival: -52', 'health_pickup: 5']
# 	Actions - Noop: 394, Move Forward: 938, Attack: 796, Move Left: 789, Move Right: 689, Turn Left: 867, Turn Right: 987, Jump: 540
# 19:36:06 | Episode: 34 | Running quick evaluation...
# Environment Seed: [1957 1126]
# Host 65511
# Player 65511
# Episode 34 | encoders       | Shape: [2, 768],	Mean: 2.66,	Std: 4.75,	Norm: 213.46
# Episode 34 | head_first     | Shape: [2, 1024],	Mean: 2.91,	Std: 5.47,	Norm: 280.31
# Episode 34 | value_head     | Shape: [2, 1],	Mean: 0.12,	Std: 0.31,	Norm: 0.36
# Episode 34 | advantage_head | Shape: [2, 8],	Mean: -3.42,	Std: 10.20,	Norm: 41.79
#
# 19:36:09 | Episode: 35 | Steps done: 52500 | Gathering rollout (currently 25000)
# 19:36:26 | Episode: 35 | Training for 20 epochs
# 19:36:27 | Episode: 35 | Updating target network...
# 19:36:27 | Episode: 35 | Rewards:
# 	Reward: [-132.  -46.  163.  248.] | Avg Reward: 34.0 | Loss: 6.0973 | ε: 0.744 | LR: 1.59e-06
# 	Metrics - ['frags: 0', 'hits: 113', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 12', 'survival: -69', 'health_pickup: 3']
# 	Actions - Noop: 346, Move Forward: 991, Attack: 717, Move Left: 737, Move Right: 698, Turn Left: 951, Turn Right: 944, Jump: 616
# 19:36:27 | Episode: 35 | Running quick evaluation...
# Environment Seed: [1161  643]
# Host 49159
# Player 49159
# Episode 35 | encoders       | Shape: [2, 768],	Mean: 2.52,	Std: 4.51,	Norm: 202.29
# Episode 35 | head_first     | Shape: [2, 1024],	Mean: 2.86,	Std: 5.36,	Norm: 275.01
# Episode 35 | value_head     | Shape: [2, 1],	Mean: -8.70,	Std: 0.60,	Norm: 12.32
# Episode 35 | advantage_head | Shape: [2, 8],	Mean: -2.60,	Std: 8.76,	Norm: 35.48
#
# 19:36:30 | Episode: 36 | Steps done: 54000 | Gathering rollout (currently 25000)
# 19:36:45 | Episode: 36 | Training for 20 epochs
# 19:36:47 | Episode: 36 | Updating target network...
# 19:36:47 | Episode: 36 | Rewards:
# 	Reward: [-18. -18.  90. -18.] | Avg Reward: 34.0 | Loss: 5.6657 | ε: 0.743 | LR: 1.36e-06
# 	Metrics - ['frags: 0', 'hits: 25', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 4', 'survival: -20', 'health_pickup: 0']
# 	Actions - Noop: 331, Move Forward: 995, Attack: 717, Move Left: 801, Move Right: 686, Turn Left: 866, Turn Right: 1001, Jump: 603
# 19:36:47 | Episode: 36 | Running quick evaluation...
# Environment Seed: [ 889 1419]
# Host 49167
# Player 49167
# Episode 36 | encoders       | Shape: [2, 768],	Mean: 2.54,	Std: 4.55,	Norm: 204.02
# Episode 36 | head_first     | Shape: [2, 1024],	Mean: 2.77,	Std: 5.38,	Norm: 273.75
# Episode 36 | value_head     | Shape: [2, 1],	Mean: 4.79,	Std: 3.75,	Norm: 7.73
# Episode 36 | advantage_head | Shape: [2, 8],	Mean: -1.15,	Std: 9.36,	Norm: 36.54
#
# 19:36:49 | Episode: 37 | Steps done: 55500 | Gathering rollout (currently 25000)
# 19:37:05 | Episode: 37 | Training for 20 epochs
# 19:37:06 | Episode: 37 | Updating target network...
# 19:37:06 | Episode: 37 | Rewards:
# 	Reward: [ 79. -18. 157. -18.] | Avg Reward: 34.0 | Loss: 6.0972 | ε: 0.741 | LR: 1.16e-06
# 	Metrics - ['frags: 0', 'hits: 71', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 9', 'survival: -30', 'health_pickup: 1']
# 	Actions - Noop: 350, Move Forward: 957, Attack: 647, Move Left: 832, Move Right: 706, Turn Left: 961, Turn Right: 1014, Jump: 533
# 19:37:06 | Episode: 37 | Running quick evaluation...
# Environment Seed: [ 140 1817]
# Host 49193
# Player 49193
# Episode 37 | encoders       | Shape: [2, 768],	Mean: 2.74,	Std: 4.82,	Norm: 217.43
# Episode 37 | head_first     | Shape: [2, 1024],	Mean: 2.86,	Std: 5.37,	Norm: 275.47
# Episode 37 | value_head     | Shape: [2, 1],	Mean: 4.86,	Std: 2.44,	Norm: 7.29
# Episode 37 | advantage_head | Shape: [2, 8],	Mean: -2.60,	Std: 8.63,	Norm: 34.99
#
# 19:37:09 | Episode: 38 | Steps done: 57000 | Gathering rollout (currently 25000)
# 19:37:25 | Episode: 38 | Training for 20 epochs
# 19:37:26 | Episode: 38 | Updating target network...
# 19:37:26 | Episode: 38 | Rewards:
# 	Reward: [-18.  36. -18. -18.] | Avg Reward: 33.0 | Loss: 5.8075 | ε: 0.740 | LR: 9.64e-07
# 	Metrics - ['frags: 0', 'hits: 12', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 3', 'survival: -20', 'health_pickup: 0']
# 	Actions - Noop: 341, Move Forward: 892, Attack: 690, Move Left: 803, Move Right: 773, Turn Left: 920, Turn Right: 965, Jump: 616
# 19:37:26 | Episode: 38 | Running quick evaluation...
# Environment Seed: [1445  213]
# Host 49207
# Player 49207
# Episode 38 | encoders       | Shape: [2, 768],	Mean: 2.74,	Std: 4.94,	Norm: 221.33
# Episode 38 | head_first     | Shape: [2, 1024],	Mean: 2.92,	Std: 5.41,	Norm: 278.25
# Episode 38 | value_head     | Shape: [2, 1],	Mean: -4.58,	Std: 1.67,	Norm: 6.69
# Episode 38 | advantage_head | Shape: [2, 8],	Mean: -0.94,	Std: 8.38,	Norm: 32.67
#
# 19:37:29 | Episode: 39 | Steps done: 58500 | Gathering rollout (currently 25000)
# 19:37:45 | Episode: 39 | Training for 20 epochs
# 19:37:47 | Episode: 39 | Updating target network...
# 19:37:47 | Episode: 39 | Rewards:
# 	Reward: [196. -58.  91.  11.] | Avg Reward: 34.0 | Loss: 6.0839 | ε: 0.738 | LR: 7.88e-07
# 	Metrics - ['frags: 0', 'hits: 88', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 10', 'survival: -39', 'health_pickup: 2']
# 	Actions - Noop: 350, Move Forward: 983, Attack: 713, Move Left: 763, Move Right: 676, Turn Left: 922, Turn Right: 930, Jump: 663
# 19:37:47 | Episode: 39 | Running quick evaluation...
# Environment Seed: [1496  296]
# Host 49231
# Player 49231
# Episode 39 | encoders       | Shape: [2, 768],	Mean: 2.33,	Std: 4.44,	Norm: 196.49
# Episode 39 | head_first     | Shape: [2, 1024],	Mean: 2.66,	Std: 5.00,	Norm: 256.34
# Episode 39 | value_head     | Shape: [2, 1],	Mean: -2.01,	Std: 4.40,	Norm: 5.24
# Episode 39 | advantage_head | Shape: [2, 8],	Mean: -2.55,	Std: 7.24,	Norm: 29.83
#
# 19:37:50 | Episode: 40 | Steps done: 60000 | Gathering rollout (currently 25000)
# 19:38:06 | Episode: 40 | Training for 20 epochs
# 19:38:07 | Episode: 40 | Updating target network...
# 19:38:07 | Episode: 40 | Rewards:
# 	Reward: [-18. -18. 198.  36.] | Avg Reward: 34.0 | Loss: 5.8117 | ε: 0.737 | LR: 6.28e-07
# 	Metrics - ['frags: 0', 'hits: 62', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 7', 'survival: -20', 'health_pickup: 0']
# 	Actions - Noop: 320, Move Forward: 944, Attack: 802, Move Left: 800, Move Right: 649, Turn Left: 899, Turn Right: 980, Jump: 606
# 19:38:07 | Episode: 40 | Running quick evaluation...
# Environment Seed: [1864  932]
# Host 49244
# Player 49244
# Episode 40 | encoders       | Shape: [2, 768],	Mean: 2.79,	Std: 4.96,	Norm: 222.96
# Episode 40 | head_first     | Shape: [2, 1024],	Mean: 3.22,	Std: 5.85,	Norm: 302.11
# Episode 40 | value_head     | Shape: [2, 1],	Mean: -4.83,	Std: 0.29,	Norm: 6.84
# Episode 40 | advantage_head | Shape: [2, 8],	Mean: -0.79,	Std: 10.28,	Norm: 39.96
#
# 19:38:09 | Episode: 40 | Saving checkpoint...
# Successfully stored the model: runs/20250622_191922/backups/backup_model_20250622_193809.pt
# 19:38:10 | Episode: 41 | Steps done: 61500 | Gathering rollout (currently 25000)
# 19:38:26 | Episode: 41 | Training for 20 epochs
# 19:38:27 | Episode: 41 | Updating target network...
# 19:38:27 | Episode: 41 | Rewards:
# 	Reward: [264. 140.  88. 123.] | Avg Reward: 37.0 | Loss: 5.8861 | ε: 0.735 | LR: 4.85e-07
# 	Metrics - ['frags: 0', 'hits: 172', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 19', 'survival: -38', 'health_pickup: 2']
# 	Actions - Noop: 281, Move Forward: 932, Attack: 836, Move Left: 713, Move Right: 718, Turn Left: 942, Turn Right: 982, Jump: 596
# 19:38:27 | Episode: 41 | Running quick evaluation...
# Environment Seed: [147 271]
# Host 49270
# Player 49270
# Episode 41 | encoders       | Shape: [2, 768],	Mean: 2.63,	Std: 4.73,	Norm: 212.24
# Episode 41 | head_first     | Shape: [2, 1024],	Mean: 2.89,	Std: 5.42,	Norm: 277.71
# Episode 41 | value_head     | Shape: [2, 1],	Mean: -5.43,	Std: 0.76,	Norm: 7.71
# Episode 41 | advantage_head | Shape: [2, 8],	Mean: 0.12,	Std: 9.27,	Norm: 35.90
#
# 19:38:30 | Episode: 42 | Steps done: 63000 | Gathering rollout (currently 25000)
# 19:38:46 | Episode: 42 | Training for 20 epochs
# 19:38:47 | Episode: 42 | Updating target network...
# 19:38:47 | Episode: 42 | Rewards:
# 	Reward: [ 71. -24.  65.  81.] | Avg Reward: 37.0 | Loss: 5.9251 | ε: 0.734 | LR: 3.61e-07
# 	Metrics - ['frags: 0', 'hits: 101', 'damage_taken: -3', 'movement: 0', 'ammo_efficiency: 18', 'survival: -71', 'health_pickup: 3']
# 	Actions - Noop: 303, Move Forward: 910, Attack: 786, Move Left: 792, Move Right: 734, Turn Left: 940, Turn Right: 950, Jump: 585
# 19:38:47 | Episode: 42 | Running quick evaluation...
# Environment Seed: [830 447]
# Host 49290
# Player 49290
# Episode 42 | encoders       | Shape: [2, 768],	Mean: 2.98,	Std: 4.94,	Norm: 226.11
# Episode 42 | head_first     | Shape: [2, 1024],	Mean: 3.21,	Std: 5.92,	Norm: 304.67
# Episode 42 | value_head     | Shape: [2, 1],	Mean: -0.59,	Std: 12.46,	Norm: 12.49
# Episode 42 | advantage_head | Shape: [2, 8],	Mean: -2.86,	Std: 9.87,	Norm: 39.91
#
# 19:38:50 | Episode: 43 | Steps done: 64500 | Gathering rollout (currently 25000)
# 19:39:06 | Episode: 43 | Training for 20 epochs
# 19:39:07 | Episode: 43 | Updating target network...
# 19:39:07 | Episode: 43 | Rewards:
# 	Reward: [ -6. 128. -73. 158.] | Avg Reward: 38.0 | Loss: 6.4514 | ε: 0.733 | LR: 2.54e-07
# 	Metrics - ['frags: 0', 'hits: 97', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 12', 'survival: -56', 'health_pickup: 0']
# 	Actions - Noop: 361, Move Forward: 985, Attack: 738, Move Left: 771, Move Right: 642, Turn Left: 949, Turn Right: 914, Jump: 640
# 19:39:07 | Episode: 43 | Running quick evaluation...
# Environment Seed: [ 605 1460]
# Host 49311
# Player 49311
# Episode 43 | encoders       | Shape: [2, 768],	Mean: 2.53,	Std: 4.61,	Norm: 206.05
# Episode 43 | head_first     | Shape: [2, 1024],	Mean: 2.79,	Std: 5.32,	Norm: 271.82
# Episode 43 | value_head     | Shape: [2, 1],	Mean: -3.14,	Std: 3.36,	Norm: 5.57
# Episode 43 | advantage_head | Shape: [2, 8],	Mean: -1.33,	Std: 8.49,	Norm: 33.29
#
# 19:39:10 | Episode: 44 | Steps done: 66000 | Gathering rollout (currently 25000)
# 19:39:26 | Episode: 44 | Training for 20 epochs
# 19:39:27 | Episode: 44 | Updating target network...
# 19:39:27 | Episode: 44 | Rewards:
# 	Reward: [ 96.  36.  76. 248.] | Avg Reward: 39.0 | Loss: 6.0999 | ε: 0.731 | LR: 1.67e-07
# 	Metrics - ['frags: 0', 'hits: 125', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 12', 'survival: -24', 'health_pickup: 2']
# 	Actions - Noop: 361, Move Forward: 910, Attack: 750, Move Left: 759, Move Right: 675, Turn Left: 929, Turn Right: 945, Jump: 671
# 19:39:27 | Episode: 44 | Running quick evaluation...
# Environment Seed: [1417 1413]
# Host 49322
# Player 49322
# Episode 44 | encoders       | Shape: [2, 768],	Mean: 2.48,	Std: 4.58,	Norm: 203.96
# Episode 44 | head_first     | Shape: [2, 1024],	Mean: 2.85,	Std: 5.29,	Norm: 271.90
# Episode 44 | value_head     | Shape: [2, 1],	Mean: 4.68,	Std: 6.35,	Norm: 9.17
# Episode 44 | advantage_head | Shape: [2, 8],	Mean: -2.20,	Std: 9.89,	Norm: 39.32
#
# 19:39:31 | Episode: 45 | Steps done: 67500 | Gathering rollout (currently 25000)
# 19:39:47 | Episode: 45 | Training for 20 epochs
# 19:39:48 | Episode: 45 | Updating target network...
# 19:39:48 | Episode: 45 | Rewards:
# 	Reward: [-49. -18.  40.  79.] | Avg Reward: 39.0 | Loss: 5.6666 | ε: 0.730 | LR: 9.85e-08
# 	Metrics - ['frags: 0', 'hits: 58', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 9', 'survival: -54', 'health_pickup: 1']
# 	Actions - Noop: 373, Move Forward: 922, Attack: 731, Move Left: 806, Move Right: 721, Turn Left: 892, Turn Right: 1004, Jump: 551
# 19:39:48 | Episode: 45 | Running quick evaluation...
# Environment Seed: [1572  421]
# Host 49335
# Player 49335
# Episode 45 | encoders       | Shape: [2, 768],	Mean: 2.59,	Std: 4.58,	Norm: 206.08
# Episode 45 | head_first     | Shape: [2, 1024],	Mean: 2.50,	Std: 5.11,	Norm: 257.52
# Episode 45 | value_head     | Shape: [2, 1],	Mean: 1.70,	Std: 4.83,	Norm: 5.40
# Episode 45 | advantage_head | Shape: [2, 8],	Mean: -2.93,	Std: 7.70,	Norm: 32.06
#
# 19:39:51 | Episode: 46 | Steps done: 69000 | Gathering rollout (currently 25000)
# 19:40:06 | Episode: 46 | Training for 20 epochs
# 19:40:08 | Episode: 46 | Updating target network...
# 19:40:08 | Episode: 46 | Rewards:
# 	Reward: [-71. 122. 491.  74.] | Avg Reward: 41.0 | Loss: 6.1895 | ε: 0.728 | LR: 4.94e-08
# 	Metrics - ['frags: 0', 'hits: 212', 'damage_taken: -8', 'movement: 0', 'ammo_efficiency: 40', 'survival: -90', 'health_pickup: 1']
# 	Actions - Noop: 371, Move Forward: 943, Attack: 801, Move Left: 786, Move Right: 735, Turn Left: 874, Turn Right: 967, Jump: 523
# 19:40:08 | Episode: 46 | Running quick evaluation...
# Environment Seed: [ 251 1340]
# Host 49344
# Player 49344
# ...
# 	Actions - Noop: 384, Move Forward: 788, Attack: 727, Move Left: 850, Move Right: 784, Turn Left: 927, Turn Right: 899, Jump: 641
# 21:03:53 | Episode: 234 | Running quick evaluation...
# Environment Seed: [1273 1566]
# Host 52748
# Player 52748
# Episode 234 | encoders       | Shape: [2, 768],	Mean: 2.78,	Std: 5.11,	Norm: 227.84
# Episode 234 | head_first     | Shape: [2, 1024],	Mean: 2.95,	Std: 5.63,	Norm: 287.84
# Episode 234 | value_head     | Shape: [2, 1],	Mean: 6.33,	Std: 1.80,	Norm: 9.13
# Episode 234 | advantage_head | Shape: [2, 8],	Mean: -0.80,	Std: 6.87,	Norm: 26.82
#
# 21:03:56 | Episode: 235 | Steps done: 352500 | Gathering rollout (currently 25000)
# 21:04:13 | Episode: 235 | Training for 20 epochs
# 21:04:14 | Episode: 235 | Updating target network...
# 21:04:14 | Episode: 235 | Rewards:
# 	Reward: [ 154. -119.   36.   35.] | Avg Reward: 47.0 | Loss: 5.3352 | ε: 0.499 | LR: 1.59e-06
# 	Metrics - ['frags: 0', 'hits: 96', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 10', 'survival: -78', 'health_pickup: 0']
# 	Actions - Noop: 377, Move Forward: 845, Attack: 706, Move Left: 864, Move Right: 737, Turn Left: 912, Turn Right: 942, Jump: 617
# 21:04:14 | Episode: 235 | Running quick evaluation...
# Environment Seed: [1698 1056]
# Host 52756
# Player 52756
# Episode 235 | encoders       | Shape: [2, 768],	Mean: 2.78,	Std: 4.88,	Norm: 220.16
# Episode 235 | head_first     | Shape: [2, 1024],	Mean: 2.96,	Std: 5.62,	Norm: 287.63
# Episode 235 | value_head     | Shape: [2, 1],	Mean: -2.54,	Std: 2.46,	Norm: 4.35
# Episode 235 | advantage_head | Shape: [2, 8],	Mean: -3.15,	Std: 10.23,	Norm: 41.57
#
# 21:04:18 | Episode: 236 | Steps done: 354000 | Gathering rollout (currently 25000)
# 21:04:35 | Episode: 236 | Training for 20 epochs
# 21:04:36 | Episode: 236 | Updating target network...
# 21:04:36 | Episode: 236 | Rewards:
# 	Reward: [-43. -18. -18.  89.] | Avg Reward: 46.0 | Loss: 5.2939 | ε: 0.498 | LR: 1.36e-06
# 	Metrics - ['frags: 0', 'hits: 37', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 9', 'survival: -43', 'health_pickup: 1']
# 	Actions - Noop: 401, Move Forward: 848, Attack: 739, Move Left: 836, Move Right: 614, Turn Left: 916, Turn Right: 943, Jump: 703
# 21:04:36 | Episode: 236 | Running quick evaluation...
# Environment Seed: [ 781 1047]
# Host 52772
# Player 52772
# Episode 236 | encoders       | Shape: [2, 768],	Mean: 2.67,	Std: 4.66,	Norm: 210.62
# Episode 236 | head_first     | Shape: [2, 1024],	Mean: 2.83,	Std: 5.33,	Norm: 273.23
# Episode 236 | value_head     | Shape: [2, 1],	Mean: 3.48,	Std: 11.18,	Norm: 12.21
# Episode 236 | advantage_head | Shape: [2, 8],	Mean: -2.41,	Std: 11.13,	Norm: 44.16
#
# 21:04:40 | Episode: 237 | Steps done: 355500 | Gathering rollout (currently 25000)
# 21:04:57 | Episode: 237 | Training for 20 epochs
# 21:04:58 | Episode: 237 | Updating target network...
# 21:04:58 | Episode: 237 | Rewards:
# 	Reward: [-18. -18. -18.  11.] | Avg Reward: 44.0 | Loss: 5.5659 | ε: 0.497 | LR: 1.16e-06
# 	Metrics - ['frags: 0', 'hits: 6', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 3', 'survival: -20', 'health_pickup: 0']
# 	Actions - Noop: 350, Move Forward: 811, Attack: 807, Move Left: 994, Move Right: 668, Turn Left: 845, Turn Right: 886, Jump: 639
# 21:04:58 | Episode: 237 | Running quick evaluation...
# Environment Seed: [1538  765]
# Host 52779
# Player 52779
# Episode 237 | encoders       | Shape: [2, 768],	Mean: 2.59,	Std: 4.76,	Norm: 212.37
# Episode 237 | head_first     | Shape: [2, 1024],	Mean: 2.66,	Std: 5.25,	Norm: 266.43
# Episode 237 | value_head     | Shape: [2, 1],	Mean: 3.61,	Std: 6.07,	Norm: 7.93
# Episode 237 | advantage_head | Shape: [2, 8],	Mean: -0.36,	Std: 9.81,	Norm: 38.02
#
# 21:05:01 | Episode: 238 | Steps done: 357000 | Gathering rollout (currently 25000)
# 21:05:19 | Episode: 238 | Training for 20 epochs
# 21:05:20 | Episode: 238 | Updating target network...
# 21:05:20 | Episode: 238 | Rewards:
# 	Reward: [  81.  334. -116.  119.] | Avg Reward: 46.0 | Loss: 5.3324 | ε: 0.496 | LR: 9.64e-07
# 	Metrics - ['frags: 0', 'hits: 136', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 16', 'survival: -47', 'health_pickup: 1']
# 	Actions - Noop: 306, Move Forward: 802, Attack: 877, Move Left: 749, Move Right: 785, Turn Left: 859, Turn Right: 941, Jump: 681
# 21:05:20 | Episode: 238 | Running quick evaluation...
# Environment Seed: [711 692]
# Host 52783
# Player 52783
# Episode 238 | encoders       | Shape: [2, 768],	Mean: 2.53,	Std: 4.73,	Norm: 210.13
# Episode 238 | head_first     | Shape: [2, 1024],	Mean: 2.93,	Std: 5.67,	Norm: 288.88
# Episode 238 | value_head     | Shape: [2, 1],	Mean: -0.41,	Std: 5.43,	Norm: 5.46
# Episode 238 | advantage_head | Shape: [2, 8],	Mean: -1.61,	Std: 9.70,	Norm: 38.12
#
# 21:05:23 | Episode: 239 | Steps done: 358500 | Gathering rollout (currently 25000)
# 21:05:40 | Episode: 239 | Training for 20 epochs
# 21:05:41 | Episode: 239 | Updating target network...
# 21:05:41 | Episode: 239 | Rewards:
# 	Reward: [104. 124.  21. 196.] | Avg Reward: 46.0 | Loss: 4.8700 | ε: 0.495 | LR: 7.88e-07
# 	Metrics - ['frags: 0', 'hits: 140', 'damage_taken: -3', 'movement: 0', 'ammo_efficiency: 20', 'survival: -48', 'health_pickup: 3']
# 	Actions - Noop: 436, Move Forward: 820, Attack: 778, Move Left: 863, Move Right: 718, Turn Left: 839, Turn Right: 985, Jump: 561
# 21:05:41 | Episode: 239 | Running quick evaluation...
# Environment Seed: [1679 1498]
# Host 52793
# Player 52793
# Episode 239 | encoders       | Shape: [2, 768],	Mean: 2.48,	Std: 4.48,	Norm: 200.63
# Episode 239 | head_first     | Shape: [2, 1024],	Mean: 2.67,	Std: 5.18,	Norm: 263.84
# Episode 239 | value_head     | Shape: [2, 1],	Mean: 3.74,	Std: 6.69,	Norm: 8.52
# Episode 239 | advantage_head | Shape: [2, 8],	Mean: -2.54,	Std: 7.66,	Norm: 31.37
#
# 21:05:45 | Episode: 240 | Steps done: 360000 | Gathering rollout (currently 25000)
# 21:06:02 | Episode: 240 | Training for 20 epochs
# 21:06:03 | Episode: 240 | Updating target network...
# 21:06:03 | Episode: 240 | Rewards:
# 	Reward: [ 77. -18.  59.  72.] | Avg Reward: 46.0 | Loss: 5.6513 | ε: 0.494 | LR: 6.28e-07
# 	Metrics - ['frags: 0', 'hits: 61', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 11', 'survival: -24', 'health_pickup: 1']
# 	Actions - Noop: 331, Move Forward: 768, Attack: 849, Move Left: 841, Move Right: 710, Turn Left: 846, Turn Right: 914, Jump: 741
# 21:06:03 | Episode: 240 | Running quick evaluation...
# Environment Seed: [1995  172]
# Host 52814
# Player 52814
# Episode 240 | encoders       | Shape: [2, 768],	Mean: 2.72,	Std: 4.74,	Norm: 214.35
# Episode 240 | head_first     | Shape: [2, 1024],	Mean: 3.19,	Std: 5.89,	Norm: 302.87
# Episode 240 | value_head     | Shape: [2, 1],	Mean: -7.16,	Std: 1.29,	Norm: 10.21
# Episode 240 | advantage_head | Shape: [2, 8],	Mean: -0.81,	Std: 9.77,	Norm: 37.97
#
# 21:06:05 | Episode: 240 | Saving checkpoint...
# Successfully stored the model: runs/20250622_191922/backups/backup_model_20250622_210605.pt
# 21:06:06 | Episode: 241 | Steps done: 361500 | Gathering rollout (currently 25000)
# 21:06:24 | Episode: 241 | Training for 20 epochs
# 21:06:25 | Episode: 241 | Updating target network...
# 21:06:25 | Episode: 241 | Rewards:
# 	Reward: [ 119.   91. -205.   50.] | Avg Reward: 43.0 | Loss: 5.2881 | ε: 0.493 | LR: 4.85e-07
# 	Metrics - ['frags: 0', 'hits: 102', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 12', 'survival: -100', 'health_pickup: 1']
# 	Actions - Noop: 370, Move Forward: 814, Attack: 771, Move Left: 911, Move Right: 695, Turn Left: 875, Turn Right: 883, Jump: 681
# 21:06:25 | Episode: 241 | Running quick evaluation...
# Environment Seed: [1826  419]
# Host 52831
# Player 52831
# Episode 241 | encoders       | Shape: [2, 768],	Mean: 2.50,	Std: 4.73,	Norm: 209.44
# Episode 241 | head_first     | Shape: [2, 1024],	Mean: 2.95,	Std: 5.46,	Norm: 280.62
# Episode 241 | value_head     | Shape: [2, 1],	Mean: -5.42,	Std: 8.09,	Norm: 11.14
# Episode 241 | advantage_head | Shape: [2, 8],	Mean: -1.47,	Std: 8.99,	Norm: 35.31
#
# 21:06:28 | Episode: 242 | Steps done: 363000 | Gathering rollout (currently 25000)
# 21:06:46 | Episode: 242 | Training for 20 epochs
# 21:06:47 | Episode: 242 | Updating target network...
# 21:06:47 | Episode: 242 | Rewards:
# 	Reward: [  6. -18.  57.  40.] | Avg Reward: 42.0 | Loss: 5.1876 | ε: 0.492 | LR: 3.61e-07
# 	Metrics - ['frags: 0', 'hits: 37', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 6', 'survival: -24', 'health_pickup: 2']
# 	Actions - Noop: 406, Move Forward: 811, Attack: 737, Move Left: 843, Move Right: 761, Turn Left: 857, Turn Right: 931, Jump: 654
# 21:06:47 | Episode: 242 | Running quick evaluation...
# Environment Seed: [1465 1136]
# Host 52854
# Player 52854
# Episode 242 | encoders       | Shape: [2, 768],	Mean: 2.55,	Std: 4.77,	Norm: 211.77
# Episode 242 | head_first     | Shape: [2, 1024],	Mean: 2.77,	Std: 5.15,	Norm: 264.55
# Episode 242 | value_head     | Shape: [2, 1],	Mean: 3.92,	Std: 7.49,	Norm: 9.33
# Episode 242 | advantage_head | Shape: [2, 8],	Mean: -1.83,	Std: 9.20,	Norm: 36.39
#
# 21:06:50 | Episode: 243 | Steps done: 364500 | Gathering rollout (currently 25000)
# 21:07:07 | Episode: 243 | Training for 20 epochs
# 21:07:09 | Episode: 243 | Updating target network...
# 21:07:09 | Episode: 243 | Rewards:
# 	Reward: [ 69.  40.  36. 207.] | Avg Reward: 43.0 | Loss: 5.6622 | ε: 0.491 | LR: 2.54e-07
# 	Metrics - ['frags: 0', 'hits: 107', 'damage_taken: -2', 'movement: 0', 'ammo_efficiency: 16', 'survival: -36', 'health_pickup: 3']
# 	Actions - Noop: 358, Move Forward: 682, Attack: 730, Move Left: 894, Move Right: 798, Turn Left: 928, Turn Right: 993, Jump: 617
# 21:07:09 | Episode: 243 | Running quick evaluation...
# Environment Seed: [ 434 1198]
# Host 52857
# Player 52857
# Episode 243 | encoders       | Shape: [2, 768],	Mean: 2.78,	Std: 4.90,	Norm: 220.68
# Episode 243 | head_first     | Shape: [2, 1024],	Mean: 3.09,	Std: 5.56,	Norm: 287.83
# Episode 243 | value_head     | Shape: [2, 1],	Mean: -6.83,	Std: 2.51,	Norm: 9.98
# Episode 243 | advantage_head | Shape: [2, 8],	Mean: -1.71,	Std: 7.67,	Norm: 30.47
#
# 21:07:12 | Episode: 244 | Steps done: 366000 | Gathering rollout (currently 25000)
# 21:07:29 | Episode: 244 | Training for 20 epochs
# 21:07:30 | Episode: 244 | Updating target network...
# 21:07:30 | Episode: 244 | Rewards:
# 	Reward: [-18.   5.  94.  90.] | Avg Reward: 44.0 | Loss: 5.5651 | ε: 0.490 | LR: 1.67e-07
# 	Metrics - ['frags: 0', 'hits: 58', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 10', 'survival: -26', 'health_pickup: 2']
# 	Actions - Noop: 364, Move Forward: 825, Attack: 796, Move Left: 835, Move Right: 788, Turn Left: 876, Turn Right: 979, Jump: 537
# 21:07:30 | Episode: 244 | Running quick evaluation...
# Environment Seed: [1214 1742]
# Host 52870
# Player 52870
# Episode 244 | encoders       | Shape: [2, 768],	Mean: 2.53,	Std: 4.87,	Norm: 215.23
# Episode 244 | head_first     | Shape: [2, 1024],	Mean: 2.75,	Std: 5.41,	Norm: 274.84
# Episode 244 | value_head     | Shape: [2, 1],	Mean: -5.13,	Std: 0.04,	Norm: 7.25
# Episode 244 | advantage_head | Shape: [2, 8],	Mean: -4.18,	Std: 8.75,	Norm: 37.80
#
# 21:07:33 | Episode: 245 | Steps done: 367500 | Gathering rollout (currently 25000)
# 21:07:51 | Episode: 245 | Training for 20 epochs
# 21:07:52 | Episode: 245 | Updating target network...
# 21:07:52 | Episode: 245 | Rewards:
# 	Reward: [-76. -60. 143. -10.] | Avg Reward: 42.0 | Loss: 5.1583 | ε: 0.489 | LR: 9.85e-08
# 	Metrics - ['frags: 0', 'hits: 63', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 10', 'survival: -75', 'health_pickup: 2']
# 	Actions - Noop: 343, Move Forward: 748, Attack: 925, Move Left: 911, Move Right: 656, Turn Left: 866, Turn Right: 916, Jump: 635
# 21:07:52 | Episode: 245 | Running quick evaluation...
# Environment Seed: [1434 1669]
# Host 52885
# Player 52885
# Episode 245 | encoders       | Shape: [2, 768],	Mean: 2.83,	Std: 4.91,	Norm: 221.93
# Episode 245 | head_first     | Shape: [2, 1024],	Mean: 2.87,	Std: 5.33,	Norm: 273.86
# Episode 245 | value_head     | Shape: [2, 1],	Mean: -3.84,	Std: 1.72,	Norm: 5.70
# Episode 245 | advantage_head | Shape: [2, 8],	Mean: -1.55,	Std: 6.28,	Norm: 25.10
#
# 21:07:55 | Episode: 246 | Steps done: 369000 | Gathering rollout (currently 25000)
# 21:08:13 | Episode: 246 | Training for 20 epochs
# 21:08:14 | Episode: 246 | Updating target network...
# 21:08:14 | Episode: 246 | Rewards:
# 	Reward: [ 20. -31. -18.  35.] | Avg Reward: 42.0 | Loss: 5.5731 | ε: 0.488 | LR: 4.94e-08
# 	Metrics - ['frags: 0', 'hits: 38', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 7', 'survival: -45', 'health_pickup: 2']
# 	Actions - Noop: 385, Move Forward: 778, Attack: 855, Move Left: 888, Move Right: 808, Turn Left: 821, Turn Right: 856, Jump: 609
# 21:08:14 | Episode: 246 | Running quick evaluation...
# Environment Seed: [1601 1532]
# Host 52886
# Player 52886
# Episode 246 | encoders       | Shape: [2, 768],	Mean: 2.55,	Std: 4.50,	Norm: 202.73
# Episode 246 | head_first     | Shape: [2, 1024],	Mean: 2.70,	Std: 5.06,	Norm: 259.69
# Episode 246 | value_head     | Shape: [2, 1],	Mean: -1.90,	Std: 1.33,	Norm: 3.00
# Episode 246 | advantage_head | Shape: [2, 8],	Mean: -2.34,	Std: 8.16,	Norm: 32.98
#
# 21:08:17 | Episode: 247 | Steps done: 370500 | Gathering rollout (currently 25000)
# 21:08:34 | Episode: 247 | Training for 20 epochs
# 21:08:35 | Episode: 247 | Updating target network...
# 21:08:35 | Episode: 247 | Rewards:
# 	Reward: [ 70.  74. -18.  75.] | Avg Reward: 43.0 | Loss: 5.2729 | ε: 0.487 | LR: 1.99e-08
# 	Metrics - ['frags: 0', 'hits: 67', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 8', 'survival: -26', 'health_pickup: 2']
# 	Actions - Noop: 405, Move Forward: 781, Attack: 792, Move Left: 805, Move Right: 732, Turn Left: 874, Turn Right: 960, Jump: 651
# 21:08:35 | Episode: 247 | Running quick evaluation...
# Environment Seed: [1449 1367]
# Host 52902
# Player 52902
# Episode 247 | encoders       | Shape: [2, 768],	Mean: 2.68,	Std: 4.81,	Norm: 215.53
# Episode 247 | head_first     | Shape: [2, 1024],	Mean: 2.79,	Std: 5.36,	Norm: 273.24
# Episode 247 | value_head     | Shape: [2, 1],	Mean: -2.15,	Std: 2.22,	Norm: 3.76
# Episode 247 | advantage_head | Shape: [2, 8],	Mean: 0.36,	Std: 11.06,	Norm: 42.85
#
# 21:08:39 | Episode: 248 | Steps done: 372000 | Gathering rollout (currently 25000)
# 21:08:56 | Episode: 248 | Training for 20 epochs
# 21:08:57 | Episode: 248 | Updating target network...
# 21:08:57 | Episode: 248 | Rewards:
# 	Reward: [-73.  20. 162.  11.] | Avg Reward: 42.0 | Loss: 5.6553 | ε: 0.486 | LR: 1.00e-05
# 	Metrics - ['frags: 0', 'hits: 92', 'damage_taken: -2', 'movement: 0', 'ammo_efficiency: 12', 'survival: -74', 'health_pickup: 2']
# 	Actions - Noop: 382, Move Forward: 866, Attack: 742, Move Left: 847, Move Right: 702, Turn Left: 863, Turn Right: 881, Jump: 717
# 21:08:57 | Episode: 248 | Running quick evaluation...
# Environment Seed: [1101 1911]
# Host 52917
# Player 52917
# Episode 248 | encoders       | Shape: [2, 768],	Mean: 2.91,	Std: 5.30,	Norm: 236.67
# Episode 248 | head_first     | Shape: [2, 1024],	Mean: 3.19,	Std: 5.84,	Norm: 300.94
# Episode 248 | value_head     | Shape: [2, 1],	Mean: 7.27,	Std: 7.68,	Norm: 12.83
# Episode 248 | advantage_head | Shape: [2, 8],	Mean: -0.22,	Std: 9.51,	Norm: 36.84
#
# 21:09:00 | Episode: 249 | Steps done: 373500 | Gathering rollout (currently 25000)
# 21:09:17 | Episode: 249 | Training for 20 epochs
# 21:09:18 | Episode: 249 | Updating target network...
# 21:09:18 | Episode: 249 | Rewards:
# 	Reward: [-18. -25.  11. -18.] | Avg Reward: 40.0 | Loss: 5.9465 | ε: 0.485 | LR: 9.99e-06
# 	Metrics - ['frags: 0', 'hits: 6', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 3', 'survival: -22', 'health_pickup: 1']
# 	Actions - Noop: 325, Move Forward: 845, Attack: 760, Move Left: 860, Move Right: 709, Turn Left: 892, Turn Right: 1012, Jump: 597
# 21:09:18 | Episode: 249 | Running quick evaluation...
# Environment Seed: [1847  223]
# Host 52940
# Player 52940
# Episode 249 | encoders       | Shape: [2, 768],	Mean: 2.57,	Std: 4.62,	Norm: 207.02
# Episode 249 | head_first     | Shape: [2, 1024],	Mean: 2.64,	Std: 5.16,	Norm: 261.98
# Episode 249 | value_head     | Shape: [2, 1],	Mean: -2.74,	Std: 3.66,	Norm: 5.33
# Episode 249 | advantage_head | Shape: [2, 8],	Mean: -2.01,	Std: 8.44,	Norm: 33.66

# %% [markdown]
# ## Dump to ONNX

# %%
  # ---------------------  SAVE / EXPORT ---------------------------------------
final_model = best_model if best_model is not None else model

onnx_filename = os.path.join(training_folder, "enhanced_doom_agent.onnx")
onnx_dump(env, final_model, PLAYER_CONFIG, onnx_filename)
print(f"Best network exported to {onnx_filename}")
# Out:
# Best network exported to runs/20250622_191922/enhanced_doom_agent.onnx

# %% [markdown]
# ### Evaluation and Visualization
#
# In this final section, you can evaluate your trained agent, inspect its performance visually, and analyze reward components over time.

# %%
plot_training_metrics(get_avg_reward(reward_history, episodes=-1), q_loss_list, epsilon_history)

# %%
replay_episode(env, final_model, device, DTYPE, store=True, random_player=False)
# Out:
# Enabling replays!
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 replay_episode(env, final_model, device, DTYPE, store=True, random_player=False)
#
# File ~/Documents/Studium/JKU/DRL/UE_DRL/Final/jku.wad/agents/utils.py:72, in replay_episode(env, model, device, dtype, path, store, random_player)
#      69 while not all(eval_dones):
#      70     env_actions = EnvActions(env)
# ---> 72     eval_act = epsilon_greedy(env, model, eval_obs, 0, env_actions, device, dtype=dtype)
#      73     eval_obs, reward_components, eval_dones, _ = env.step(eval_act)
#      74     eval_reward += sum(reward_components)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Documents/Studium/JKU/DRL/UE_DRL/Final/jku.wad/agents/dqn.py:55, in epsilon_greedy(env, model, obs, epsilon, env_actions, device, dtype, action_counter, debug)
#      52     obs = torch.stack(obs) # stack players
#      54 processed_obs = process_observation(obs, device=device, dtype=dtype, permute=False)
# ---> 55 q_values = model(processed_obs)
#      57 # Indices are necessary if buttons don't start at 0 but at 1 (e.g., if there wouldn't be a noop option)
#      58 if num_players == 1:
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Documents/Studium/JKU/DRL/UE_DRL/Final/jku.wad/agents/dqn.py:201, in EfficientDQN.forward(self, observations)
#     194 """
#     195 Forward pass through multi-buffer DQN
#     196
#     197 Args:
#     198     observations: Tensor for "screen", "depth", "labels", "automap"
#     199 """
#     200 # Encode each visual buffer and split the observations
# --> 201 features = self.encoders(observations.split(self.obs_state_dims, dim=1))
#     203 # Use one head for the dueling network
#     204 head_logits = self.head_first(features)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Documents/Studium/JKU/DRL/UE_DRL/Final/jku.wad/agents/modules.py:20, in Parallel.forward(self, inputs)
#      17 all_logits = []
#      19 for module, input in zip(self.model, inputs):
# ---> 20     all_logits.append(module(input))
#      22 return torch.cat(all_logits, dim=1)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# RuntimeError: Input type (MPSFloatType) and weight type (torch.FloatTensor) should be the same
