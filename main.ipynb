# %% [markdown]
# # Deep Reinforcement Learning — Doom Agent (SS2025)
#
# Welcome to the last assignment for the **Deep Reinforcement Learning** course (SS2025). In this notebook, you"ll implement and train a reinforcement learning agent to play **Doom**.
#
# You will:
# - Set up a custom VizDoom environment with shaped rewards
# - Train an agent using an approach of your choice
# - Track reward components across episodes
# - Evaluate the best model
# - Visualize performance with replays and GIFs
# - Export the trained agent to ONNX to submit to the evaluation server

# %%
# Clone repo
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#%cd /content/drive/MyDrive/Colab\ Notebooks

# %%
# Clone repo
#!git clone https://github.com/albortino/doom-drl-challenge.git
#%cd doom-drl-challenge

# Install the dependencies
#!pip install torch numpy matplotlib vizdoom portpicker gym onnx

# %%
from IPython import get_ipython
get_ipython().run_line_magic('load_ext', 'autoreload')
get_ipython().run_line_magic('autoreload', '2')

# %%
from datetime import datetime
from collections import deque
from copy import deepcopy
import random
from torch import nn
from doom_arena import VizdoomMPEnv

# %%
from agents.utils import *
from agents.visualizations import *
from agents.helpers import *
from agents.dqn import EfficientDQN, epsilon_greedy, soft_update_target_network

# %%
rng = np.random.default_rng(100)

# %% [markdown]
# ## Configuration
#
# ViZDoom supports multiple visual buffers that can be used as input for training agents. Each buffer provides different information about the game environment, as seen from left to right:
#
#
# Screen
# - The default first-person RGB view seen by the agent.
#
# Labels
# - A semantic map where each pixel is tagged with an object ID (e.g., enemy, item, wall).
#
# Depth
# - A grayscale map showing the distance from the agent to surfaces in the scene.
#
# Automap
# - A top-down schematic view of the map, useful for global navigation tasks.
#
# ![buffers gif](https://vizdoom.farama.org/_images/vizdoom-demo.gif)

# %% [markdown]
# ### Variables

# %%
USE_GRAYSCALE = False  # ← flip to False for RGB

PLAYER_CONFIG = {
    # NOTE: "algo_type" defaults to POLICY in evaluation script!
    "algo_type": "QVALUE",  # OPTIONAL, change to POLICY if using policy-based (eg PPO)
    "n_stack_frames": 1, #4, # 1 # Temporal information
    "extra_state": ["depth"], #["labels"],#, "automap"], #["depth", "labels", "automap"],
    "hud": "none",
    "crosshair": True,
    "screen_format": 8 if USE_GRAYSCALE else 0,
}

# %%
# TODO: environment training paramters
N_STACK_FRAMES = 1 # 4 does not work yet!
NUM_PLAYERS = 4 #3
NUM_EVAL_PLAYERS = 2
NUM_BOTS = 6 #1, #6
EPISODE_TIMEOUT = 1500 # 2000
# TODO: model hyperparams
GAMMA = 0.98
EPISODES = 250 #2 # 500
BATCH_SIZE = 128
REPLAY_BUFFER_SIZE = 25_000
LEARNING_RATE = 1e-5
EPSILON_START = 1.0
EPSILON_END = 0.1
EPSILON_DECAY = 0.998 # 0.987
N_EPOCHS = 20
FRAME_SKIPPING = 0
FRAME_SKIPPING_STOP = 100
DEBUG = True
PRINT_EVERY = 50
VIDEO_DURING_TRAINING = True
EVALUATION_EVERY = 25
CHECKPOINT_EVERY = 10
DTYPE = torch.float32
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print("Device:", device)
# Out:
# Device: mps

# %%
# Create folder for training
training_id = datetime.now().strftime('%Y%m%d_%H%M%S')
training_folder = os.path.join("runs", training_id)
os.makedirs(training_folder, exist_ok=True)
print("Using folder:", training_folder)

# Define loggers and helpers
logger = Logger(training_folder, also_print=True)
activation_logger = ActivationLogger(training_folder, filename="activations.txt", also_print=False)

obs_states = ExtraStates(PLAYER_CONFIG["extra_state"] + ["screen"], num_frames = N_STACK_FRAMES)
# Out:
# Using folder: runs/20250622_183846

# %% [markdown]
# ### Environment

# %%
reward_fn = YourReward(num_players=NUM_PLAYERS)
def build_env(num_players: int = NUM_PLAYERS, seed: np.ndarray = rng.integers(1, 2000, NUM_PLAYERS)):
    env = VizdoomMPEnv(
        num_players=num_players, # 4 is max
        num_bots=NUM_BOTS,
        bot_skill=1, # Increased difficulty
        doom_map="TRNM",  # ROOM = NOTE simple, small map; other options: TRNM, TRNMBIG
        extra_state=PLAYER_CONFIG["extra_state"],  # see info about states at the beginning of "Environment configuration" above
        episode_timeout=EPISODE_TIMEOUT,
        n_stack_frames=PLAYER_CONFIG["n_stack_frames"],
        crosshair=PLAYER_CONFIG["crosshair"],
        hud=PLAYER_CONFIG["hud"],
        screen_format=PLAYER_CONFIG["screen_format"],
        reward_fn=reward_fn,
        seed = seed,
        ticrate = 35#*3,
    )
    return env

env = build_env()
with suppress_output(): # Reset to get player and game information
    _ = env.reset()
# Out:
# Environment Seed: [1534 1670  249 1193]
# Host 62830
# Player 62830

# %% [markdown]
# ## Agent
#
# Implement **your own agent** in the code cell that follows.
#
# * In `agents/dqn.py` and `agents/ppo.py` you’ll find very small **skeletons**—they compile but are meant only as reference or quick tests.
#   Feel free to open them, borrow ideas, extend them, or ignore them entirely.
# * The notebook does **not** import those files automatically; whatever class you define in the next cell is the one that will be trained.
# * You may keep the DQN interface, switch to PPO, or try something else.
# * Tweak any hyper-parameters (`PLAYER_CONFIG`, ε-schedule, optimiser, etc.) and document what you tried.

# %%
# Get information about actions from the environment
env_actions = EnvActions(env, rng=rng)

# main Q-network
model = EfficientDQN(
    input_dim = 0,
    action_space=env_actions.action_space,
    obs_state_infos=obs_states,
).to(device, dtype=DTYPE)

# Load a model from file
#model = model.load_model("/Users/matsschneider/Documents/Studium/JKU/DRL/UE_DRL/Final/jku.wad/runs/20250622_120122/best_model_20250622_121858_best223_max473.pt").to(device, dtype=DTYPE)
# Out:
# Weights initialized with Kaiming He
# Weights initialized with Kaiming He
# Weights initialized with Kaiming He
# Weights initialized with Kaiming He
# Weights initialized with Kaiming He
# Initialized model with 1349049 parameters!

# %%
# Define training helpers
target_model  = deepcopy(model).to(device, dtype=DTYPE)
optimizer  = torch.optim.AdamW(target_model.parameters(), lr=LEARNING_RATE, weight_decay=5e-4)
scheduler  = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=50, eta_min=1e-8)
loss_fn = nn.MSELoss()
replay_buffer = deque(maxlen=REPLAY_BUFFER_SIZE)

# %% [markdown]
# ## Example of environment
#
# This let's you play and analyze the environment

# %%
# Reset environment
with suppress_output():
    obs_test: list = env.reset()
    
for player in range(len(obs_test)):
    plot_images(obs_test[player], obs_states.get_dims())

# %%
# Iterate for a given number of steps
STEPS = 30

with torch.no_grad():
    for i in range(STEPS):
        actions = env_actions.get_random_action(NUM_PLAYERS) # Random
        #actions = env_actions.get_action_value(1, NUM_PLAYERS) # Get a specific action 
        #actions = epsilon_greedy(env, model, obs_test, 0.5, env_actions, device, DTYPE, debug=True) # 50% random actions by model
        actions = epsilon_greedy(env, model, torch.rand_like(torch.stack(obs_test)), 0, env_actions, device, DTYPE, debug=False) # model fully random
        
        obs_test, reward = env.step(actions)[0:2] # Select next observations and reward

    # Plot the visuals for every player
    for player in range(env.num_players):
        action_print = [actions] if isinstance(actions, int) else actions
        plot_images(obs_test[player], obs_states.get_dims(), **{"title": f"Reward: {reward[player]:.1f} | Action: {env_actions.get_action_name(action_print[player])}"})

# %% [markdown]
# ### Example of Reward

# %%
player_idx = rng.integers(env.num_players)

player_game_vars = env.envs[player_idx].unwrapped._game_vars
player_game_vars_pre = env.envs[player_idx].unwrapped._game_vars_pre
reward = reward_fn(0, player_game_vars, player_game_vars_pre, 0)
print(f"Reward: {np.sum(reward)} | {reward}")
for key, value_now, value_old in zip(player_game_vars, player_game_vars.values(), player_game_vars_pre.values()):   
    print(f"{key+':':<25}{value_now:.0f} | {value_old:.0f}")
# Out:
# Reward: -0.013520792420351882 | (0.0, 0.0, -0.0, 0, 0.0, np.float64(-0.013520792420351882), 0.0)
# HEALTH:                  100 | 100
# AMMO3:                   0 | 0
# FRAGCOUNT:               0 | 0
# ARMOR:                   0 | 0
# HITCOUNT:                0 | 0
# HITS_TAKEN:              0 | 0
# DEAD:                    0 | 0
# DEATHCOUNT:              0 | 0
# DAMAGECOUNT:             0 | 0
# DAMAGE_TAKEN:            0 | 0
# KILLCOUNT:               0 | 0
# SELECTED_WEAPON:         2 | 2
# SELECTED_WEAPON_AMMO:    110 | 110
# POSITION_X:              1088 | 1088
# POSITION_Y:              1230 | 1230

# %% [markdown]
# ## Training loop

# %%
# ---------------------  TRAINING LOOP  ----------------------
training_info_str = (
    f"N_STACK_FRAMES: {N_STACK_FRAMES}, "
    f"NUM_PLAYERS: {NUM_PLAYERS}, "
    f"NUM_BOTS: {NUM_BOTS}, "
    f"EPISODE_TIMEOUT: {EPISODE_TIMEOUT}, "
    f"GAMMA: {GAMMA}, "
    f"EPISODES: {EPISODES}, "
    f"BATCH_SIZE: {BATCH_SIZE}, "
    f"REPLAY_BUFFER_SIZE: {REPLAY_BUFFER_SIZE}, "
    f"LEARNING_RATE: {LEARNING_RATE}, "
    f"EPSILON_START: {EPSILON_START}, "
    f"EPSILON_END: {EPSILON_END}, "
    f"EPSILON_DECAY: {EPSILON_DECAY}, "
    f"N_EPOCHS: {N_EPOCHS}, "
    f"FRAME_SKIPPING: {FRAME_SKIPPING}, "
    f"FRAME_SKIPPING_STOP: {FRAME_SKIPPING_STOP}, "
    f"DEBUG: {DEBUG}, "
    f"PRINT_EVERY: {PRINT_EVERY}, "
    f"VIDEO_DURING_TRAINING: {VIDEO_DURING_TRAINING}, "
    f"EVALUATION_EVERY: {EVALUATION_EVERY}"
)

training_info_str += ', '.join([f"{k}: {v}" for k, v in PLAYER_CONFIG.items()])

logger.log(training_info_str, improve_file_output=True)

# Training settings
q_loss_list, epsilon_history = [], []
reward_history = {player: [] for player in range(env.num_players)}
best_reward = float("-inf")
best_model = None

epsilon = EPSILON_START 
steps_done = 0

with TqdmProgress(total=EPISODES) as progress_bar:
    for episode in progress_bar:
        
        episode_action_counter = ActionCounter()
        progress_bar.set_description(episode)
        
        with suppress_output():
            obs: torch.Tensor = env.reset()
        
        # Episode variables for each player
        episode_metrics = {player: {"frags": 0, "hits": 0, "damage_taken": 0, "movement": 0, "ammo_efficiency": 0, "survival": 0, "health_pickup": 0} for player in range(env.num_players)}
        episode_reward = {player: 0.0 for player in range(env.num_players)}

        dones = [False]
        model.eval()
        
        episode_msg = f"{datetime.now().strftime('%H:%M:%S')} | Episode: {episode} | Steps done: {steps_done} | Gathering rollout (currently {len(replay_buffer)})"
        logger.log(episode_msg)
        
        # ───────── rollout ─────────────────────────────────────────────
        while not all(dones):
            
            # Skip Frames (Testing - I am aware that in the original paper they stacked the images. I want to get many more steps at the beginning)
            act = epsilon_greedy(env, model, obs, epsilon, env_actions, device, DTYPE, episode_action_counter)
            
            max_skip_steps = max(FRAME_SKIPPING * (episode < FRAME_SKIPPING_STOP), 1)
            for skip_steps in range(max_skip_steps):
                if all(dones):
                    break
                next_obs, reward, dones, _ = env.step(act)
                steps_done += 1

            # ----- reward definition ----------------
            for player_idx in range(env.num_players):
                episode_reward[player_idx] += np.sum(reward[player_idx]) # Should be a list with one value
                
                if dones[player_idx]:
                    break
                
                reward_components = reward_fn(None, env.envs[player_idx].unwrapped._game_vars, env.envs[player_idx].unwrapped._game_vars_pre, None)

                if len(reward_components) >= 6:
                    episode_metrics[player_idx]["frags"] += reward_components[0]
                    episode_metrics[player_idx]["hits"] += reward_components[1]
                    episode_metrics[player_idx]["damage_taken"] += reward_components[2]
                    episode_metrics[player_idx]["movement"] += reward_components[3]
                    episode_metrics[player_idx]["ammo_efficiency"] += reward_components[4]
                    episode_metrics[player_idx]["survival"] += reward_components[5]
                    episode_metrics[player_idx]["health_pickup"] += reward_components[6]
            
                # ----- buffer and environment handling ----------------
                if env.num_players == 1:
                    act = [act]
                    
                replay_buffer.append((obs[player_idx], act[player_idx], reward[player_idx], next_obs[player_idx], dones[player_idx]))

            obs = next_obs
            
        [reward_history[player_idx].append(reward) for player_idx, reward in episode_reward.items()] # Append rewards for every player
        epsilon_history.append(epsilon)

        # ───────── learning step (experience replay) ──────────────────
        if len(replay_buffer) >= BATCH_SIZE:

            model.train()
            train_msg = f"{datetime.now().strftime('%H:%M:%S')} | Episode: {episode} | Training for {N_EPOCHS} epochs"
            logger.log(train_msg)
            
            for epoch in range(N_EPOCHS):

                batch = random.sample(replay_buffer, BATCH_SIZE)
                states, actions, rewards, next_states, dones = zip(*batch)

                # Convert to tensors for training
                states = torch.stack(states).to(device, DTYPE)
                next_states = torch.stack(next_states).to(device, DTYPE)
                actions = torch.tensor(actions, device=device)
                rewards = torch.tensor(rewards, device=device, dtype=torch.float32)
                dones = torch.tensor(dones, device=device, dtype=torch.float32)

                current_q = model(states).gather(1, actions.unsqueeze(1)).squeeze(1)
                
                # Target q values
                with torch.no_grad():
                    next_q = target_model(next_states).max(1)[0] #.values
                    target_q = torch.clamp(rewards + GAMMA * next_q * (1 - dones), min=-10, max=10) # clamping to staibilize training
                
                loss = loss_fn(current_q, target_q)

                optimizer.zero_grad()
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                optimizer.step()
                
                q_loss_list.append(loss.item())
            
            # Update scheduler and epsilon
            scheduler.step()
            epsilon = max(EPSILON_END, epsilon * EPSILON_DECAY)
            
            progress_bar.update_step_count()

            # Update target network        
            target_update_msg = f"{datetime.now().strftime('%H:%M:%S')} | Episode: {episode} | Updating target network..."
            logger.log(target_update_msg)
            
            soft_update_target_network(model, target_model, tau=1e-3)
            #hard_update_target_network(target_model, model)
            
        else:
            train_fail_msg = f"{datetime.now().strftime('%H:%M:%S')} | Episode: {episode} | Replay buffer smaller than batchsize {len(replay_buffer)} {BATCH_SIZE}"
            logger.log(train_fail_msg, print_once=True)

        # -------- logging ----------
        avg_reward = get_avg_reward(reward_history, episodes=PRINT_EVERY, round=0)
        avg_loss = np.mean(q_loss_list[-10:]) if q_loss_list else 0
        stacked_episode_reward = np.array([np.round(reward, 0) for reward in episode_reward.values()])
        
        action_counts = episode_action_counter.get_counts()

        # Rewards and losses
        reward_msg = f"{datetime.now().strftime('%H:%M:%S')} | Episode: {episode} | Rewards:\n"
        reward_msg += f"\tReward: {stacked_episode_reward} | Avg Reward: {avg_reward} | Loss: {avg_loss:.4f} | ε: {epsilon:.3f} | LR: {scheduler.get_last_lr()[0]:.2e}"
        reward_msg += f"\n\tMetrics - {[f'{metric}: {value}' for metric, value in get_average_result(episode_metrics).items()]}"
        reward_msg += f"\n\tActions - {', '.join([f'{k}: {v}' for k, v in episode_action_counter.get_name_counts(env_actions).items()])}"

        logger.log(reward_msg, print_once = episode % PRINT_EVERY == 0)
        
        progress_bar.set_postfix({
            "Avg Reward": f"{avg_reward}",
            "Loss": f"{avg_loss:.4f}",
            "Epsilon": f"{epsilon:.2f}"
        })
            
        # Show the video 
        if VIDEO_DURING_TRAINING and episode % EVALUATION_EVERY == 0:
            replay_msg = f"{datetime.now().strftime('%H:%M:%S')} | Episode: {episode} | Replaying animation..."
            logger.log(replay_msg)
            with suppress_output():
                replay_episode(env, model, device, DTYPE, path=training_folder, store=True, random_player=False)
        
        # ───────── quick evaluation for best-model tracking ───────────
        quick_eval_msg = f"{datetime.now().strftime('%H:%M:%S')} | Episode: {episode} | Running quick evaluation..."
        logger.log(quick_eval_msg)
        
        # Create test env with random seed
        eval_env = build_env(num_players=NUM_EVAL_PLAYERS, seed = rng.integers(2000, size=NUM_EVAL_PLAYERS))
        
        # Reset environment
        with suppress_output():
            eval_obs = eval_env.reset()

        # Make a random number of steps in the environment
        for action in [env_actions.get_random_action(2) for _ in range(rng.integers(100))]:
            eval_obs = eval_env.step(action)[0]

        # Analyze the model tensors at the position
        analyze_model_tensors(activation_logger, episode, eval_obs, model, split_dims=obs_states.get_dims(return_dict=False), print_once=True)

        # Evaluate every EVALUTATION EVERY periods to improve the speed
        if episode > 0 and episode % EVALUATION_EVERY == 0:
            with suppress_output():
                eval_obs = eval_env.reset() # List of obs
                
            eval_episode_rewards = [0.0] * eval_env.num_players
            eval_dones = [False]
            model.eval()
        
            while not all(eval_dones):
                eval_action_list = epsilon_greedy(eval_env, model, eval_obs, 0, env_actions, device, dtype=DTYPE)
                eval_next_obs_list, eval_reward_list, eval_dones, _ = eval_env.step(eval_action_list)
                for i in range(eval_env.num_players):
                    eval_episode_rewards[i] += eval_reward_list[i]
                eval_obs = eval_next_obs_list
            
            mean_eval_reward = np.mean(eval_episode_rewards)
            
            if mean_eval_reward > best_reward:
                best_reward = mean_eval_reward
                model_name = f"best_model_{datetime.now().strftime('%Y%m%d_%H%M%S')}_best{best_reward:.0f}_max{np.max(eval_episode_rewards):.0f}.pt"
                model.save_model(path=training_folder, filename=model_name)
                best_model = deepcopy(model)
        
        if episode > 0 and episode % CHECKPOINT_EVERY == 0:
            model_name = f"backup_model_{datetime.now().strftime('%Y%m%d_%H%M%S')}.pt"
            model.save_model(path=os.path.join(training_folder, 'backups'), filename=model_name)
# Out:
# N_STACK_FRAMES: 1, NUM_PLAYERS: 4, NUM_BOTS: 6, EPISODE_TIMEOUT: 1500, GAMMA: 0.98, EPISODES: 250, BATCH_SIZE: 128, REPLAY_BUFFER_SIZE: 25000, LEARNING_RATE: 1e-05, EPSILON_START: 1.0, EPSILON_END: 0.1, EPSILON_DECAY: 0.998, N_EPOCHS: 20, FRAME_SKIPPING: 0, FRAME_SKIPPING_STOP: 100, DEBUG: True, PRINT_EVERY: 50, VIDEO_DURING_TRAINING: True, EVALUATION_EVERY: 25algo_type: QVALUE, n_stack_frames: 1, extra_state: ['depth'], hud: none, crosshair: True, screen_format: 0
# Training:   0%|          | 0/250 [00:00<?, ? episode/s]
# 18:40:03 | Episode: 0 | Steps done: 0 | Gathering rollout (currently 0)
# 18:40:18 | Episode: 0 | Training for 20 epochs
# 18:40:19 | Episode: 0 | Updating target network...
# 18:40:19 | Episode: 0 | Rewards:
# 	Reward: [ -6. 136. -18. -18.] | Avg Reward: 23.0 | Loss: 6.7557 | ε: 0.998 | LR: 9.99e-06
# 	Metrics - ['frags: 0', 'hits: 40', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 3', 'survival: -21', 'health_pickup: 1']
# 	Actions - Noop: 299, Move Forward: 1101, Attack: 902, Move Left: 620, Move Right: 619, Turn Left: 899, Turn Right: 1034, Jump: 526
# 18:40:19 | Episode: 0 | Replaying animation...
# 18:41:03 | Episode: 0 | Running quick evaluation...
# Environment Seed: [121  76]
# Host 63695
# Player 63695
# Episode 0 | encoders       | Shape: [2, 768],	Mean: 2.65,	Std: 4.73,	Norm: 212.30
# Episode 0 | head_first     | Shape: [2, 1024],	Mean: 2.90,	Std: 5.52,	Norm: 281.92
# Episode 0 | value_head     | Shape: [2, 1],	Mean: -0.36,	Std: 4.80,	Norm: 4.82
# Episode 0 | advantage_head | Shape: [2, 8],	Mean: -4.64,	Std: 8.94,	Norm: 39.29
#
# 18:41:07 | Episode: 1 | Steps done: 1500 | Gathering rollout (currently 5996)
# 18:41:22 | Episode: 1 | Training for 20 epochs
# 18:41:23 | Episode: 1 | Updating target network...
# 18:41:23 | Episode: 1 | Rewards:
# 	Reward: [ 51. -18. -18.  56.] | Avg Reward: 20.0 | Loss: 6.7356 | ε: 0.996 | LR: 9.96e-06
# 	Metrics - ['frags: 0', 'hits: 42', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 3', 'survival: -28', 'health_pickup: 1']
# 	Actions - Noop: 304, Move Forward: 1080, Attack: 907, Move Left: 630, Move Right: 622, Turn Left: 978, Turn Right: 946, Jump: 533
# 18:41:23 | Episode: 1 | Running quick evaluation...
# Environment Seed: [ 998 1847]
# Host 63696
# Player 63696
# Episode 1 | encoders       | Shape: [2, 768],	Mean: 2.68,	Std: 4.78,	Norm: 214.64
# Episode 1 | head_first     | Shape: [2, 1024],	Mean: 3.02,	Std: 5.61,	Norm: 288.17
# Episode 1 | value_head     | Shape: [2, 1],	Mean: 3.76,	Std: 6.49,	Norm: 8.39
# Episode 1 | advantage_head | Shape: [2, 8],	Mean: -5.38,	Std: 6.91,	Norm: 34.35
#
# 18:41:27 | Episode: 2 | Steps done: 3000 | Gathering rollout (currently 11992)
# 18:41:42 | Episode: 2 | Training for 20 epochs
# 18:41:44 | Episode: 2 | Updating target network...
# 18:41:44 | Episode: 2 | Rewards:
# 	Reward: [  79. -131.   20.   61.] | Avg Reward: 16.0 | Loss: 6.5608 | ε: 0.994 | LR: 9.91e-06
# 	Metrics - ['frags: 0', 'hits: 128', 'damage_taken: -2', 'movement: 0', 'ammo_efficiency: 9', 'survival: -132', 'health_pickup: 3']
# 	Actions - Noop: 327, Move Forward: 1063, Attack: 943, Move Left: 651, Move Right: 622, Turn Left: 941, Turn Right: 933, Jump: 520
# 18:41:44 | Episode: 2 | Running quick evaluation...
# Environment Seed: [ 604 1345]
# Host 63697
# Player 63697
# Episode 2 | encoders       | Shape: [2, 768],	Mean: 2.47,	Std: 4.54,	Norm: 202.59
# Episode 2 | head_first     | Shape: [2, 1024],	Mean: 2.79,	Std: 5.35,	Norm: 273.05
# Episode 2 | value_head     | Shape: [2, 1],	Mean: -4.34,	Std: 0.83,	Norm: 6.20
# Episode 2 | advantage_head | Shape: [2, 8],	Mean: -0.28,	Std: 7.25,	Norm: 28.10
#
# 18:41:47 | Episode: 3 | Steps done: 4500 | Gathering rollout (currently 17988)
# 18:42:02 | Episode: 3 | Training for 20 epochs
# 18:42:03 | Episode: 3 | Updating target network...
# 18:42:03 | Episode: 3 | Rewards:
# 	Reward: [ 82. -18. -29. 135.] | Avg Reward: 23.0 | Loss: 7.1044 | ε: 0.992 | LR: 9.84e-06
# 	Metrics - ['frags: 0', 'hits: 142', 'damage_taken: -5', 'movement: 0', 'ammo_efficiency: 12', 'survival: -109', 'health_pickup: 2']
# 	Actions - Noop: 292, Move Forward: 1140, Attack: 898, Move Left: 583, Move Right: 691, Turn Left: 956, Turn Right: 945, Jump: 495
# 18:42:03 | Episode: 3 | Running quick evaluation...
# Environment Seed: [842 315]
# Host 63698
# Player 63698
# Episode 3 | encoders       | Shape: [2, 768],	Mean: 2.39,	Std: 4.42,	Norm: 196.79
# Episode 3 | head_first     | Shape: [2, 1024],	Mean: 2.67,	Std: 5.15,	Norm: 262.52
# Episode 3 | value_head     | Shape: [2, 1],	Mean: 0.61,	Std: 3.45,	Norm: 3.55
# Episode 3 | advantage_head | Shape: [2, 8],	Mean: -3.52,	Std: 8.61,	Norm: 36.19
#
# 18:42:07 | Episode: 4 | Steps done: 6000 | Gathering rollout (currently 23984)
# 18:42:22 | Episode: 4 | Training for 20 epochs
# 18:42:24 | Episode: 4 | Updating target network...
# 18:42:24 | Episode: 4 | Rewards:
# 	Reward: [ 56. -18.  75.  20.] | Avg Reward: 25.0 | Loss: 7.3320 | ε: 0.990 | LR: 9.76e-06
# 	Metrics - ['frags: 0', 'hits: 58', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 5', 'survival: -31', 'health_pickup: 1']
# 	Actions - Noop: 341, Move Forward: 1069, Attack: 911, Move Left: 654, Move Right: 629, Turn Left: 920, Turn Right: 955, Jump: 521
# 18:42:24 | Episode: 4 | Running quick evaluation...
# Environment Seed: [796 389]
# Host 63699
# Player 63699
# Episode 4 | encoders       | Shape: [2, 768],	Mean: 2.40,	Std: 4.45,	Norm: 197.97
# Episode 4 | head_first     | Shape: [2, 1024],	Mean: 2.66,	Std: 5.12,	Norm: 261.03
# Episode 4 | value_head     | Shape: [2, 1],	Mean: -3.79,	Std: 2.81,	Norm: 6.04
# Episode 4 | advantage_head | Shape: [2, 8],	Mean: -3.40,	Std: 8.46,	Norm: 35.46
#
# 18:42:27 | Episode: 5 | Steps done: 7500 | Gathering rollout (currently 25000)
# 18:42:42 | Episode: 5 | Training for 20 epochs
# 18:42:43 | Episode: 5 | Updating target network...
# 18:42:43 | Episode: 5 | Rewards:
# 	Reward: [103.  -7. -18. -46.] | Avg Reward: 22.0 | Loss: 6.3589 | ε: 0.988 | LR: 9.65e-06
# 	Metrics - ['frags: 0', 'hits: 97', 'damage_taken: -4', 'movement: 0', 'ammo_efficiency: 10', 'survival: -97', 'health_pickup: 2']
# 	Actions - Noop: 306, Move Forward: 1049, Attack: 836, Move Left: 658, Move Right: 638, Turn Left: 992, Turn Right: 988, Jump: 533
# 18:42:43 | Episode: 5 | Running quick evaluation...
# Environment Seed: [232 329]
# Host 63708
# Player 63708
# Episode 5 | encoders       | Shape: [2, 768],	Mean: 2.48,	Std: 4.48,	Norm: 200.61
# Episode 5 | head_first     | Shape: [2, 1024],	Mean: 2.72,	Std: 5.20,	Norm: 265.53
# Episode 5 | value_head     | Shape: [2, 1],	Mean: -2.75,	Std: 2.71,	Norm: 4.74
# Episode 5 | advantage_head | Shape: [2, 8],	Mean: -1.07,	Std: 10.08,	Norm: 39.29
#
# 18:42:47 | Episode: 6 | Steps done: 9000 | Gathering rollout (currently 25000)
# 18:43:02 | Episode: 6 | Training for 20 epochs
# 18:43:04 | Episode: 6 | Updating target network...
# 18:43:04 | Episode: 6 | Rewards:
# 	Reward: [136. -24. 224.   1.] | Avg Reward: 31.0 | Loss: 6.8957 | ε: 0.986 | LR: 9.52e-06
# 	Metrics - ['frags: 0', 'hits: 117', 'damage_taken: -2', 'movement: 0', 'ammo_efficiency: 9', 'survival: -42', 'health_pickup: 2']
# 	Actions - Noop: 309, Move Forward: 1108, Attack: 880, Move Left: 676, Move Right: 642, Turn Left: 913, Turn Right: 985, Jump: 487
# 18:43:04 | Episode: 6 | Running quick evaluation...
# Environment Seed: [ 287 1129]
# Host 63722
# Player 63722
# Episode 6 | encoders       | Shape: [2, 768],	Mean: 2.34,	Std: 4.44,	Norm: 196.77
# Episode 6 | head_first     | Shape: [2, 1024],	Mean: 2.59,	Std: 4.87,	Norm: 249.53
# Episode 6 | value_head     | Shape: [2, 1],	Mean: 1.05,	Std: 3.81,	Norm: 4.09
# Episode 6 | advantage_head | Shape: [2, 8],	Mean: -0.17,	Std: 9.46,	Norm: 36.64
#
# 18:43:07 | Episode: 7 | Steps done: 10500 | Gathering rollout (currently 25000)
# 18:43:22 | Episode: 7 | Training for 20 epochs
# 18:43:24 | Episode: 7 | Updating target network...
# 18:43:24 | Episode: 7 | Rewards:
# 	Reward: [ 89. -18.  86. 152.] | Avg Reward: 37.0 | Loss: 6.6479 | ε: 0.984 | LR: 9.38e-06
# 	Metrics - ['frags: 0', 'hits: 90', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 6', 'survival: -21', 'health_pickup: 2']
# 	Actions - Noop: 300, Move Forward: 1118, Attack: 874, Move Left: 673, Move Right: 652, Turn Left: 946, Turn Right: 947, Jump: 490
# 18:43:24 | Episode: 7 | Running quick evaluation...
# Environment Seed: [1543 1511]
# Host 63737
# Player 63737
# Episode 7 | encoders       | Shape: [2, 768],	Mean: 2.80,	Std: 4.98,	Norm: 223.69
# Episode 7 | head_first     | Shape: [2, 1024],	Mean: 3.17,	Std: 5.97,	Norm: 305.99
# Episode 7 | value_head     | Shape: [2, 1],	Mean: -4.23,	Std: 5.11,	Norm: 7.87
# Episode 7 | advantage_head | Shape: [2, 8],	Mean: -3.28,	Std: 10.84,	Norm: 43.98
#
# 18:43:28 | Episode: 8 | Steps done: 12000 | Gathering rollout (currently 25000)
# 18:43:42 | Episode: 8 | Training for 20 epochs
# 18:43:43 | Episode: 8 | Updating target network...
# 18:43:43 | Episode: 8 | Rewards:
# 	Reward: [-18. -18. -18.  34.] | Avg Reward: 32.0 | Loss: 7.0425 | ε: 0.982 | LR: 9.22e-06
# 	Metrics - ['frags: 0', 'hits: 12', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 2', 'survival: -20', 'health_pickup: 0']
# 	Actions - Noop: 322, Move Forward: 1038, Attack: 904, Move Left: 695, Move Right: 599, Turn Left: 984, Turn Right: 951, Jump: 507
# 18:43:43 | Episode: 8 | Running quick evaluation...
# Environment Seed: [1409 1701]
# Host 63761
# Player 63761
# Episode 8 | encoders       | Shape: [2, 768],	Mean: 2.57,	Std: 4.72,	Norm: 210.76
# Episode 8 | head_first     | Shape: [2, 1024],	Mean: 2.87,	Std: 5.46,	Norm: 279.15
# Episode 8 | value_head     | Shape: [2, 1],	Mean: 10.48,	Std: 6.17,	Norm: 16.05
# Episode 8 | advantage_head | Shape: [2, 8],	Mean: -4.43,	Std: 7.14,	Norm: 32.85
#
# 18:43:47 | Episode: 9 | Steps done: 13500 | Gathering rollout (currently 25000)
# 18:44:02 | Episode: 9 | Training for 20 epochs
# 18:44:03 | Episode: 9 | Updating target network...
# 18:44:03 | Episode: 9 | Rewards:
# 	Reward: [ 97. -40. 173.  15.] | Avg Reward: 35.0 | Loss: 6.6064 | ε: 0.980 | LR: 9.05e-06
# 	Metrics - ['frags: 0', 'hits: 122', 'damage_taken: -4', 'movement: 0', 'ammo_efficiency: 11', 'survival: -71', 'health_pickup: 3']
# 	Actions - Noop: 317, Move Forward: 1067, Attack: 881, Move Left: 624, Move Right: 623, Turn Left: 965, Turn Right: 1028, Jump: 495
# 18:44:03 | Episode: 9 | Running quick evaluation...
# Environment Seed: [1182 1804]
# Host 63776
# Player 63776
# Episode 9 | encoders       | Shape: [2, 768],	Mean: 2.55,	Std: 4.46,	Norm: 201.44
# Episode 9 | head_first     | Shape: [2, 1024],	Mean: 2.71,	Std: 5.17,	Norm: 264.04
# Episode 9 | value_head     | Shape: [2, 1],	Mean: 0.08,	Std: 0.78,	Norm: 0.79
# Episode 9 | advantage_head | Shape: [2, 8],	Mean: -0.66,	Std: 9.80,	Norm: 38.07
#
# 18:44:07 | Episode: 10 | Steps done: 15000 | Gathering rollout (currently 25000)
# 18:44:21 | Episode: 10 | Training for 20 epochs
# 18:44:22 | Episode: 10 | Updating target network...
# 18:44:22 | Episode: 10 | Rewards:
# 	Reward: [-101.  136.  -18.   58.] | Avg Reward: 33.0 | Loss: 7.4494 | ε: 0.978 | LR: 8.85e-06
# 	Metrics - ['frags: 0', 'hits: 55', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 4', 'survival: -40', 'health_pickup: 0']
# 	Actions - Noop: 318, Move Forward: 1072, Attack: 954, Move Left: 681, Move Right: 607, Turn Left: 959, Turn Right: 911, Jump: 498
# 18:44:22 | Episode: 10 | Running quick evaluation...
# Environment Seed: [1104 1733]
# Host 63799
# Player 63799
# Episode 10 | encoders       | Shape: [2, 768],	Mean: 2.40,	Std: 4.40,	Norm: 196.62
# Episode 10 | head_first     | Shape: [2, 1024],	Mean: 2.48,	Std: 4.86,	Norm: 246.65
# Episode 10 | value_head     | Shape: [2, 1],	Mean: -5.63,	Std: 1.60,	Norm: 8.12
# Episode 10 | advantage_head | Shape: [2, 8],	Mean: 0.69,	Std: 7.57,	Norm: 29.46
#
# Successfully stored the model: runs/20250622_183846/backups/backup_model_20250622_184424.pt
# 18:44:25 | Episode: 11 | Steps done: 16500 | Gathering rollout (currently 25000)
# 18:44:40 | Episode: 11 | Training for 20 epochs
# 18:44:41 | Episode: 11 | Updating target network...
# 18:44:41 | Episode: 11 | Rewards:
# 	Reward: [ 31. -18. -18. 328.] | Avg Reward: 37.0 | Loss: 7.0291 | ε: 0.976 | LR: 8.65e-06
# 	Metrics - ['frags: 0', 'hits: 122', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 5', 'survival: -49', 'health_pickup: 3']
# 	Actions - Noop: 318, Move Forward: 1075, Attack: 865, Move Left: 645, Move Right: 639, Turn Left: 989, Turn Right: 976, Jump: 493
# 18:44:41 | Episode: 11 | Running quick evaluation...
# Environment Seed: [1494  161]
# Host 63827
# Player 63827
# Episode 11 | encoders       | Shape: [2, 768],	Mean: 2.54,	Std: 4.66,	Norm: 207.90
# Episode 11 | head_first     | Shape: [2, 1024],	Mean: 2.92,	Std: 5.73,	Norm: 291.17
# Episode 11 | value_head     | Shape: [2, 1],	Mean: -11.74,	Std: 5.57,	Norm: 17.52
# Episode 11 | advantage_head | Shape: [2, 8],	Mean: -0.30,	Std: 10.46,	Norm: 40.52
#
# 18:44:45 | Episode: 12 | Steps done: 18000 | Gathering rollout (currently 25000)
# 18:44:59 | Episode: 12 | Training for 20 epochs
# 18:45:01 | Episode: 12 | Updating target network...
# 18:45:01 | Episode: 12 | Rewards:
# 	Reward: [-18. -18.   9. 111.] | Avg Reward: 36.0 | Loss: 7.6797 | ε: 0.974 | LR: 8.42e-06
# 	Metrics - ['frags: 0', 'hits: 37', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 3', 'survival: -20', 'health_pickup: 0']
# 	Actions - Noop: 286, Move Forward: 1072, Attack: 947, Move Left: 635, Move Right: 672, Turn Left: 969, Turn Right: 934, Jump: 485
# 18:45:01 | Episode: 12 | Running quick evaluation...
# Environment Seed: [ 77 339]
# Host 63856
# Player 63856
# Episode 12 | encoders       | Shape: [2, 768],	Mean: 2.41,	Std: 4.48,	Norm: 199.20
# Episode 12 | head_first     | Shape: [2, 1024],	Mean: 2.86,	Std: 5.36,	Norm: 274.67
# Episode 12 | value_head     | Shape: [2, 1],	Mean: -1.30,	Std: 1.00,	Norm: 2.09
# Episode 12 | advantage_head | Shape: [2, 8],	Mean: 0.06,	Std: 8.01,	Norm: 31.02
#
# 18:45:04 | Episode: 13 | Steps done: 19500 | Gathering rollout (currently 25000)
# 18:45:19 | Episode: 13 | Training for 20 epochs
# 18:45:20 | Episode: 13 | Updating target network...
# 18:45:20 | Episode: 13 | Rewards:
# 	Reward: [ 38.  56.  88. -61.] | Avg Reward: 36.0 | Loss: 7.1053 | ε: 0.972 | LR: 8.19e-06
# 	Metrics - ['frags: 0', 'hits: 55', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 5', 'survival: -31', 'health_pickup: 2']
# 	Actions - Noop: 327, Move Forward: 1025, Attack: 928, Move Left: 649, Move Right: 614, Turn Left: 960, Turn Right: 968, Jump: 529
# 18:45:20 | Episode: 13 | Running quick evaluation...
# Environment Seed: [  93 1914]
# Host 63884
# Player 63884
# Episode 13 | encoders       | Shape: [2, 768],	Mean: 2.26,	Std: 4.37,	Norm: 192.72
# Episode 13 | head_first     | Shape: [2, 1024],	Mean: 2.72,	Std: 5.19,	Norm: 265.21
# Episode 13 | value_head     | Shape: [2, 1],	Mean: -6.91,	Std: 11.13,	Norm: 14.81
# Episode 13 | advantage_head | Shape: [2, 8],	Mean: 2.57,	Std: 11.65,	Norm: 46.28
#
# 18:45:23 | Episode: 14 | Steps done: 21000 | Gathering rollout (currently 25000)
# 18:45:38 | Episode: 14 | Training for 20 epochs
# 18:45:39 | Episode: 14 | Updating target network...
# 18:45:39 | Episode: 14 | Rewards:
# 	Reward: [111. -18.  86. 138.] | Avg Reward: 39.0 | Loss: 7.6423 | ε: 0.970 | LR: 7.94e-06
# 	Metrics - ['frags: 0', 'hits: 93', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 5', 'survival: -20', 'health_pickup: 0']
# 	Actions - Noop: 323, Move Forward: 1054, Attack: 922, Move Left: 680, Move Right: 641, Turn Left: 888, Turn Right: 960, Jump: 532
# 18:45:39 | Episode: 14 | Running quick evaluation...
# Environment Seed: [1837 1344]
# Host 63894
# Player 63894
# Episode 14 | encoders       | Shape: [2, 768],	Mean: 2.63,	Std: 4.69,	Norm: 210.83
# Episode 14 | head_first     | Shape: [2, 1024],	Mean: 2.99,	Std: 5.58,	Norm: 286.30
# Episode 14 | value_head     | Shape: [2, 1],	Mean: -0.03,	Std: 0.24,	Norm: 0.24
# Episode 14 | advantage_head | Shape: [2, 8],	Mean: -0.83,	Std: 9.27,	Norm: 36.04
#
# 18:45:44 | Episode: 15 | Steps done: 22500 | Gathering rollout (currently 25000)
# 18:45:59 | Episode: 15 | Training for 20 epochs
# 18:46:00 | Episode: 15 | Updating target network...
# 18:46:00 | Episode: 15 | Rewards:
# 	Reward: [ 73. -88.  90. -18.] | Avg Reward: 37.0 | Loss: 6.6070 | ε: 0.968 | LR: 7.68e-06
# 	Metrics - ['frags: 0', 'hits: 46', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 5', 'survival: -36', 'health_pickup: 0']
# 	Actions - Noop: 315, Move Forward: 1086, Attack: 870, Move Left: 625, Move Right: 660, Turn Left: 943, Turn Right: 941, Jump: 560
# 18:46:00 | Episode: 15 | Running quick evaluation...
# Environment Seed: [ 303 1499]
# Host 63910
# Player 63910
# Episode 15 | encoders       | Shape: [2, 768],	Mean: 2.56,	Std: 4.65,	Norm: 208.15
# Episode 15 | head_first     | Shape: [2, 1024],	Mean: 2.92,	Std: 5.50,	Norm: 281.73
# Episode 15 | value_head     | Shape: [2, 1],	Mean: -0.93,	Std: 3.28,	Norm: 3.54
# Episode 15 | advantage_head | Shape: [2, 8],	Mean: -2.45,	Std: 11.26,	Norm: 44.68
#
# 18:46:03 | Episode: 16 | Steps done: 24000 | Gathering rollout (currently 25000)
# 18:46:18 | Episode: 16 | Training for 20 epochs
# 18:46:19 | Episode: 16 | Updating target network...
# 18:46:19 | Episode: 16 | Rewards:
# 	Reward: [-18. -18. 111.   9.] | Avg Reward: 36.0 | Loss: 6.7917 | ε: 0.967 | LR: 7.41e-06
# 	Metrics - ['frags: 0', 'hits: 37', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 3', 'survival: -20', 'health_pickup: 0']
# 	Actions - Noop: 338, Move Forward: 1022, Attack: 855, Move Left: 697, Move Right: 671, Turn Left: 952, Turn Right: 929, Jump: 536
# 18:46:19 | Episode: 16 | Running quick evaluation...
# Environment Seed: [ 915 1333]
# Host 63920
# Player 63920
# Episode 16 | encoders       | Shape: [2, 768],	Mean: 2.50,	Std: 4.71,	Norm: 208.89
# Episode 16 | head_first     | Shape: [2, 1024],	Mean: 2.87,	Std: 5.63,	Norm: 285.96
# Episode 16 | value_head     | Shape: [2, 1],	Mean: -10.22,	Std: 16.53,	Norm: 21.96
# Episode 16 | advantage_head | Shape: [2, 8],	Mean: -0.64,	Std: 10.56,	Norm: 40.97
#
# 18:46:22 | Episode: 17 | Steps done: 25500 | Gathering rollout (currently 25000)
# 18:46:37 | Episode: 17 | Training for 20 epochs
# 18:46:38 | Episode: 17 | Updating target network...
# 18:46:38 | Episode: 17 | Rewards:
# 	Reward: [-131.   59.   97.  -18.] | Avg Reward: 34.0 | Loss: 6.4111 | ε: 0.965 | LR: 7.13e-06
# 	Metrics - ['frags: 0', 'hits: 45', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 5', 'survival: -48', 'health_pickup: 1']
# 	Actions - Noop: 317, Move Forward: 1073, Attack: 889, Move Left: 722, Move Right: 638, Turn Left: 976, Turn Right: 888, Jump: 497
# 18:46:38 | Episode: 17 | Running quick evaluation...
# Environment Seed: [1019 1271]
# Host 63928
# Player 63928
# Episode 17 | encoders       | Shape: [2, 768],	Mean: 2.60,	Std: 4.69,	Norm: 210.20
# Episode 17 | head_first     | Shape: [2, 1024],	Mean: 2.95,	Std: 5.53,	Norm: 283.48
# Episode 17 | value_head     | Shape: [2, 1],	Mean: -1.06,	Std: 3.01,	Norm: 3.36
# Episode 17 | advantage_head | Shape: [2, 8],	Mean: -1.71,	Std: 8.70,	Norm: 34.37
#
# 18:46:42 | Episode: 18 | Steps done: 27000 | Gathering rollout (currently 25000)
# 18:46:57 | Episode: 18 | Training for 20 epochs
# 18:46:58 | Episode: 18 | Updating target network...
# 18:46:58 | Episode: 18 | Rewards:
# 	Reward: [  6. -15.   9. -32.] | Avg Reward: 32.0 | Loss: 6.9374 | ε: 0.963 | LR: 6.84e-06
# 	Metrics - ['frags: 0', 'hits: 37', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 5', 'survival: -50', 'health_pickup: 1']
# 	Actions - Noop: 324, Move Forward: 1025, Attack: 899, Move Left: 686, Move Right: 674, Turn Left: 947, Turn Right: 936, Jump: 509
# 18:46:58 | Episode: 18 | Running quick evaluation...
# Environment Seed: [651 229]
# Host 63936
# Player 63936
# Episode 18 | encoders       | Shape: [2, 768],	Mean: 2.57,	Std: 4.72,	Norm: 210.53
# Episode 18 | head_first     | Shape: [2, 1024],	Mean: 2.97,	Std: 5.56,	Norm: 285.00
# Episode 18 | value_head     | Shape: [2, 1],	Mean: -5.60,	Std: 1.13,	Norm: 8.00
# Episode 18 | advantage_head | Shape: [2, 8],	Mean: -3.79,	Std: 7.46,	Norm: 32.61
#
# 18:47:02 | Episode: 19 | Steps done: 28500 | Gathering rollout (currently 25000)
# 18:47:17 | Episode: 19 | Training for 20 epochs
# 18:47:18 | Episode: 19 | Updating target network...
# 18:47:18 | Episode: 19 | Rewards:
# 	Reward: [-19. -18. -18. 214.] | Avg Reward: 32.0 | Loss: 7.2545 | ε: 0.961 | LR: 6.55e-06
# 	Metrics - ['frags: 0', 'hits: 67', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 5', 'survival: -33', 'health_pickup: 1']
# 	Actions - Noop: 342, Move Forward: 1050, Attack: 851, Move Left: 695, Move Right: 624, Turn Left: 943, Turn Right: 971, Jump: 524
# 18:47:18 | Episode: 19 | Running quick evaluation...
# Environment Seed: [ 17 621]
# Host 63946
# Player 63946
# Episode 19 | encoders       | Shape: [2, 768],	Mean: 2.46,	Std: 4.61,	Norm: 204.71
# Episode 19 | head_first     | Shape: [2, 1024],	Mean: 2.91,	Std: 5.44,	Norm: 278.99
# Episode 19 | value_head     | Shape: [2, 1],	Mean: -0.75,	Std: 2.49,	Norm: 2.70
# Episode 19 | advantage_head | Shape: [2, 8],	Mean: -3.01,	Std: 7.26,	Norm: 30.57
#
# 18:47:21 | Episode: 20 | Steps done: 30000 | Gathering rollout (currently 25000)
# 18:47:36 | Episode: 20 | Training for 20 epochs
# 18:47:37 | Episode: 20 | Updating target network...
# 18:47:37 | Episode: 20 | Rewards:
# 	Reward: [-48.  36. -18.  46.] | Avg Reward: 31.0 | Loss: 7.3173 | ε: 0.959 | LR: 6.25e-06
# 	Metrics - ['frags: 0', 'hits: 27', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 4', 'survival: -27', 'health_pickup: 1']
# 	Actions - Noop: 331, Move Forward: 1086, Attack: 909, Move Left: 641, Move Right: 624, Turn Left: 986, Turn Right: 959, Jump: 464
# 18:47:37 | Episode: 20 | Running quick evaluation...
# Environment Seed: [1087 1308]
# Host 63953
# Player 63953
# Episode 20 | encoders       | Shape: [2, 768],	Mean: 2.53,	Std: 4.54,	Norm: 203.48
# Episode 20 | head_first     | Shape: [2, 1024],	Mean: 2.83,	Std: 5.40,	Norm: 276.06
# Episode 20 | value_head     | Shape: [2, 1],	Mean: 0.30,	Std: 3.36,	Norm: 3.39
# Episode 20 | advantage_head | Shape: [2, 8],	Mean: -0.48,	Std: 10.48,	Norm: 40.63
#
# Successfully stored the model: runs/20250622_183846/backups/backup_model_20250622_184740.pt
# 18:47:41 | Episode: 21 | Steps done: 31500 | Gathering rollout (currently 25000)
# 18:47:56 | Episode: 21 | Training for 20 epochs
# 18:47:58 | Episode: 21 | Updating target network...
# 18:47:58 | Episode: 21 | Rewards:
# 	Reward: [-120.  198.  -18.   75.] | Avg Reward: 31.0 | Loss: 7.7294 | ε: 0.957 | LR: 5.94e-06
# 	Metrics - ['frags: 0', 'hits: 107', 'damage_taken: -3', 'movement: 0', 'ammo_efficiency: 9', 'survival: -83', 'health_pickup: 3']
# 	Actions - Noop: 305, Move Forward: 1062, Attack: 974, Move Left: 641, Move Right: 659, Turn Left: 898, Turn Right: 942, Jump: 519
# 18:47:58 | Episode: 21 | Running quick evaluation...
# Environment Seed: [469 115]
# Host 63961
# Player 63961
# Episode 21 | encoders       | Shape: [2, 768],	Mean: 2.41,	Std: 4.37,	Norm: 195.35
# Episode 21 | head_first     | Shape: [2, 1024],	Mean: 2.73,	Std: 5.22,	Norm: 266.43
# Episode 21 | value_head     | Shape: [2, 1],	Mean: -3.67,	Std: 0.77,	Norm: 5.25
# Episode 21 | advantage_head | Shape: [2, 8],	Mean: -1.06,	Std: 10.02,	Norm: 39.04
#
# 18:48:01 | Episode: 22 | Steps done: 33000 | Gathering rollout (currently 25000)
# 18:48:16 | Episode: 22 | Training for 20 epochs
# 18:48:17 | Episode: 22 | Updating target network...
# 18:48:17 | Episode: 22 | Rewards:
# 	Reward: [ 71. -18.  36.  -9.] | Avg Reward: 31.0 | Loss: 6.9042 | ε: 0.955 | LR: 5.63e-06
# 	Metrics - ['frags: 0', 'hits: 35', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 5', 'survival: -22', 'health_pickup: 3']
# 	Actions - Noop: 316, Move Forward: 1014, Attack: 920, Move Left: 653, Move Right: 638, Turn Left: 957, Turn Right: 965, Jump: 537
# 18:48:17 | Episode: 22 | Running quick evaluation...
# Environment Seed: [ 842 1387]
# Host 63982
# Player 63982
# Episode 22 | encoders       | Shape: [2, 768],	Mean: 2.59,	Std: 4.85,	Norm: 215.32
# Episode 22 | head_first     | Shape: [2, 1024],	Mean: 3.03,	Std: 5.61,	Norm: 288.62
# Episode 22 | value_head     | Shape: [2, 1],	Mean: 0.11,	Std: 9.86,	Norm: 9.86
# Episode 22 | advantage_head | Shape: [2, 8],	Mean: -3.03,	Std: 7.94,	Norm: 33.05
#
# 18:48:21 | Episode: 23 | Steps done: 34500 | Gathering rollout (currently 25000)
# 18:48:36 | Episode: 23 | Training for 20 epochs
# 18:48:37 | Episode: 23 | Updating target network...
# 18:48:37 | Episode: 23 | Rewards:
# 	Reward: [-17. -18.  -0. -18.] | Avg Reward: 29.0 | Loss: 6.7938 | ε: 0.953 | LR: 5.32e-06
# 	Metrics - ['frags: 0', 'hits: 27', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 3', 'survival: -46', 'health_pickup: 2']
# 	Actions - Noop: 333, Move Forward: 1040, Attack: 907, Move Left: 633, Move Right: 616, Turn Left: 962, Turn Right: 954, Jump: 555
# 18:48:37 | Episode: 23 | Running quick evaluation...
# Environment Seed: [593 128]
# Host 63991
# Player 63991
# Episode 23 | encoders       | Shape: [2, 768],	Mean: 2.43,	Std: 4.58,	Norm: 203.04
# Episode 23 | head_first     | Shape: [2, 1024],	Mean: 2.72,	Std: 5.19,	Norm: 265.39
# Episode 23 | value_head     | Shape: [2, 1],	Mean: 3.22,	Std: 5.63,	Norm: 7.24
# Episode 23 | advantage_head | Shape: [2, 8],	Mean: -3.55,	Std: 11.34,	Norm: 46.17
#
# 18:48:40 | Episode: 24 | Steps done: 36000 | Gathering rollout (currently 25000)
# 18:48:55 | Episode: 24 | Training for 20 epochs
# 18:48:56 | Episode: 24 | Updating target network...
# 18:48:56 | Episode: 24 | Rewards:
# 	Reward: [ 43. -11. -22.  -0.] | Avg Reward: 28.0 | Loss: 6.9113 | ε: 0.951 | LR: 5.01e-06
# 	Metrics - ['frags: 0', 'hits: 63', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 6', 'survival: -68', 'health_pickup: 2']
# 	Actions - Noop: 324, Move Forward: 1048, Attack: 902, Move Left: 640, Move Right: 650, Turn Left: 934, Turn Right: 973, Jump: 529
# 18:48:56 | Episode: 24 | Running quick evaluation...
# Environment Seed: [1672 1661]
# Host 64009
# Player 64009
# Episode 24 | encoders       | Shape: [2, 768],	Mean: 2.50,	Std: 4.53,	Norm: 202.69
# Episode 24 | head_first     | Shape: [2, 1024],	Mean: 2.76,	Std: 5.26,	Norm: 268.91
# Episode 24 | value_head     | Shape: [2, 1],	Mean: -5.81,	Std: 7.96,	Norm: 11.43
# Episode 24 | advantage_head | Shape: [2, 8],	Mean: -1.62,	Std: 8.66,	Norm: 34.16
#
# 18:49:00 | Episode: 25 | Steps done: 37500 | Gathering rollout (currently 25000)
# 18:49:15 | Episode: 25 | Training for 20 epochs
# 18:49:16 | Episode: 25 | Updating target network...
# 18:49:16 | Episode: 25 | Rewards:
# 	Reward: [-21.  83.  59.  88.] | Avg Reward: 29.0 | Loss: 7.2130 | ε: 0.949 | LR: 4.69e-06
# 	Metrics - ['frags: 0', 'hits: 80', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 6', 'survival: -34', 'health_pickup: 1']
# 	Actions - Noop: 304, Move Forward: 1056, Attack: 920, Move Left: 635, Move Right: 623, Turn Left: 954, Turn Right: 967, Jump: 541
# 18:49:16 | Episode: 25 | Replaying animation...
# 18:50:01 | Episode: 25 | Running quick evaluation...
# Environment Seed: [1512 1990]
# Host 64079
# Player 64079
# Episode 25 | encoders       | Shape: [2, 768],	Mean: 2.62,	Std: 4.62,	Norm: 207.95
# Episode 25 | head_first     | Shape: [2, 1024],	Mean: 2.84,	Std: 5.30,	Norm: 271.94
# Episode 25 | value_head     | Shape: [2, 1],	Mean: 1.67,	Std: 2.30,	Norm: 3.29
# Episode 25 | advantage_head | Shape: [2, 8],	Mean: -0.93,	Std: 6.65,	Norm: 26.03
#
# Successfully stored the model: runs/20250622_183846/best_model_20250622_185023_best-5_max9.pt
# 18:50:24 | Episode: 26 | Steps done: 39000 | Gathering rollout (currently 25000)
# 18:50:40 | Episode: 26 | Training for 20 epochs
# 18:50:41 | Episode: 26 | Updating target network...
# 18:50:41 | Episode: 26 | Rewards:
# 	Reward: [-176.   36.  283.   34.] | Avg Reward: 29.0 | Loss: 6.9683 | ε: 0.947 | LR: 4.38e-06
# 	Metrics - ['frags: 0', 'hits: 98', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 5', 'survival: -60', 'health_pickup: 2']
# 	Actions - Noop: 327, Move Forward: 1088, Attack: 900, Move Left: 637, Move Right: 631, Turn Left: 943, Turn Right: 949, Jump: 525
# 18:50:41 | Episode: 26 | Running quick evaluation...
# Environment Seed: [ 180 1685]
# Host 64095
# Player 64095
# Episode 26 | encoders       | Shape: [2, 768],	Mean: 2.53,	Std: 4.54,	Norm: 203.74
# Episode 26 | head_first     | Shape: [2, 1024],	Mean: 2.59,	Std: 4.95,	Norm: 252.95
# Episode 26 | value_head     | Shape: [2, 1],	Mean: 0.19,	Std: 4.89,	Norm: 4.90
# Episode 26 | advantage_head | Shape: [2, 8],	Mean: -3.28,	Std: 6.21,	Norm: 27.39
#
# 18:50:45 | Episode: 27 | Steps done: 40500 | Gathering rollout (currently 25000)
# 18:51:04 | Episode: 27 | Training for 20 epochs
# 18:51:05 | Episode: 27 | Updating target network...
# 18:51:05 | Episode: 27 | Rewards:
# 	Reward: [24.  9. 61.  9.] | Avg Reward: 29.0 | Loss: 6.6462 | ε: 0.945 | LR: 4.07e-06
# 	Metrics - ['frags: 0', 'hits: 56', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 5', 'survival: -34', 'health_pickup: 0']
# 	Actions - Noop: 314, Move Forward: 1066, Attack: 923, Move Left: 622, Move Right: 691, Turn Left: 884, Turn Right: 974, Jump: 526
# 18:51:05 | Episode: 27 | Running quick evaluation...
# Environment Seed: [1993  719]
# Host 64106
# Player 64106
# Episode 27 | encoders       | Shape: [2, 768],	Mean: 2.60,	Std: 4.87,	Norm: 216.38
# Episode 27 | head_first     | Shape: [2, 1024],	Mean: 3.12,	Std: 5.89,	Norm: 301.68
# Episode 27 | value_head     | Shape: [2, 1],	Mean: -3.57,	Std: 1.95,	Norm: 5.41
# Episode 27 | advantage_head | Shape: [2, 8],	Mean: -1.63,	Std: 11.58,	Norm: 45.31
#
# 18:51:08 | Episode: 28 | Steps done: 42000 | Gathering rollout (currently 25000)
# 18:51:27 | Episode: 28 | Training for 20 epochs
# 18:51:28 | Episode: 28 | Updating target network...
# 18:51:28 | Episode: 28 | Rewards:
# 	Reward: [-295.  375.    2.  -18.] | Avg Reward: 29.0 | Loss: 7.2503 | ε: 0.944 | LR: 3.76e-06
# 	Metrics - ['frags: 0', 'hits: 113', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 5', 'survival: -103', 'health_pickup: 1']
# 	Actions - Noop: 328, Move Forward: 1157, Attack: 899, Move Left: 645, Move Right: 612, Turn Left: 918, Turn Right: 938, Jump: 503
# 18:51:28 | Episode: 28 | Running quick evaluation...
# Environment Seed: [299 745]
# Host 64117
# Player 64117
# Episode 28 | encoders       | Shape: [2, 768],	Mean: 2.60,	Std: 4.65,	Norm: 208.80
# Episode 28 | head_first     | Shape: [2, 1024],	Mean: 2.80,	Std: 5.36,	Norm: 273.70
# Episode 28 | value_head     | Shape: [2, 1],	Mean: 12.19,	Std: 6.84,	Norm: 18.55
# Episode 28 | advantage_head | Shape: [2, 8],	Mean: -2.45,	Std: 7.00,	Norm: 28.84
#
# 18:51:33 | Episode: 29 | Steps done: 43500 | Gathering rollout (currently 25000)
# 18:51:52 | Episode: 29 | Training for 20 epochs
# 18:51:53 | Episode: 29 | Updating target network...
# 18:51:53 | Episode: 29 | Rewards:
# 	Reward: [-37. -66. 140. 174.] | Avg Reward: 29.0 | Loss: 7.8859 | ε: 0.942 | LR: 3.46e-06
# 	Metrics - ['frags: 0', 'hits: 107', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 8', 'survival: -65', 'health_pickup: 3']
# 	Actions - Noop: 277, Move Forward: 1047, Attack: 901, Move Left: 666, Move Right: 608, Turn Left: 957, Turn Right: 1007, Jump: 537
# 18:51:53 | Episode: 29 | Running quick evaluation...
# Environment Seed: [ 606 1777]
# Host 64127
# Player 64127
# Episode 29 | encoders       | Shape: [2, 768],	Mean: 2.37,	Std: 4.51,	Norm: 199.67
# Episode 29 | head_first     | Shape: [2, 1024],	Mean: 2.91,	Std: 5.33,	Norm: 274.89
# Episode 29 | value_head     | Shape: [2, 1],	Mean: 3.15,	Std: 6.88,	Norm: 8.19
# Episode 29 | advantage_head | Shape: [2, 8],	Mean: -3.14,	Std: 8.91,	Norm: 36.72
#
# 18:51:57 | Episode: 30 | Steps done: 45000 | Gathering rollout (currently 25000)
# 18:52:16 | Episode: 30 | Training for 20 epochs
# 18:52:17 | Episode: 30 | Updating target network...
# 18:52:17 | Episode: 30 | Rewards:
# 	Reward: [-25. -18. -29. 242.] | Avg Reward: 30.0 | Loss: 6.9786 | ε: 0.940 | LR: 3.17e-06
# 	Metrics - ['frags: 0', 'hits: 93', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 6', 'survival: -58', 'health_pickup: 2']
# 	Actions - Noop: 357, Move Forward: 1041, Attack: 875, Move Left: 639, Move Right: 651, Turn Left: 933, Turn Right: 974, Jump: 530
# 18:52:17 | Episode: 30 | Running quick evaluation...
# Environment Seed: [1020 1946]
# Host 64136
# Player 64136
# Episode 30 | encoders       | Shape: [2, 768],	Mean: 2.50,	Std: 4.59,	Norm: 204.91
# Episode 30 | head_first     | Shape: [2, 1024],	Mean: 2.85,	Std: 5.51,	Norm: 280.46
# Episode 30 | value_head     | Shape: [2, 1],	Mean: 2.99,	Std: 1.66,	Norm: 4.54
# Episode 30 | advantage_head | Shape: [2, 8],	Mean: -2.56,	Std: 10.49,	Norm: 41.92
#
# Successfully stored the model: runs/20250622_183846/backups/backup_model_20250622_185219.pt
# 18:52:21 | Episode: 31 | Steps done: 46500 | Gathering rollout (currently 25000)
# 18:52:40 | Episode: 31 | Training for 20 epochs
# 18:52:41 | Episode: 31 | Updating target network...
# 18:52:41 | Episode: 31 | Rewards:
# 	Reward: [-18. -18.   9.  38.] | Avg Reward: 29.0 | Loss: 6.0651 | ε: 0.938 | LR: 2.88e-06
# 	Metrics - ['frags: 0', 'hits: 37', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 3', 'survival: -37', 'health_pickup: 0']
# 	Actions - Noop: 346, Move Forward: 1005, Attack: 910, Move Left: 706, Move Right: 591, Turn Left: 947, Turn Right: 972, Jump: 523
# 18:52:41 | Episode: 31 | Running quick evaluation...
# Environment Seed: [944 736]
# Host 64146
# Player 64146
# Episode 31 | encoders       | Shape: [2, 768],	Mean: 2.58,	Std: 4.92,	Norm: 217.71
# Episode 31 | head_first     | Shape: [2, 1024],	Mean: 3.10,	Std: 5.82,	Norm: 298.64
# Episode 31 | value_head     | Shape: [2, 1],	Mean: 0.81,	Std: 1.95,	Norm: 2.26
# Episode 31 | advantage_head | Shape: [2, 8],	Mean: -2.50,	Std: 9.14,	Norm: 36.80
#
# 18:52:45 | Episode: 32 | Steps done: 48000 | Gathering rollout (currently 25000)
# 18:53:04 | Episode: 32 | Training for 20 epochs
# 18:53:05 | Episode: 32 | Updating target network...
# 18:53:05 | Episode: 32 | Rewards:
# 	Reward: [19. 14. 86.  3.] | Avg Reward: 29.0 | Loss: 6.7396 | ε: 0.936 | LR: 2.60e-06
# 	Metrics - ['frags: 0', 'hits: 55', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 5', 'survival: -30', 'health_pickup: 1']
# 	Actions - Noop: 338, Move Forward: 1052, Attack: 894, Move Left: 644, Move Right: 647, Turn Left: 936, Turn Right: 978, Jump: 511
# 18:53:05 | Episode: 32 | Running quick evaluation...
# Environment Seed: [457  84]
# Host 64157
# Player 64157
# Episode 32 | encoders       | Shape: [2, 768],	Mean: 2.68,	Std: 4.76,	Norm: 214.09
# Episode 32 | head_first     | Shape: [2, 1024],	Mean: 2.85,	Std: 5.50,	Norm: 280.41
# Episode 32 | value_head     | Shape: [2, 1],	Mean: 5.77,	Std: 1.93,	Norm: 8.38
# Episode 32 | advantage_head | Shape: [2, 8],	Mean: -2.05,	Std: 10.74,	Norm: 42.40
#
# 18:53:10 | Episode: 33 | Steps done: 49500 | Gathering rollout (currently 25000)
# 18:53:29 | Episode: 33 | Training for 20 epochs
# 18:53:30 | Episode: 33 | Updating target network...
# 18:53:30 | Episode: 33 | Rewards:
# 	Reward: [-333.   19.  136.    9.] | Avg Reward: 27.0 | Loss: 7.0047 | ε: 0.934 | LR: 2.33e-06
# 	Metrics - ['frags: 0', 'hits: 75', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 7', 'survival: -123', 'health_pickup: 1']
# 	Actions - Noop: 306, Move Forward: 1000, Attack: 921, Move Left: 689, Move Right: 659, Turn Left: 931, Turn Right: 970, Jump: 524
# 18:53:30 | Episode: 33 | Running quick evaluation...
# Environment Seed: [1074 1183]
# Host 64169
# Player 64169
# Episode 33 | encoders       | Shape: [2, 768],	Mean: 2.53,	Std: 4.68,	Norm: 208.58
# Episode 33 | head_first     | Shape: [2, 1024],	Mean: 2.77,	Std: 5.19,	Norm: 266.00
# Episode 33 | value_head     | Shape: [2, 1],	Mean: 5.56,	Std: 1.78,	Norm: 8.06
# Episode 33 | advantage_head | Shape: [2, 8],	Mean: -3.14,	Std: 9.85,	Norm: 40.15
#
# 18:53:33 | Episode: 34 | Steps done: 51000 | Gathering rollout (currently 25000)
# 18:53:52 | Episode: 34 | Training for 20 epochs
# 18:53:54 | Episode: 34 | Updating target network...
# 18:53:54 | Episode: 34 | Rewards:
# 	Reward: [-14.   6.  36. -18.] | Avg Reward: 26.0 | Loss: 6.4467 | ε: 0.932 | LR: 2.07e-06
# 	Metrics - ['frags: 0', 'hits: 21', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 4', 'survival: -24', 'health_pickup: 2']
# 	Actions - Noop: 322, Move Forward: 1072, Attack: 874, Move Left: 668, Move Right: 661, Turn Left: 910, Turn Right: 984, Jump: 509
# 18:53:54 | Episode: 34 | Running quick evaluation...
# Environment Seed: [244 321]
# Host 64178
# Player 64178
# Episode 34 | encoders       | Shape: [2, 768],	Mean: 2.52,	Std: 4.40,	Norm: 198.55
# Episode 34 | head_first     | Shape: [2, 1024],	Mean: 2.79,	Std: 5.23,	Norm: 268.03
# Episode 34 | value_head     | Shape: [2, 1],	Mean: -5.75,	Std: 6.91,	Norm: 10.67
# Episode 34 | advantage_head | Shape: [2, 8],	Mean: -0.61,	Std: 9.21,	Norm: 35.76
#
# 18:53:57 | Episode: 35 | Steps done: 52500 | Gathering rollout (currently 25000)
# 18:54:16 | Episode: 35 | Training for 20 epochs
# 18:54:17 | Episode: 35 | Updating target network...
# 18:54:17 | Episode: 35 | Rewards:
# 	Reward: [ 76. -26. -51.  34.] | Avg Reward: 26.0 | Loss: 6.5929 | ε: 0.930 | LR: 1.82e-06
# 	Metrics - ['frags: 0', 'hits: 83', 'damage_taken: -2', 'movement: 0', 'ammo_efficiency: 6', 'survival: -81', 'health_pickup: 1']
# 	Actions - Noop: 334, Move Forward: 992, Attack: 901, Move Left: 697, Move Right: 624, Turn Left: 970, Turn Right: 951, Jump: 531
# 18:54:17 | Episode: 35 | Running quick evaluation...
# Environment Seed: [ 779 1688]
# Host 64186
# Player 64186
# Episode 35 | encoders       | Shape: [2, 768],	Mean: 2.50,	Std: 4.50,	Norm: 201.71
# Episode 35 | head_first     | Shape: [2, 1024],	Mean: 2.86,	Std: 5.46,	Norm: 278.81
# Episode 35 | value_head     | Shape: [2, 1],	Mean: -2.25,	Std: 1.40,	Norm: 3.48
# Episode 35 | advantage_head | Shape: [2, 8],	Mean: 0.00,	Std: 12.98,	Norm: 50.26
#
# 18:54:21 | Episode: 36 | Steps done: 54000 | Gathering rollout (currently 25000)
# 18:54:40 | Episode: 36 | Training for 20 epochs
# 18:54:42 | Episode: 36 | Updating target network...
# 18:54:42 | Episode: 36 | Rewards:
# 	Reward: [ 1. 83. 47.  9.] | Avg Reward: 26.0 | Loss: 6.7534 | ε: 0.929 | LR: 1.59e-06
# 	Metrics - ['frags: 0', 'hits: 75', 'damage_taken: -2', 'movement: 0', 'ammo_efficiency: 7', 'survival: -47', 'health_pickup: 2']
# 	Actions - Noop: 307, Move Forward: 1080, Attack: 858, Move Left: 656, Move Right: 659, Turn Left: 958, Turn Right: 949, Jump: 533
# 18:54:42 | Episode: 36 | Running quick evaluation...
# Environment Seed: [1107  647]
# Host 64197
# Player 64197
# Episode 36 | encoders       | Shape: [2, 768],	Mean: 2.53,	Std: 4.51,	Norm: 202.40
# Episode 36 | head_first     | Shape: [2, 1024],	Mean: 2.89,	Std: 5.35,	Norm: 274.90
# Episode 36 | value_head     | Shape: [2, 1],	Mean: -0.69,	Std: 4.97,	Norm: 5.06
# Episode 36 | advantage_head | Shape: [2, 8],	Mean: -1.39,	Std: 11.10,	Norm: 43.33
#
# 18:54:46 | Episode: 37 | Steps done: 55500 | Gathering rollout (currently 25000)
# 18:55:05 | Episode: 37 | Training for 20 epochs
# 18:55:06 | Episode: 37 | Updating target network...
# 18:55:06 | Episode: 37 | Rewards:
# 	Reward: [ 82. -18. 113.  61.] | Avg Reward: 27.0 | Loss: 6.8243 | ε: 0.927 | LR: 1.36e-06
# 	Metrics - ['frags: 0', 'hits: 75', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 6', 'survival: -23', 'health_pickup: 2']
# 	Actions - Noop: 332, Move Forward: 1039, Attack: 842, Move Left: 649, Move Right: 692, Turn Left: 966, Turn Right: 939, Jump: 541
# 18:55:06 | Episode: 37 | Running quick evaluation...
# Environment Seed: [ 332 1285]
# Host 64211
# Player 64211
# Episode 37 | encoders       | Shape: [2, 768],	Mean: 2.42,	Std: 4.50,	Norm: 200.34
# Episode 37 | head_first     | Shape: [2, 1024],	Mean: 2.63,	Std: 5.28,	Norm: 266.78
# Episode 37 | value_head     | Shape: [2, 1],	Mean: -0.76,	Std: 5.37,	Norm: 5.48
# Episode 37 | advantage_head | Shape: [2, 8],	Mean: 0.06,	Std: 10.26,	Norm: 39.74
#
# 18:55:09 | Episode: 38 | Steps done: 57000 | Gathering rollout (currently 25000)
# 18:55:28 | Episode: 38 | Training for 20 epochs
# 18:55:29 | Episode: 38 | Updating target network...
# 18:55:29 | Episode: 38 | Rewards:
# 	Reward: [ 33.  34. -18. -18.] | Avg Reward: 26.0 | Loss: 6.7093 | ε: 0.925 | LR: 1.16e-06
# 	Metrics - ['frags: 0', 'hits: 43', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 3', 'survival: -39', 'health_pickup: 0']
# 	Actions - Noop: 300, Move Forward: 1080, Attack: 825, Move Left: 696, Move Right: 623, Turn Left: 1016, Turn Right: 918, Jump: 542
# 18:55:29 | Episode: 38 | Running quick evaluation...
# Environment Seed: [1359 1591]
# Host 64219
# Player 64219
# Episode 38 | encoders       | Shape: [2, 768],	Mean: 2.82,	Std: 5.01,	Norm: 225.39
# Episode 38 | head_first     | Shape: [2, 1024],	Mean: 3.17,	Std: 6.04,	Norm: 308.58
# Episode 38 | value_head     | Shape: [2, 1],	Mean: 3.60,	Std: 3.71,	Norm: 6.30
# Episode 38 | advantage_head | Shape: [2, 8],	Mean: -1.82,	Std: 9.66,	Norm: 38.11
#
# 18:55:33 | Episode: 39 | Steps done: 58500 | Gathering rollout (currently 25000)
# 18:55:52 | Episode: 39 | Training for 20 epochs
# 18:55:53 | Episode: 39 | Updating target network...
# 18:55:53 | Episode: 39 | Rewards:
# 	Reward: [  8. -18.  -6.  64.] | Avg Reward: 26.0 | Loss: 6.3681 | ε: 0.923 | LR: 9.64e-07
# 	Metrics - ['frags: 0', 'hits: 27', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 4', 'survival: -21', 'health_pickup: 2']
# 	Actions - Noop: 326, Move Forward: 1110, Attack: 897, Move Left: 655, Move Right: 638, Turn Left: 879, Turn Right: 976, Jump: 519
# 18:55:53 | Episode: 39 | Running quick evaluation...
# Environment Seed: [ 670 1014]
# Host 64228
# Player 64228
# Episode 39 | encoders       | Shape: [2, 768],	Mean: 2.66,	Std: 4.89,	Norm: 218.08
# Episode 39 | head_first     | Shape: [2, 1024],	Mean: 3.03,	Std: 5.57,	Norm: 286.93
# Episode 39 | value_head     | Shape: [2, 1],	Mean: -3.93,	Std: 5.74,	Norm: 7.99
# Episode 39 | advantage_head | Shape: [2, 8],	Mean: -1.26,	Std: 9.59,	Norm: 37.46
#
# 18:55:56 | Episode: 40 | Steps done: 60000 | Gathering rollout (currently 25000)
# 18:56:16 | Episode: 40 | Training for 20 epochs
# 18:56:17 | Episode: 40 | Updating target network...
# 18:56:17 | Episode: 40 | Rewards:
# 	Reward: [-12. -27. -18. 137.] | Avg Reward: 26.0 | Loss: 6.6458 | ε: 0.921 | LR: 7.88e-07
# 	Metrics - ['frags: 0', 'hits: 48', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 5', 'survival: -35', 'health_pickup: 2']
# 	Actions - Noop: 352, Move Forward: 1046, Attack: 935, Move Left: 695, Move Right: 616, Turn Left: 907, Turn Right: 925, Jump: 524
# 18:56:17 | Episode: 40 | Running quick evaluation...
# Environment Seed: [ 77 101]
# Host 64236
# Player 64236
# Episode 40 | encoders       | Shape: [2, 768],	Mean: 2.67,	Std: 4.63,	Norm: 209.52
# Episode 40 | head_first     | Shape: [2, 1024],	Mean: 2.94,	Std: 5.48,	Norm: 281.20
# Episode 40 | value_head     | Shape: [2, 1],	Mean: -3.53,	Std: 1.17,	Norm: 5.12
# Episode 40 | advantage_head | Shape: [2, 8],	Mean: -4.80,	Std: 8.81,	Norm: 39.15
#
# Successfully stored the model: runs/20250622_183846/backups/backup_model_20250622_185619.pt
# 18:56:21 | Episode: 41 | Steps done: 61500 | Gathering rollout (currently 25000)
# 18:56:40 | Episode: 41 | Training for 20 epochs
# 18:56:41 | Episode: 41 | Updating target network...
# 18:56:41 | Episode: 41 | Rewards:
# 	Reward: [  9. -18. -59. 113.] | Avg Reward: 25.0 | Loss: 6.3598 | ε: 0.919 | LR: 6.28e-07
# 	Metrics - ['frags: 0', 'hits: 62', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 5', 'survival: -57', 'health_pickup: 1']
# 	Actions - Noop: 295, Move Forward: 1041, Attack: 872, Move Left: 672, Move Right: 691, Turn Left: 951, Turn Right: 930, Jump: 548
# 18:56:41 | Episode: 41 | Running quick evaluation...
# Environment Seed: [ 203 1491]
# Host 64246
# Player 64246
# Episode 41 | encoders       | Shape: [2, 768],	Mean: 2.34,	Std: 4.39,	Norm: 194.79
# Episode 41 | head_first     | Shape: [2, 1024],	Mean: 2.70,	Std: 5.15,	Norm: 263.10
# Episode 41 | value_head     | Shape: [2, 1],	Mean: -1.98,	Std: 3.34,	Norm: 4.36
# Episode 41 | advantage_head | Shape: [2, 8],	Mean: -1.35,	Std: 6.59,	Norm: 26.07
#
# 18:56:44 | Episode: 42 | Steps done: 63000 | Gathering rollout (currently 25000)
# 18:57:04 | Episode: 42 | Training for 20 epochs
# 18:57:05 | Episode: 42 | Updating target network...
# 18:57:05 | Episode: 42 | Rewards:
# 	Reward: [-40.   9. -18. -20.] | Avg Reward: 24.0 | Loss: 6.4916 | ε: 0.918 | LR: 4.85e-07
# 	Metrics - ['frags: 0', 'hits: 62', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 5', 'survival: -88', 'health_pickup: 3']
# 	Actions - Noop: 328, Move Forward: 1080, Attack: 890, Move Left: 654, Move Right: 662, Turn Left: 929, Turn Right: 961, Jump: 496
# 18:57:05 | Episode: 42 | Running quick evaluation...
# Environment Seed: [597 924]
# Host 64268
# Player 64268
# Episode 42 | encoders       | Shape: [2, 768],	Mean: 2.75,	Std: 4.97,	Norm: 222.40
# Episode 42 | head_first     | Shape: [2, 1024],	Mean: 3.21,	Std: 6.02,	Norm: 308.63
# Episode 42 | value_head     | Shape: [2, 1],	Mean: 5.84,	Std: 7.86,	Norm: 11.40
# Episode 42 | advantage_head | Shape: [2, 8],	Mean: -1.06,	Std: 10.28,	Norm: 40.03
#
# 18:57:08 | Episode: 43 | Steps done: 64500 | Gathering rollout (currently 25000)
# 18:57:24 | Episode: 43 | Training for 20 epochs
# 18:57:25 | Episode: 43 | Updating target network...
# 18:57:25 | Episode: 43 | Rewards:
# 	Reward: [ 83. -18. -18.   9.] | Avg Reward: 24.0 | Loss: 5.9674 | ε: 0.916 | LR: 3.61e-07
# 	Metrics - ['frags: 0', 'hits: 31', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 3', 'survival: -21', 'health_pickup: 1']
# 	Actions - Noop: 311, Move Forward: 1042, Attack: 886, Move Left: 639, Move Right: 653, Turn Left: 969, Turn Right: 954, Jump: 546
# 18:57:25 | Episode: 43 | Running quick evaluation...
# Environment Seed: [1034  356]
# Host 64286
# Player 64286
# Episode 43 | encoders       | Shape: [2, 768],	Mean: 2.64,	Std: 4.81,	Norm: 214.97
# Episode 43 | head_first     | Shape: [2, 1024],	Mean: 3.00,	Std: 5.64,	Norm: 289.07
# Episode 43 | value_head     | Shape: [2, 1],	Mean: -1.71,	Std: 17.42,	Norm: 17.59
# Episode 43 | advantage_head | Shape: [2, 8],	Mean: 0.02,	Std: 9.27,	Norm: 35.92
#
# 18:57:28 | Episode: 44 | Steps done: 66000 | Gathering rollout (currently 25000)
# 18:57:44 | Episode: 44 | Training for 20 epochs
# 18:57:45 | Episode: 44 | Updating target network...
# 18:57:45 | Episode: 44 | Rewards:
# 	Reward: [ -4. -21. 187.  -3.] | Avg Reward: 25.0 | Loss: 5.8672 | ε: 0.914 | LR: 2.54e-07
# 	Metrics - ['frags: 0', 'hits: 53', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 5', 'survival: -22', 'health_pickup: 3']
# 	Actions - Noop: 331, Move Forward: 1022, Attack: 877, Move Left: 699, Move Right: 633, Turn Left: 896, Turn Right: 1030, Jump: 512
# 18:57:45 | Episode: 44 | Running quick evaluation...
# Environment Seed: [1314  156]
# Host 64293
# Player 64293
# Episode 44 | encoders       | Shape: [2, 768],	Mean: 2.70,	Std: 4.82,	Norm: 216.56
# Episode 44 | head_first     | Shape: [2, 1024],	Mean: 3.11,	Std: 5.81,	Norm: 298.02
# Episode 44 | value_head     | Shape: [2, 1],	Mean: -4.69,	Std: 3.88,	Norm: 7.69
# Episode 44 | advantage_head | Shape: [2, 8],	Mean: -2.50,	Std: 9.34,	Norm: 37.51
#
# 18:57:48 | Episode: 45 | Steps done: 67500 | Gathering rollout (currently 25000)
# 18:58:04 | Episode: 45 | Training for 20 epochs
# 18:58:05 | Episode: 45 | Updating target network...
# 18:58:05 | Episode: 45 | Rewards:
# 	Reward: [-375.   22.   61.   95.] | Avg Reward: 23.0 | Loss: 6.2159 | ε: 0.912 | LR: 1.67e-07
# 	Metrics - ['frags: 0', 'hits: 100', 'damage_taken: -2', 'movement: 0', 'ammo_efficiency: 9', 'survival: -155', 'health_pickup: 0']
# 	Actions - Noop: 317, Move Forward: 1007, Attack: 914, Move Left: 678, Move Right: 657, Turn Left: 914, Turn Right: 985, Jump: 528
# 18:58:05 | Episode: 45 | Running quick evaluation...
# Environment Seed: [938 206]
# Host 64301
# Player 64301
# Episode 45 | encoders       | Shape: [2, 768],	Mean: 2.79,	Std: 5.00,	Norm: 224.15
# Episode 45 | head_first     | Shape: [2, 1024],	Mean: 3.14,	Std: 5.73,	Norm: 295.61
# Episode 45 | value_head     | Shape: [2, 1],	Mean: 0.26,	Std: 3.07,	Norm: 3.10
# Episode 45 | advantage_head | Shape: [2, 8],	Mean: 0.63,	Std: 11.66,	Norm: 45.21
#
# 18:58:08 | Episode: 46 | Steps done: 69000 | Gathering rollout (currently 25000)
# 18:58:23 | Episode: 46 | Training for 20 epochs
# 18:58:25 | Episode: 46 | Updating target network...
# 18:58:25 | Episode: 46 | Rewards:
# 	Reward: [-31. -18.  88.  99.] | Avg Reward: 23.0 | Loss: 6.4304 | ε: 0.910 | LR: 9.85e-08
# 	Metrics - ['frags: 0', 'hits: 55', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 5', 'survival: -27', 'health_pickup: 2']
# 	Actions - Noop: 316, Move Forward: 1026, Attack: 891, Move Left: 695, Move Right: 635, Turn Left: 972, Turn Right: 928, Jump: 537
# 18:58:25 | Episode: 46 | Running quick evaluation...
# Environment Seed: [1461   93]
# Host 64309
# Player 64309
# Episode 46 | encoders       | Shape: [2, 768],	Mean: 2.42,	Std: 4.54,	Norm: 201.79
# Episode 46 | head_first     | Shape: [2, 1024],	Mean: 2.71,	Std: 5.13,	Norm: 262.52
# Episode 46 | value_head     | Shape: [2, 1],	Mean: 2.38,	Std: 8.17,	Norm: 8.84
# Episode 46 | advantage_head | Shape: [2, 8],	Mean: -3.76,	Std: 9.38,	Norm: 39.30
#
# 18:58:28 | Episode: 47 | Steps done: 70500 | Gathering rollout (currently 25000)
# 18:58:43 | Episode: 47 | Training for 20 epochs
# 18:58:45 | Episode: 47 | Updating target network...
# 18:58:45 | Episode: 47 | Rewards:
# 	Reward: [ 67. -18. -18.  13.] | Avg Reward: 23.0 | Loss: 6.7022 | ε: 0.908 | LR: 4.94e-08
# 	Metrics - ['frags: 0', 'hits: 57', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 6', 'survival: -53', 'health_pickup: 2']
# 	Actions - Noop: 340, Move Forward: 1038, Attack: 878, Move Left: 652, Move Right: 653, Turn Left: 1001, Turn Right: 902, Jump: 536
# 18:58:45 | Episode: 47 | Running quick evaluation...
# Environment Seed: [1441  146]
# Host 64317
# Player 64317
# Episode 47 | encoders       | Shape: [2, 768],	Mean: 2.70,	Std: 4.87,	Norm: 218.32
# Episode 47 | head_first     | Shape: [2, 1024],	Mean: 3.12,	Std: 5.74,	Norm: 295.83
# Episode 47 | value_head     | Shape: [2, 1],	Mean: -1.48,	Std: 7.86,	Norm: 8.13
# Episode 47 | advantage_head | Shape: [2, 8],	Mean: -3.87,	Std: 8.64,	Norm: 36.88
#
# 18:58:48 | Episode: 48 | Steps done: 72000 | Gathering rollout (currently 25000)
# 18:59:03 | Episode: 48 | Training for 20 epochs
# 18:59:04 | Episode: 48 | Updating target network...
# 18:59:04 | Episode: 48 | Rewards:
# 	Reward: [ 33. -18.  59. -17.] | Avg Reward: 23.0 | Loss: 6.3016 | ε: 0.907 | LR: 1.99e-08
# 	Metrics - ['frags: 0', 'hits: 80', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 6', 'survival: -70', 'health_pickup: 0']
# 	Actions - Noop: 333, Move Forward: 1008, Attack: 926, Move Left: 696, Move Right: 636, Turn Left: 962, Turn Right: 922, Jump: 517
# 18:59:04 | Episode: 48 | Running quick evaluation...
# Environment Seed: [679 711]
# Host 64327
# Player 64327
# Episode 48 | encoders       | Shape: [2, 768],	Mean: 2.76,	Std: 4.90,	Norm: 220.33
# Episode 48 | head_first     | Shape: [2, 1024],	Mean: 3.03,	Std: 5.66,	Norm: 290.66
# Episode 48 | value_head     | Shape: [2, 1],	Mean: 5.19,	Std: 3.79,	Norm: 8.26
# Episode 48 | advantage_head | Shape: [2, 8],	Mean: -1.68,	Std: 8.43,	Norm: 33.35
#
# 18:59:08 | Episode: 49 | Steps done: 73500 | Gathering rollout (currently 25000)
# 18:59:23 | Episode: 49 | Training for 20 epochs
# 18:59:24 | Episode: 49 | Updating target network...
# 18:59:24 | Episode: 49 | Rewards:
# 	Reward: [ 86. 127.  34. -36.] | Avg Reward: 23.0 | Loss: 6.7222 | ε: 0.905 | LR: 1.00e-05
# 	Metrics - ['frags: 0', 'hits: 71', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 6', 'survival: -25', 'health_pickup: 2']
# 	Actions - Noop: 328, Move Forward: 979, Attack: 894, Move Left: 693, Move Right: 716, Turn Left: 914, Turn Right: 1002, Jump: 474
# 18:59:24 | Episode: 49 | Running quick evaluation...
# Environment Seed: [1630 1103]
# Host 64335
# Player 64335
# Episode 49 | encoders       | Shape: [2, 768],	Mean: 2.62,	Std: 4.78,	Norm: 213.63
# Episode 49 | head_first     | Shape: [2, 1024],	Mean: 3.00,	Std: 5.54,	Norm: 285.10
# Episode 49 | value_head     | Shape: [2, 1],	Mean: 4.54,	Std: 6.63,	Norm: 9.23
# Episode 49 | advantage_head | Shape: [2, 8],	Mean: -1.56,	Std: 8.13,	Norm: 32.08
#
# 18:59:28 | Episode: 50 | Steps done: 75000 | Gathering rollout (currently 25000)
# 18:59:43 | Episode: 50 | Training for 20 epochs
# 18:59:44 | Episode: 50 | Updating target network...
# 18:59:44 | Episode: 50 | Rewards:
# 	Reward: [-18. -18.  69. -18.] | Avg Reward: 23.0 | Loss: 6.4580 | ε: 0.903 | LR: 9.99e-06
# 	Metrics - ['frags: 0', 'hits: 25', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 3', 'survival: -25', 'health_pickup: 1']
# 	Actions - Noop: 301, Move Forward: 1022, Attack: 902, Move Left: 708, Move Right: 624, Turn Left: 928, Turn Right: 959, Jump: 556
# 18:59:44 | Episode: 50 | Replaying animation...
# 19:00:34 | Episode: 50 | Running quick evaluation...
# Environment Seed: [1786 1353]
# Host 64376
# Player 64376
# Episode 50 | encoders       | Shape: [2, 768],	Mean: 2.59,	Std: 4.75,	Norm: 211.98
# Episode 50 | head_first     | Shape: [2, 1024],	Mean: 2.90,	Std: 5.43,	Norm: 278.72
# Episode 50 | value_head     | Shape: [2, 1],	Mean: -6.83,	Std: 15.17,	Norm: 17.98
# Episode 50 | advantage_head | Shape: [2, 8],	Mean: -1.65,	Std: 9.58,	Norm: 37.67
#
# Successfully stored the model: runs/20250622_183846/backups/backup_model_20250622_190055.pt
# 19:00:57 | Episode: 51 | Steps done: 76500 | Gathering rollout (currently 25000)
# 19:01:12 | Episode: 51 | Training for 20 epochs
# 19:01:14 | Episode: 51 | Updating target network...
# 19:01:14 | Episode: 51 | Rewards:
# 	Reward: [ -8.  86. -18.  98.] | Avg Reward: 23.0 | Loss: 6.4422 | ε: 0.901 | LR: 9.96e-06
# 	Metrics - ['frags: 0', 'hits: 57', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 5', 'survival: -23', 'health_pickup: 1']
# 	Actions - Noop: 351, Move Forward: 996, Attack: 861, Move Left: 712, Move Right: 683, Turn Left: 878, Turn Right: 943, Jump: 576
# 19:01:14 | Episode: 51 | Running quick evaluation...
# Environment Seed: [1739  531]
# Host 64382
# Player 64382
# Episode 51 | encoders       | Shape: [2, 768],	Mean: 2.54,	Std: 4.69,	Norm: 209.08
# Episode 51 | head_first     | Shape: [2, 1024],	Mean: 2.84,	Std: 5.61,	Norm: 284.72
# Episode 51 | value_head     | Shape: [2, 1],	Mean: -10.20,	Std: 0.85,	Norm: 14.45
# Episode 51 | advantage_head | Shape: [2, 8],	Mean: -1.11,	Std: 11.16,	Norm: 43.44
#
# 19:01:17 | Episode: 52 | Steps done: 78000 | Gathering rollout (currently 25000)
# 19:01:33 | Episode: 52 | Training for 20 epochs
# 19:01:34 | Episode: 52 | Updating target network...
# 19:01:34 | Episode: 52 | Rewards:
# 	Reward: [  9. -18. -52. -18.] | Avg Reward: 23.0 | Loss: 7.1600 | ε: 0.899 | LR: 9.91e-06
# 	Metrics - ['frags: 0', 'hits: 6', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 2', 'survival: -28', 'health_pickup: 0']
# 	Actions - Noop: 320, Move Forward: 986, Attack: 904, Move Left: 661, Move Right: 649, Turn Left: 913, Turn Right: 1041, Jump: 526
# 19:01:34 | Episode: 52 | Running quick evaluation...
# Environment Seed: [714 975]
# Host 64384
# Player 64384
# Episode 52 | encoders       | Shape: [2, 768],	Mean: 2.51,	Std: 4.60,	Norm: 205.34
# Episode 52 | head_first     | Shape: [2, 1024],	Mean: 2.74,	Std: 5.22,	Norm: 266.68
# Episode 52 | value_head     | Shape: [2, 1],	Mean: -2.57,	Std: 3.08,	Norm: 4.77
# Episode 52 | advantage_head | Shape: [2, 8],	Mean: -1.96,	Std: 11.63,	Norm: 45.72
#
# 19:01:37 | Episode: 53 | Steps done: 79500 | Gathering rollout (currently 25000)
# 19:01:52 | Episode: 53 | Training for 20 epochs
# 19:01:53 | Episode: 53 | Updating target network...
# 19:01:53 | Episode: 53 | Rewards:
# 	Reward: [-92. -18.  73. -18.] | Avg Reward: 22.0 | Loss: 6.4199 | ε: 0.898 | LR: 9.84e-06
# 	Metrics - ['frags: 0', 'hits: 21', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 3', 'survival: -37', 'health_pickup: 0']
# 	Actions - Noop: 319, Move Forward: 1060, Attack: 937, Move Left: 677, Move Right: 652, Turn Left: 929, Turn Right: 882, Jump: 544
# 19:01:53 | Episode: 53 | Running quick evaluation...
# Environment Seed: [1994  250]
# Host 64388
# Player 64388
# Episode 53 | encoders       | Shape: [2, 768],	Mean: 2.63,	Std: 4.79,	Norm: 213.93
# Episode 53 | head_first     | Shape: [2, 1024],	Mean: 3.06,	Std: 5.56,	Norm: 287.20
# Episode 53 | value_head     | Shape: [2, 1],	Mean: -4.70,	Std: 2.04,	Norm: 6.95
# Episode 53 | advantage_head | Shape: [2, 8],	Mean: -4.74,	Std: 10.67,	Norm: 45.45
#
# 19:01:56 | Episode: 54 | Steps done: 81000 | Gathering rollout (currently 25000)
# 19:02:12 | Episode: 54 | Training for 20 epochs
# 19:02:13 | Episode: 54 | Updating target network...
# 19:02:13 | Episode: 54 | Rewards:
# 	Reward: [ -18.  -18.  136. -121.] | Avg Reward: 21.0 | Loss: 6.4371 | ε: 0.896 | LR: 9.76e-06
# 	Metrics - ['frags: 0', 'hits: 62', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 4', 'survival: -71', 'health_pickup: 0']
# 	Actions - Noop: 321, Move Forward: 1008, Attack: 900, Move Left: 690, Move Right: 646, Turn Left: 976, Turn Right: 927, Jump: 532
# 19:02:13 | Episode: 54 | Running quick evaluation...
# Environment Seed: [531  34]
# Host 64391
# Player 64391
# Episode 54 | encoders       | Shape: [2, 768],	Mean: 2.52,	Std: 4.67,	Norm: 208.08
# Episode 54 | head_first     | Shape: [2, 1024],	Mean: 2.71,	Std: 5.29,	Norm: 269.05
# Episode 54 | value_head     | Shape: [2, 1],	Mean: -2.14,	Std: 3.95,	Norm: 4.98
# Episode 54 | advantage_head | Shape: [2, 8],	Mean: 0.06,	Std: 8.72,	Norm: 33.76
#
# 19:02:16 | Episode: 55 | Steps done: 82500 | Gathering rollout (currently 25000)
# 19:02:32 | Episode: 55 | Training for 20 epochs
# 19:02:33 | Episode: 55 | Updating target network...
# 19:02:33 | Episode: 55 | Rewards:
# 	Reward: [ 83. -18. -18. -95.] | Avg Reward: 21.0 | Loss: 6.4132 | ε: 0.894 | LR: 9.65e-06
# 	Metrics - ['frags: 0', 'hits: 23', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 3', 'survival: -39', 'health_pickup: 1']
# 	Actions - Noop: 333, Move Forward: 1009, Attack: 932, Move Left: 723, Move Right: 645, Turn Left: 935, Turn Right: 906, Jump: 517
# 19:02:33 | Episode: 55 | Running quick evaluation...
# Environment Seed: [366  98]
# Host 64396
# Player 64396
# Episode 55 | encoders       | Shape: [2, 768],	Mean: 2.55,	Std: 4.74,	Norm: 210.71
# Episode 55 | head_first     | Shape: [2, 1024],	Mean: 3.05,	Std: 5.67,	Norm: 291.15
# Episode 55 | value_head     | Shape: [2, 1],	Mean: -0.54,	Std: 6.42,	Norm: 6.46
# Episode 55 | advantage_head | Shape: [2, 8],	Mean: -0.08,	Std: 7.35,	Norm: 28.47
#
# 19:02:36 | Episode: 56 | Steps done: 84000 | Gathering rollout (currently 25000)
# 19:02:52 | Episode: 56 | Training for 20 epochs
# 19:02:53 | Episode: 56 | Updating target network...
# 19:02:53 | Episode: 56 | Rewards:
# 	Reward: [ 33. -30.  -6. -22.] | Avg Reward: 19.0 | Loss: 6.6069 | ε: 0.892 | LR: 9.52e-06
# 	Metrics - ['frags: 0', 'hits: 13', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 4', 'survival: -24', 'health_pickup: 1']
# 	Actions - Noop: 355, Move Forward: 1047, Attack: 907, Move Left: 686, Move Right: 640, Turn Left: 907, Turn Right: 900, Jump: 558
# 19:02:53 | Episode: 56 | Running quick evaluation...
# Environment Seed: [808 492]
# Host 64401
# Player 64401
# Episode 56 | encoders       | Shape: [2, 768],	Mean: 2.44,	Std: 4.45,	Norm: 198.89
# Episode 56 | head_first     | Shape: [2, 1024],	Mean: 2.69,	Std: 5.08,	Norm: 259.98
# Episode 56 | value_head     | Shape: [2, 1],	Mean: -1.12,	Std: 5.46,	Norm: 5.68
# Episode 56 | advantage_head | Shape: [2, 8],	Mean: -1.59,	Std: 10.68,	Norm: 41.84
#
# 19:02:56 | Episode: 57 | Steps done: 85500 | Gathering rollout (currently 25000)
# 19:03:12 | Episode: 57 | Training for 20 epochs
# 19:03:13 | Episode: 57 | Updating target network...
# 19:03:13 | Episode: 57 | Rewards:
# 	Reward: [115. -18.   9.  41.] | Avg Reward: 18.0 | Loss: 6.1972 | ε: 0.890 | LR: 9.38e-06
# 	Metrics - ['frags: 0', 'hits: 76', 'damage_taken: -1', 'movement: 0', 'ammo_efficiency: 6', 'survival: -46', 'health_pickup: 2']
# 	Actions - Noop: 308, Move Forward: 1001, Attack: 907, Move Left: 680, Move Right: 681, Turn Left: 947, Turn Right: 960, Jump: 516
# 19:03:13 | Episode: 57 | Running quick evaluation...
# Environment Seed: [ 339 1375]
# Host 64405
# Player 64405
# Episode 57 | encoders       | Shape: [2, 768],	Mean: 2.51,	Std: 4.57,	Norm: 204.37
# Episode 57 | head_first     | Shape: [2, 1024],	Mean: 2.85,	Std: 5.35,	Norm: 274.13
# Episode 57 | value_head     | Shape: [2, 1],	Mean: -3.99,	Std: 7.92,	Norm: 9.72
# Episode 57 | advantage_head | Shape: [2, 8],	Mean: -4.33,	Std: 8.92,	Norm: 38.64
#
# 19:03:16 | Episode: 58 | Steps done: 87000 | Gathering rollout (currently 25000)
# 19:03:32 | Episode: 58 | Training for 20 epochs
# 19:03:33 | Episode: 58 | Updating target network...
# 19:03:33 | Episode: 58 | Rewards:
# 	Reward: [ 63. -18.  55. -18.] | Avg Reward: 18.0 | Loss: 6.3893 | ε: 0.889 | LR: 9.22e-06
# 	Metrics - ['frags: 0', 'hits: 56', 'damage_taken: -2', 'movement: 0', 'ammo_efficiency: 7', 'survival: -43', 'health_pickup: 2']
# 	Actions - Noop: 363, Move Forward: 1032, Attack: 907, Move Left: 636, Move Right: 715, Turn Left: 933, Turn Right: 879, Jump: 535
# 19:03:33 | Episode: 58 | Running quick evaluation...
# Environment Seed: [ 298 1689]
# Host 64418
# Player 64418
# Episode 58 | encoders       | Shape: [2, 768],	Mean: 2.53,	Std: 4.69,	Norm: 208.57
# Episode 58 | head_first     | Shape: [2, 1024],	Mean: 2.85,	Std: 5.40,	Norm: 276.35
# Episode 58 | value_head     | Shape: [2, 1],	Mean: 6.74,	Std: 0.63,	Norm: 9.56
# Episode 58 | advantage_head | Shape: [2, 8],	Mean: -0.59,	Std: 12.51,	Norm: 48.49
#
# 19:03:36 | Episode: 59 | Steps done: 88500 | Gathering rollout (currently 25000)
# 19:03:52 | Episode: 59 | Training for 20 epochs
# 19:03:53 | Episode: 59 | Updating target network...
# 19:03:53 | Episode: 59 | Rewards:
# 	Reward: [-13. -18. 110. 113.] | Avg Reward: 18.0 | Loss: 6.8972 | ε: 0.887 | LR: 9.05e-06
# 	Metrics - ['frags: 0', 'hits: 61', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 5', 'survival: -20', 'health_pickup: 2']
# 	Actions - Noop: 295, Move Forward: 1006, Attack: 935, Move Left: 681, Move Right: 636, Turn Left: 960, Turn Right: 959, Jump: 528
# 19:03:53 | Episode: 59 | Running quick evaluation...
# Environment Seed: [ 352 1890]
# Host 64436
# Player 64436
# Episode 59 | encoders       | Shape: [2, 768],	Mean: 2.46,	Std: 4.54,	Norm: 202.22
# Episode 59 | head_first     | Shape: [2, 1024],	Mean: 2.69,	Std: 5.23,	Norm: 266.25
# Episode 59 | value_head     | Shape: [2, 1],	Mean: -6.77,	Std: 0.83,	Norm: 9.61
# Episode 59 | advantage_head | Shape: [2, 8],	Mean: -2.10,	Std: 8.55,	Norm: 34.18
#
# 19:03:57 | Episode: 60 | Steps done: 90000 | Gathering rollout (currently 25000)
# 19:04:12 | Episode: 60 | Training for 20 epochs
# 19:04:13 | Episode: 60 | Updating target network...
# 19:04:13 | Episode: 60 | Rewards:
# 	Reward: [-19. -18. -18.  86.] | Avg Reward: 18.0 | Loss: 7.2574 | ε: 0.885 | LR: 8.85e-06
# 	Metrics - ['frags: 0', 'hits: 25', 'damage_taken: 0', 'movement: 0', 'ammo_efficiency: 3', 'survival: -21', 'health_pickup: 1']
# 	Actions - Noop: 339, Move Forward: 1024, Attack: 868, Move Left: 686, Move Right: 600, Turn Left: 950, Turn Right: 971, Jump: 562
# 19:04:13 | Episode: 60 | Running quick evaluation...
# Environment Seed: [ 135 1900]
# Host 64448
# Player 64448
# Episode 60 | encoders       | Shape: [2, 768],	Mean: 2.43,	Std: 4.55,	Norm: 202.22
# Episode 60 | head_first     | Shape: [2, 1024],	Mean: 2.85,	Std: 5.31,	Norm: 272.81
# Episode 60 | value_head     | Shape: [2, 1],	Mean: -4.81,	Std: 2.36,	Norm: 7.20
# Episode 60 | advantage_head | Shape: [2, 8],	Mean: -0.88,	Std: 7.10,	Norm: 27.73
#
# Successfully stored the model: runs/20250622_183846/backups/backup_model_20250622_190415.pt
# 19:04:16 | Episode: 61 | Steps done: 91500 | Gathering rollout (currently 25000)

# %% [markdown]
# ## Dump to ONNX

# %%
  # ---------------------  SAVE / EXPORT ---------------------------------------
final_model = best_model if best_model is not None else model

onnx_filename = os.path.join(training_folder, "enhanced_doom_agent.onnx")
onnx_dump(env, final_model, PLAYER_CONFIG, onnx_filename)
print(f"Best network exported to {onnx_filename}")
# Out:
# Best network exported to runs/20250622_180012/enhanced_doom_agent.onnx

# %% [markdown]
# ### Evaluation and Visualization
#
# In this final section, you can evaluate your trained agent, inspect its performance visually, and analyze reward components over time.

# %%
plot_training_metrics(get_avg_reward(reward_history), q_loss_list, epsilon_history)

# %%
replay_episode(env, final_model, device, DTYPE, store=True, random_player=False)
# Out:
# Enabling replays!
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 replay_episode(env, final_model, device, DTYPE, store=True, random_player=False)
#
# File ~/Documents/Studium/JKU/DRL/UE_DRL/Final/jku.wad/agents/utils.py:72, in replay_episode(env, model, device, dtype, path, store, random_player)
#      69 while not all(eval_dones):
#      70     env_actions = EnvActions(env)
# ---> 72     eval_act = epsilon_greedy(env, model, eval_obs, 0, env_actions, device, dtype=dtype)
#      73     eval_obs, reward_components, eval_dones, _ = env.step(eval_act)
#      74     eval_reward += sum(reward_components)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Documents/Studium/JKU/DRL/UE_DRL/Final/jku.wad/agents/dqn.py:55, in epsilon_greedy(env, model, obs, epsilon, env_actions, device, dtype, action_counter, debug)
#      52     obs = torch.stack(obs) # stack players
#      54 processed_obs = process_observation(obs, device=device, dtype=dtype, permute=False)
# ---> 55 q_values = model(processed_obs)
#      57 # Indices are necessary if buttons don't start at 0 but at 1 (e.g., if there wouldn't be a noop option)
#      58 if num_players == 1:
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Documents/Studium/JKU/DRL/UE_DRL/Final/jku.wad/agents/dqn.py:201, in EfficientDQN.forward(self, observations)
#     194 """
#     195 Forward pass through multi-buffer DQN
#     196
#     197 Args:
#     198     observations: Tensor for "screen", "depth", "labels", "automap"
#     199 """
#     200 # Encode each visual buffer and split the observations
# --> 201 features = self.encoders(observations.split(self.obs_state_dims, dim=1))
#     203 # Use one head for the dueling network
#     204 head_logits = self.head_first(features)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Documents/Studium/JKU/DRL/UE_DRL/Final/jku.wad/agents/modules.py:20, in Parallel.forward(self, inputs)
#      17 all_logits = []
#      19 for module, input in zip(self.model, inputs):
# ---> 20     all_logits.append(module(input))
#      22 return torch.cat(all_logits, dim=1)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniconda3/envs/jku_wad/lib/python3.12/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# RuntimeError: Input type (MPSFloatType) and weight type (torch.FloatTensor) should be the same
